# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import glob,gzip,os,operator
import numpy as np
from numpy.random import randn
from itertools import combinations
import random
import pandas as pd
from scipy import stats
from scipy.spatial import KDTree
from sklearn.metrics import confusion_matrix
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("temp/1kg3_maf_fst.txt",header=0,sep='\t')

# %%
print "Number of nsSNPs: %d"%len(df)
# Out:
# Number of nsSNPs: 644956

# %%
print df.corr()
print df[df["allpop_Fst"]>0.05].corr()
print df[df["allpop_Fst"]>0.1].corr()
# Out:
#                  maf  allpop_Fst
# maf         1.000000    0.523356
# allpop_Fst  0.523356    1.000000
#                  maf  allpop_Fst
# maf         1.000000    0.227841
# allpop_Fst  0.227841    1.000000
#                  maf  allpop_Fst
# maf         1.000000    0.154448
# allpop_Fst  0.154448    1.000000

# %%
# plt.scatter(df["maf"],df["allpop_Fst"])
plt.scatter(df["maf"],df["allpop_Fst"])
plt.xlabel("maf")
plt.ylabel("Fst")

# %%
np.percentile(df["allpop_Fst"],95)
# Out:
# 0.040825500000000001

# %%
plt.scatter(df.ix[df["allpop_Fst"]<=0.04082,"maf"],df.ix[df["allpop_Fst"]<=0.04082,"allpop_Fst"])
plt.xlabel("maf")
plt.ylabel("Fst")

# %%
plt.scatter(df.ix[df["allpop_Fst"]>0.04082,"maf"],df.ix[df["allpop_Fst"]>0.04082,"allpop_Fst"])
plt.xlabel("maf")
plt.ylabel("Fst")
