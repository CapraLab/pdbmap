# %% [markdown]
# ##HAVE NOT YET ADAPTED FROM RTEL1

# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import glob,gzip,os
import numpy as np
from numpy.random import randn
from itertools import combinations
import random
import pandas as pd
from scipy import stats
from scipy.spatial import KDTree
from sklearn.metrics import confusion_matrix
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# Read the mutation disease classifications
rtel1_dclass = {}
# saxpd_dclass = {}
with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/1kg3.txt','rb') as fin:
  rtel1_dclass.update(dict((m.strip()[1:],0) for m in fin))
with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/candidate.txt','rb') as fin:
  rtel1_dclass.update(dict((m.strip()[1:],3) for m in fin))
with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/telomere_syndrome.txt','rb') as fin:
  rtel1_dclass.update(dict((m.strip()[1:],1) for m in fin))
with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/pulmonary_fibrosis.txt','rb') as fin:
  rtel1_dclass.update(dict((m.strip()[1:],2) for m in fin))
# with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/xp_snps.txt','rb') as fin:
#   saxpd_dclass.update(dict((m.strip()[1:],4) for m in fin))
# with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/xpcs_snps.txt','rb') as fin:
#   saxpd_dclass.update(dict((m.strip()[1:],5) for m in fin))
# with open('/Volumes/sivleyrm/pdbmap/temp/rtel1/ttd_snps.txt','rb') as fin:
#   saxpd_dclass.update(dict((m.strip()[1:],6) for m in fin))
dcolor = {0:"darkgray",1:"green",2:"blue",3:"red",4:"orange",5:"yellow",6:"purple"}
rtel1_pos2snp = dict((int(key[1:-1]),key) for key in rtel1_dclass.keys())
# saxpd_pos2snp = dict((int(key[1:-1]),key) for key in saxpd_dclass.keys())

# %%
rtel1_coord_file = "/Volumes/sivleyrm/pdbmap/results/RTEL_Custom_Model_wt_relaxation/RTEL_Custom_Model.relaxed.pdb.gz"
# saxpd_coord_file = "/Volumes/sivleyrm/pdbmap/temp/rtel1/SaXPD.coords"

# %%
def snp_coords(coord_file):
    with gzip.open(coord_file,'rb') as fin:
        rows = [line.split()[3:8] for line in fin if line[:4]=="ATOM"]
        try:
            int(rows[0][1])
        except:
            with open(coord_file,'rb') as fin:
                rows = [line.split()[3:9] for line in fin if line[:4]=="ATOM"]
        rtel1_coords = np.array(rows)
        if rtel1_coords.shape[1] == 5:
            df = pd.DataFrame(rtel1_coords,columns=["res","seqid","x","y","z"])
            df["chain"] = "A"
        else:
            df = pd.DataFrame(rtel1_coords,columns=["res","chain","seqid","x","y","z"])
    df[["seqid"]] = df[["seqid"]].astype(np.int)
    df[["x","y","z"]] = df[["x","y","z"]].astype(np.float64)
    coords = np.array(zip(df.groupby(["chain","seqid"])["x"].mean(),df.groupby(["chain","seqid"])["y"].mean(),df.groupby(["chain","seqid"])["z"].mean()))
    coord_df = df[["res","chain","seqid"]].drop_duplicates()
    coord_df["x"] = coords[:,0]
    coord_df["y"] = coords[:,1]
    coord_df["z"] = coords[:,2]
    return coord_df
rtel1_coords = snp_coords(rtel1_coord_file)
# saxpd_coords = snp_coords(saxpd_coord_file)

# %%
cls2code = {"1000 Genomes":0,"Telomere Syndrome":1,"Pulmonary Fibrosis":2,"Candidate":3,"XP":4,"XP/CS":5,"TDD":6}
rtel1_coords = rtel1_coords[rtel1_coords["seqid"].isin(rtel1_pos2snp.keys())]
rtel1_coords["dcode"] = rtel1_coords["seqid"].apply(lambda x: rtel1_dclass[rtel1_pos2snp[x]])
# saxpd_coords["dcode"] = saxpd_coords["seqid"].apply(lambda x: saxpd_dclass[saxpd_pos2snp[x]])
# coords = pd.concat((rtel1_coords,saxpd_coords))
coords = rtel1_coords
print "Candidate Coords:"
print rtel1_coords[rtel1_coords["dcode"]==3]
# Out:
# Candidate Coords:
#        res chain  seqid          x          y          z  dcode
# 858    THR     A     55  -0.472857  -2.291357   6.251643      3
# 8662   PHE     A    559  11.674100 -29.138100  15.477000      3
# 10661  SER     A    688  -0.743545 -26.509818  17.816545      3
# 11159  ASP     A    719 -11.516917 -34.769417  15.859417      3

# %%
@np.vectorize
def score(D):
    if 0<D<=8:
        return 1.
    elif 8<D<=16:
        return np.sin((D-8)/5.1+.5*np.pi)
    else:
        return 0.

# %%
# Predict disease status with a kNN approach
def pathprox(dfq,dcodes=[],show_scores=False):
    k = len(dfq)
    dfq["Pathogenic"] = np.array([1 if d in dcodes else -1 for d in dfq["dcode"]]) # Set which dcodes to use
    dfq.ix[dfq["dcode"]==0,"Pathogenic"] = 0 # Set the neutral variants
    num_neut = (dfq["Pathogenic"]==0).sum() 
    num_path = (dfq["Pathogenic"]==1).sum()
    pathprox = []
    for i,row in dfq.iterrows():
        # Calculate a "neutral score"
        kdt = KDTree(dfq.ix[dfq["Pathogenic"]==0,["x","y","z"]])
        dist,snps = kdt.query(row[["x","y","z"]],num_neut)
        neutral_score = np.sum(score(dist))/num_neut
        # Calculate a "pathogenic score"
        kdt = KDTree(dfq.ix[dfq["Pathogenic"]==1,["x","y","z"]])
        dist,snps = kdt.query(row[["x","y","z"]],num_path)
        pathogenic_score = np.sum(score(dist))/num_path
        pathprox.append(pathogenic_score/neutral_score)
    # Set all scores to real values (inf->max,nan->0)
    pathprox = np.array(pathprox)
    pathprox[np.isnan(pathprox)] = 0
    pathprox[np.isinf(pathprox)] = np.max(pathprox[np.isfinite(pathprox)])
    return pathprox

# %%
all_coords = coords.copy()
coords["IPF_Path"]   = pathprox(coords,[2])
print "IPF Path:\n",coords.ix[coords["dcode"]==3,["res","chain","seqid","IPF_Path"]].sort("IPF_Path",ascending=False)
coords["Tel_Path"]   = pathprox(coords,[1])
print "\nTel Path:\n",coords.ix[coords["dcode"]==3,["res","chain","seqid","Tel_Path"]].sort("Tel_Path",ascending=False)
coords["RTEL1_Path"] = pathprox(coords,[1,2])
print "\nRTEL1 Path:\n",coords.ix[coords["dcode"]==3,["res","chain","seqid","RTEL1_Path"]].sort("RTEL1_Path",ascending=False)
# coords["XPCS_Path"]  = pathprox(coords,[4,5])
# coords["TDD_Path"]   = pathprox(coords,[6])
# coords["SaXPD_Path"] = pathprox(coords,[4,5,6])
# coords["All_Path"]   = pathprox(coords,[1,2,4,5,6])
# print coords[coords["dcode"]==3].sort("All_Path",ascending=False)
print "--"
print coords[["res","seqid","dcode","IPF_Path","Tel_Path","RTEL1_Path"]].sort("RTEL1_Path",ascending=False)
# print coords[["res","seqid","dcode","IPF_Path","Tel_Path","RTEL1_Path","XPCS_Path","TDD_Path","SaXPD_Path","All_Path"]].sort("All_Path",ascending=False)
coords.to_csv("/Users/mikesivley/Dropbox/Vanderbilt/Research/UDN/RTEL1/RTEL1-Pathogenicity_Predictions.txt",sep="\t")
# Out:
# IPF Path:
#        res chain  seqid   IPF_Path
# 10661  SER     A    688  19.160639
# 8662   PHE     A    559  17.603709
# 11159  ASP     A    719   8.799839
# 858    THR     A     55   0.000000
#
# Tel Path:
#        res chain  seqid   Tel_Path
# 8662   PHE     A    559  17.498617
# 10661  SER     A    688   3.698748
# 11159  ASP     A    719   1.574238
# 858    THR     A     55   0.000000
#
# RTEL1 Path:
#        res chain  seqid  RTEL1_Path
# 8662   PHE     A    559   17.528643
# 10661  SER     A    688    8.116431
# 11159  ASP     A    719    3.638695
# 858    THR     A     55    0.000000
# --
#        res  seqid  dcode    IPF_Path    Tel_Path  RTEL1_Path
# 8015   VAL    516      2  185.131458  182.957248  183.578451
# 9650   ALA    621      0  185.131458  182.957248  183.578451
# 11494  GLY    739      1   59.254401   20.850673   31.823167
# 8369   SER    540      2   17.268200   31.922303   27.735416
# 11016  LEU    710      1   51.466048   12.499920   23.633099
# 11977  VAL    770      0    0.000000   30.633557   21.881112
# 8662   PHE    559      3   17.603709   17.498617   17.528643
# 7494   ALA    483      0   26.364389   13.453963   17.142656
# 10593  ARG    684      0   43.663662    4.201342   15.476291
# 11589  VAL    745      1    9.264611   11.549727   10.896837
# 10661  SER    688      3   19.160639    3.698748    8.116431
# 7620   MET    492      1   11.071537    3.655228    5.774173
# 10829  ILE    699      1    0.000000    6.471300    4.622357
# 10014  PRO    647      2    5.072846    4.089564    4.370501
# 8955   ARG    576      0    3.457025    4.623929    4.290528
# 11722  GLU    753      0    0.000000    5.169778    3.692698
# 11159  ASP    719      3    8.799839    1.574238    3.638695
# 9857   THR    636      0    0.000000    4.779278    3.413770
# 13969  SER    898      0    0.000000    4.213053    3.009324
# 1729   ALA    112      0    0.000000    3.794041    2.710029
# 14929  SER    966      0    0.000000    3.173815    2.267010
# 1739   SER    113      0    0.000000    3.127809    2.234149
# 13884  PRO    893      0    0.000000    2.871545    2.051104
# 7504   PRO    484      2    0.000000    2.503701    1.788358
# 16010  PRO   1034      0    0.000000    2.500447    1.786033
# 14957  LEU    968      0    0.407285    2.299989    1.759216
# 4009   GLU    251      1    0.000000    2.288057    1.634327
# 13810  ARG    888      0    0.000000    2.229396    1.592426
# 14911  GLY    964      1    2.141581    1.319360    1.554280
# 13188  HIS    849      0    0.000000    1.832689    1.309063
# 14806  ARG    957      1    1.419584    1.050070    1.155645
# 15287  ALA    989      0    0.000000    1.542875    1.102054
# 15015  LEU    972      0    0.000000    1.127455    0.805325
# 15326  THR    992      0    0.000000    1.075629    0.768307
# 1918   ASN    124      0    0.000000    1.050905    0.750646
# 9218   GLU    591      1    2.307340    0.000000    0.659240
# 13097  PHE    844      0    0.000000    0.854368    0.610263
# 15173  ASP    982      0    0.000000    0.575358    0.410970
# 15118  ASP    978      0    0.000000    0.433460    0.309614
# 15832  THR   1022      0    0.000000    0.387082    0.276487
# 15759  PHE   1017      0    0.000000    0.334459    0.238900
# 15154  LEU    981      0    0.000000    0.165699    0.118357
# 14470  GLN    933      0    0.000000    0.000000    0.000000
# 14529  GLY    937      0    0.000000    0.000000    0.000000
# 14590  ALA    941      0    0.000000    0.000000    0.000000
# 14421  GLY    929      0    0.000000    0.000000    0.000000
# 14600  GLY    942      0    0.000000    0.000000    0.000000
# 6727   THR    434      0    0.000000    0.000000    0.000000
# 1325   ARG     84      0    0.000000    0.000000    0.000000
# 1378   SER     87      0    0.000000    0.000000    0.000000
# 15447  PRO   1000      0    0.000000    0.000000    0.000000
# 15588  PHE   1008      0    0.000000    0.000000    0.000000
# 15679  HIS   1013      0    0.000000    0.000000    0.000000
# 15790  GLN   1019      0    0.000000    0.000000    0.000000
# 15898  ARG   1027      0    0.000000    0.000000    0.000000
# 15130  ASP    979      0    0.000000    0.000000    0.000000
# 13598  ARG    875      0    0.000000    0.000000    0.000000
# 13953  VAL    897      1    0.000000    0.000000    0.000000
# 3299   TYR    209      0    0.000000    0.000000    0.000000
# 5919   ARG    379      0    0.000000    0.000000    0.000000
# 5536   GLU    354      0    0.000000    0.000000    0.000000
# 5321   GLY    340      0    0.000000    0.000000    0.000000
# 5164   ALA    328      0    0.000000    0.000000    0.000000
# 5025   MET    320      0    0.000000    0.000000    0.000000
# 4540   THR    287      0    0.000000    0.000000    0.000000
# 4394   VAL    278      0    0.000000    0.000000    0.000000
# 4259   THR    268      0    0.000000    0.000000    0.000000
# 3744   ARG    235      0    0.000000    0.000000    0.000000
# 3371   ARG    213      0    0.000000    0.000000    0.000000
# 2814   VAL    178      0    0.000000    0.000000    0.000000
# 6192   GLN    397      0    0.000000    0.000000    0.000000
# 1172   GLU     74      0    0.000000    0.000000    0.000000
# 2645   VAL    167      0    0.000000    0.000000    0.000000
# 2110   VAL    135      0    0.000000    0.000000    0.000000
# 12319  LYS    793      0    0.000000    0.000000    0.000000
# 12585  ASP    810      0    0.000000    0.000000    0.000000
# 12658  ASP    815      0    0.000000    0.000000    0.000000
# 13117  VAL    845      0    0.000000    0.000000    0.000000
# 13463  TYR    867      0    0.000000    0.000000    0.000000
# 13522  GLU    870      0    0.000000    0.000000    0.000000
# 13537  HIS    871      0    0.000000    0.000000    0.000000
# 858    THR     55      3    0.000000    0.000000    0.000000

# %%
def path_roc(dfq,dcodes=[0,1],pathcodes=[2],predcol="All_Path",label="",color="red",jitter=False):
    from sklearn.metrics import roc_curve,auc
    jitter = np.random.normal(0,0.01,1)[0] if jitter else 0
    dfq = dfq.sort(predcol,ascending=False)
    dfq["Pathogenic"] = np.array([1 if d in pathcodes else -1 for d in dfq["dcode"]])
    dfq.ix[dfq["dcode"]==0,"Pathogenic"] = 0 # Set to netrual variants
    dfq = dfq[dfq["Pathogenic"]>-1]
    fpr,tpr,thresh = roc_curve(dfq.ix[dfq["dcode"].isin(dcodes),"Pathogenic"],dfq.ix[dfq["dcode"].isin(dcodes),predcol])
    roc_auc = auc(fpr,tpr)
    fpr += jitter
    tpr += jitter
    plt.plot(fpr-0.01,tpr+0.01,label='%s (AUC = %0.2f)'%(label,roc_auc),color=color)

# %%
# Plot the ROC for predicting RTEL1 IPF SNPs from RTELPATH
plt.figure(figsize=(10,10))
plt.title('Predicting IPF nsSNPs from known Pulmonary Fibrosis and Telomere Syndrome nsSNPs')
# ROC with Pulmonary Fibrosis Background
path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="IPF_Path",label="IPF from IPF",color="Gold",jitter=False)
# ROC with Telomere Syndrome Background
path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="Tel_Path",label="IPF from Telomere Syndrome",color="Blue",jitter=False)
# ROC with Pulmonary Fibrosis + Telomere Syndrome Background
path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="RTEL1_Path",label="IPF from RTEL1",color="Black",jitter=False)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig("ipf_from_ipf-ts.pdf")
plt.show()

# %%
# # Plot the ROC for predicting RTEL1 IPF SNPs from RTELPATH or SAXPDPATH mutations
# plt.figure(figsize=(10,10))
# plt.title('Predicting IPF nsSNPs from Disease-Associated SaXPD Mutations')
# # ROC with Pulmonary Fibrosis + Telomere Syndrome Background
# path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="RTEL1_Path",label="IPF from RTEL1",color="black")
# # ROC with XP + XP/CS + TDD background
# path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="SaXPD_Path",label="IPF from SaXPD",color="red")
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.legend(loc="lower right")
# plt.savefig("ipf_from_saxpd.pdf")
# plt.show()

# %%
# # Plot the ROC for predicting RTEL1 IPF SNPs from RTELPATH or SAXPDPATH mutations
# plt.figure(figsize=(10,10))
# plt.title('Predicting IPF nsSNPs from Disease-Associated Mutations')
# # ROC with Pulmonary Fibrosis + Telomere Syndrome Background
# path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="RTEL1_Path",label="IPF from RTEL1",color="black")
# # ROC with XP + XP/CS + TDD background
# path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="SaXPD_Path",label="IPF from SaXPD",color="red")
# # ROC with All known pathogenic SNPs as background
# path_roc(coords,dcodes=[0,2],pathcodes=[2],predcol="All_Path",label="Telomere Syndrome from RTEL1 + SaXPD",color="green")
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.legend(loc="lower right")
# plt.savefig("ipf_from_rtel1-saxpd.pdf")
# plt.show()

# %%
# Plot the ROC for predicting RTEL1 IPF SNPs from different pathogenic backgrounds
plt.figure(figsize=(10,10))
plt.title('Predicting Telomere Syndrome Pathogenic nsSNPs from Different Pathogenic SNP Sets')
# ROC with Pulmonary Fibrosis background
path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="IPF_Path",label="Telomere Syndrome from IPF",color="red")
# ROC with Telomere Syndrome background
path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="Tel_Path",label="Telomere Syndrome from Telomere Syndrome",color="orange")
# ROC with Pulmonary Fibrosis + Telomere Syndrome Background
path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="RTEL1_Path",label="Telomere Syndrome from RTEL1",color="yellow")
# # ROC with XP + XP/CS background
# path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="XPCS_Path",label="Telomere Syndrome from XP/CS",color="green")
# # ROC with TDD background
# path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="TDD_Path",label="Telomere Syndrome from TDD",color="blue")
# # ROC with XP + XP/CS + TDD background
# path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="SaXPD_Path",label="Telomere Syndrome from SaXPD",color="purple")
# # ROC with All known pathogenic SNPs as background
# path_roc(coords,dcodes=[0,1],pathcodes=[1],predcol="All_Path",label="Telomere Syndrome from RTEL1 + SaXPD",color="black")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %%
# # Plot the ROC for predicting RTEL1 SNPs from SaXPD SNPs
# plt.figure(figsize=(10,10))
# plt.title('Predicting RTEL1 Pathogenic nsSNPs from SaXPD pathogenic nsSNPs')
# path_roc(coords,dcodes=[0,1,2],pathcodes=[1,2],predcol="SaXPD_Path",label="RTEL1 nsSNPs from SaXPD nsSNPs",color="darkblue")
# path_roc(coords,dcodes=[0,1,2],pathcodes=[1,2],predcol="XPCS_Path",label="RTEL1 nsSNPs from XP+XP/CS nsSNPs",color="darkred")
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.legend(loc="lower right")
# plt.show()

# %%
# Predicting candidate SNP pathogenicity from IPF nsSNPs
print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","IPF_Path"]]
print "--"
# Predicting candidate SNP pathogenicity from Telomere Syndrome nsSNPs
print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","Tel_Path"]]
print "--"
# Predicting candidate SNP pathogenicity from RTEL1 nsSNPs
print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","RTEL1_Path"]]
# print "--"
# # Predicting candidate SNP pathogenicity from XP/CS nsSNPs
# print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","XPCS_Path"]]
# print "--"
# # Predicting candidate SNP pathogenicity from TDD nsSNPs
# print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","TDD_Path"]]
# print "--"
# # Predicting candidate SNP pathogenicity from SaXPD nsSNPs
# print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","SaXPD_Path"]]
# print "--"
# # Predicting candidate SNP pathogenicity from RTEL1 and SaXPD nsSNPs
# print coords[coords["dcode"]==3].sort("IPF_Path",ascending=False)[["res","seqid","All_Path"]]
# Out:
#        res  seqid   IPF_Path
# 10661  SER    688  19.160639
# 8662   PHE    559  17.603709
# 11159  ASP    719   8.799839
# 858    THR     55   0.000000
# --
#        res  seqid   Tel_Path
# 10661  SER    688   3.698748
# 8662   PHE    559  17.498617
# 11159  ASP    719   1.574238
# 858    THR     55   0.000000
# --
#        res  seqid  RTEL1_Path
# 10661  SER    688    8.116431
# 8662   PHE    559   17.528643
# 11159  ASP    719    3.638695
# 858    THR     55    0.000000
