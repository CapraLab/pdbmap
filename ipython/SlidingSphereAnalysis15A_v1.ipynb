# %% [markdown]
# ## Duplicate of the first Sliding Sphere Analysis - Corrections Made - Evaluating 15A Spheres

# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# Z:\projects\pdbmap

# %%
# Load libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the results file into a pandas data frame
import pandas as pd
results_fname = 'results/sliding_sphere_15/sliding_sphere_1KG_15A.txt'
df = pd.read_table(results_fname,delimiter='\t')
df.describe()
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1130: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                  isvar           issnp         amr_af         asn_af  \
# count  12543145.000000  1205347.000000  417475.000000  417475.000000
# mean          0.096096        0.226357       0.020855       0.022056
# std           0.294723        0.418473       0.099231       0.106024
# min           0.000000        0.000000       0.000000       0.000000
# 25%           0.000000        0.000000       0.000000       0.000000
# 50%           0.000000        0.000000       0.000000       0.000000
# 75%           0.000000        0.000000       0.010000       0.010000
# max           1.000000        1.000000       1.000000       1.000000
#
#               eur_af         afr_af            seqid                x  \
# count  417475.000000  417475.000000  12543145.000000  12543145.000000
# mean        0.020751       0.061122       300.435591        17.212520
# std         0.102887       0.123018       385.040667        45.397133
# min         0.000000       0.000000        -4.552333      -448.479126
# 25%         0.000000       0.000000        99.000000        -6.932500
# 50%         0.000000       0.002000       204.000000        14.612125
# 75%         0.010000       0.020000       365.000000        38.067089
# max         1.000000       1.000000      8797.000000       610.963013
#
#                      y             z      ...       AMR_EUR_obsor  \
# count  12543145.000000  1.254281e+07      ...        1.103800e+06
# mean         18.112588           inf      ...                 inf
# std          48.415826           NaN      ...                 NaN
# min        -963.986023 -5.814912e+02      ...        0.000000e+00
# 25%          -7.927125 -4.486000e+00      ...        3.827160e-01
# 50%          13.495251  1.788118e+01      ...        1.000000e+00
# 75%          40.112442  4.361575e+01      ...        2.000000e+00
# max         447.828491           inf      ...                 inf
#
#          AMR_EUR_pval  AMR_AFR_obsor  AMR_AFR_pval  ASN_EUR_obsor  \
# count  1212182.000000   1.251527e+06  1.350280e+06   1.222720e+06
# mean         0.820994            inf           inf            inf
# std          0.268494            NaN           NaN            NaN
# min          0.000000   0.000000e+00  0.000000e+00   0.000000e+00
# 25%          0.556122   3.750000e-01  5.428571e-01   0.000000e+00
# 50%          1.000000   1.000000e+00  1.000000e+00   1.000000e+00
# 75%          1.000000   2.000000e+00  1.000000e+00   3.000000e+00
# max          2.400000            inf           inf            inf
#
#        ASN_EUR_pval  ASN_AFR_obsor  ASN_AFR_pval  EUR_AFR_obsor  \
# count  1.352838e+06   1.404659e+06  1.509234e+06   1.479608e+06
# mean            inf            inf           inf            inf
# std             NaN            NaN           NaN            NaN
# min    0.000000e+00   0.000000e+00  0.000000e+00   0.000000e+00
# 25%    4.830769e-01   0.000000e+00  4.848485e-01   3.259259e-01
# 50%    1.000000e+00   9.166667e-01  1.000000e+00   1.000000e+00
# 75%    1.000000e+00   3.000000e+00  1.000000e+00   2.857143e+00
# max             inf            inf           inf            inf
#
#          EUR_AFR_pval
# count  1585680.000000
# mean         0.747782
# std          0.297108
# min          0.000019
# 25%          0.497238
# 50%          1.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 22 columns]

# %%
# View all column names
print df.dtypes
# Out:
# isvar              int64
# issnp            float64
# name              object
# amr_af           float64
# asn_af           float64
# eur_af           float64
# afr_af           float64
# structid          object
# chain             object
# unp               object
# seqid            float64
# x                float64
# y                float64
# z                float64
# AMR_ASN_obsor    float64
# AMR_ASN_pval     float64
# AMR_EUR_obsor    float64
# AMR_EUR_pval     float64
# AMR_AFR_obsor    float64
# AMR_AFR_pval     float64
# ASN_EUR_obsor    float64
# ASN_EUR_pval     float64
# ASN_AFR_obsor    float64
# ASN_AFR_pval     float64
# EUR_AFR_obsor    float64
# EUR_AFR_pval     float64
# dtype: object

# %%
# Define the population lists to avoid mess below
pop_pvals = ['AMR_ASN_pval','AMR_EUR_pval','AMR_AFR_pval','ASN_EUR_pval','ASN_AFR_pval','EUR_AFR_pval']
pop_ors   = ['AMR_ASN_obsor','AMR_EUR_obsor','AMR_AFR_obsor','ASN_EUR_obsor','ASN_AFR_obsor','EUR_AFR_obsor']

# %%
# Quality Control: There are a lot of residues with p-values equal to 1.0
# I need to find out what is driving these, but first, we'll remove them
# They probably reflect testing under an invalid condition
df[pop_pvals] = df[pop_pvals].replace(1,np.nan)
# There was a problem found earlier with 3RBN duplication, fixing:
df = df[df['structid']!='A']
df = df[df['structid']!='B']

# %%
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    df[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Not a good start, really. These p-values seem to be following three separate distributions in the first, second, and third tertiles (had to look that one up). I also don't see any infalation for p-values near 0.

# %%
# How many nominally significant (p<0.05) spheres do we have for each population comparison?
totcnt = len(df)
print "Total residues tested: %d"%totcnt
for pop_pval in pop_pvals:
    popcnt = len(df[~np.isnan(df[pop_pval])])
    sigcnt = len(df[df[pop_pval]<0.05])
    print "%s: %d\tof %d(%2.2f%%)"%(pop_pval,sigcnt,popcnt,(float(sigcnt)/popcnt)*100)
# Out:
# Total residues tested: 12542645
# AMR_ASN_pval: 8722	of 517556(1.69%)
# AMR_EUR_pval: 1392	of 399824(0.35%)
# AMR_AFR_pval: 1607	of 489866(0.33%)
# ASN_EUR_pval: 9381	of 613458(1.53%)
# ASN_AFR_pval: 7454	of 723641(1.03%)
# EUR_AFR_pval: 7340	of 718228(1.02%)

# %% [markdown]
# Confusing p-value distributions aside, we're at least seeing nominally significant p-values in fewer than 5% of tested residues within each population, so there is some evidence that those residues are actually significant and not simply the product of chance. Then again, given the p-value distribution, the likelihood of a null residue having a p-value <0.05 isn't 5%, it's likely less.

# %%
# Let's see the p-value distributions from before, but only for our nominally significant residues
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    tdf = df[df[pop_pval]<0.05][pop_pval]
    tdf.hist(bins=20,range=(0,0.05))
    plt.xlabel("Nominally significant %s"%pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Oh, so here's a thought. Since I'm only looking at spheres that contained at least 2 variants in one of the populations, I'm further increasing the dependence of my tests. That might explain a lot of the mini-distributions I'm seeing, since any biases in PDB representation would cause inflation of all p-values derived from that protein/residue/gene/etc.
#
# I should be able to check for this effect by doing we talked about during our last meeting. I'll generate a non-redundant set of structures representing all of the proteins mapped in the PDB. I'll choose each structure as the one that contains the most protein sequence for the given protein. If this flattens out my p-value distribution, then I can attribute the effect to PDB bias.

# %%
# There are too many significant spheres to look at them at once.
# How many unique structures contained significant spheres, for each population comparison?
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').size()
    print "%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
# Out:
# AMR_ASN_pval: 99 unique proteins with significant residues
# AMR_EUR_pval: 37 unique proteins with significant residues
# AMR_AFR_pval: 45 unique proteins with significant residues
# ASN_EUR_pval: 127 unique proteins with significant residues
# ASN_AFR_pval: 148 unique proteins with significant residues
# EUR_AFR_pval: 116 unique proteins with significant residues

# %% [markdown]
# Okay, I'm going to reproduce the original p-value plots, but I'm only going to plot one p-value per unique protein. To find my significant sphers, I have to plot the smallest p-value for each protein. This will bias my p-value distribution towards lower p-values, but the important question will not be the absolute p-values observed, but whether they flatten into a more uniform distribution.

# %%
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    tdf = df.loc[df.groupby('unp')[pop_pval].idxmin()]
    tdf[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Well, I did see the bias towards lower pvalues that I expected, but I didn't observe any flattening of the distribution. This time I'm going to group by both unp and seqid. In a perfect dataset, this would uniquely identify each residue in each protein, and only plot it once, regardless of how many times it appeared in structures. However, because alignment is not included in this query, residues may not necessarily match. Again, I'm going to use the lowest p-value for each residue, but it is more appropriate in this case, since I'm referring to a single amino acid in a protein, and asking what its most differentiated state was, across all structures.

# %%
# Plot the minimum p-value for each unique protein-residue combination, across all structures
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_pval].min().hist(bins=100,range=(0,1))
#     tdf[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Well...huh. Maybe I'll learn something from the odds ratios (priors as determined by Fisher Exact)
# It is less clear whether I should be looking at the minimum or maximum for this, since these are
# unordered sets, so I'll just look at one and then the other.

# %%
# Plot the maximum OR for each sphere in each population comparison
for pop_or in pop_ors:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_or].max().hist(bins=100,range=(0,10))
    plt.xlabel(pop_or)
    plt.ylabel('count')
    plt.show()

# %%
# Plot the minimum OR for each sphere in each population comparison
for pop_or in pop_ors:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_or].min().hist(bins=100,range=(0,10))
    plt.xlabel(pop_or)
    plt.ylabel('count')
    plt.show()

# %%
# How many duplicates am I even eliminating with this step?
"%d - %d => %d residues in %d proteins"%(len(df),len(df.groupby(['unp','seqid'])),len(df)-len(df.groupby(['unp','seqid'])),len(df.groupby('unp')))
# Out:
# '12542645 - 1125975 => 11416670 residues in 4400 proteins'

# %% [markdown]
# So I've evaluated 12,543,145 residues in solved structures,
# and I removed 1,126,458 as duplicates from homo-polymers, duplicate structures, etc,
# leaving me with 11,416,687 uniquely evaluated residues/spheres in 4,649 unique human proteins.
#
# It looks like I have a large bias for odds ratios of 0 and infinity, which corresponds to spheres containing no variation in one of the two populations. If the 0/N is in the same direction as the expected frequencies, then the OR is 0.0, if it is in the opposite, the OR is infinite.
#
# So far I'm not liking what I'm seeing, but let's move on to looking at a handful of our best-scoring spheres/proteins. I'll start by sorting the proteins by the number of significant spheres identified in that protein.

# %%
# Sort unique proteins by the number of significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').size()
    uniq.sort(ascending=False)
    print "%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
    print uniq.head(10)
# Out:
# AMR_ASN_pval: 99 unique proteins with significant residues
# unp
# P15151    5700
# Q07108     249
# P15289     230
# P47989     191
# Q8N539     160
# Q16853     152
# Q8N4E7     120
# O14732     114
# O75643      98
# P04629      97
# dtype: int64
# AMR_EUR_pval: 37 unique proteins with significant residues
# unp
# P02766    700
# P14174    140
# Q9UNA4     69
# P47989     53
# P02652     48
# P36222     37
# Q13231     36
# P05062     33
# O95684     28
# Q8NFE9     24
# dtype: int64
# AMR_AFR_pval: 45 unique proteins with significant residues
# unp
# O75473    314
# P43250    184
# P02768    166
# P53350    116
# P62805    114
# Q9UIK4     99
# Q2MKA7     91
# Q9NUI1     56
# Q86XE5     56
# P20933     50
# dtype: int64
# ASN_EUR_pval: 127 unique proteins with significant residues
# unp
# P15151    4140
# P02766    1258
# P08684     367
# Q9Y223     347
# P23381     201
# P34913     192
# Q13191     140
# Q6P2F0     126
# Q9UNA4     124
# P20702     105
# dtype: int64
# ASN_AFR_pval: 148 unique proteins with significant residues
# unp
# P15151    1920
# O15382     505
# P47989     426
# P62805     256
# Q07108     249
# P15289     238
# P34913     235
# Q16853     231
# Q8N539     192
# P20813     191
# dtype: int64
# EUR_AFR_pval: 116 unique proteins with significant residues
# unp
# P15151    1860
# P00749     785
# P02766     684
# O00625     427
# Q8TBC4     342
# Q13564     285
# P20813     284
# P13726     191
# P23381     179
# Q9BPX1     147
# dtype: int64

# %% [markdown]
# P15151 is a very interesting result. P15151 is the Poliovirus receptor (gene=PVR).
# Let's look closer

# %%
df[(df['unp'] == 'P15151') & np.any(df[pop_pvals]<0.05) & (df['chain']=='A')].sort('seqid')
# Out:
#          isvar  issnp         name  amr_af  asn_af  eur_af  afr_af structid  \
# 8022421      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022456      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022488      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8
# 8022263      0.236364       0.333333      0.575758
# 8022537      0.490909       0.555556           NaN
# 8022299      0.490909       0.555556           NaN
# 8022335      0.490909       0.000000      0.490909
# 8022273      0.236364       0.333333      0.575758
# 8022403      0.490909       0.000000      0.490909
# 8022436      0.490909       0.555556           NaN
# 8022470      0.490909       0.555556           NaN
# 8022505           NaN            NaN           NaN
# 8022539           NaN       7.000000      0.236364
# 8022301           NaN            NaN           NaN
# 8022337           NaN            NaN           NaN
# 8022373           NaN            NaN           NaN
# 8022405           NaN            NaN           NaN
# 8022438           NaN            NaN           NaN
# 8022472           NaN            NaN           NaN
# 8022507           NaN            NaN           NaN
# 8022541           NaN            NaN           NaN
#
# [317 rows x 26 columns]

# %% [markdown]
# Okay, this is still a very interesting result, but its clear that the variant count is being inflated by 1DGI and 1NN8, enormous multi-chain structures of poliovirus bound to the polioreceptor. This may be an incredibly interesting structure to study, but for our general list asking the question "which proteins have the largest number of significant spheres?", I need to limit that to non-redundant residues.

# %%
# Sort unique proteins by the number of *unique* significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').seqid.nunique()
    uniq.sort(ascending=False)
    print "\n%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
    for i,p in enumerate(uniq.index):
        print "%s\t%d\tuniprot.org/uniprot/%s"%(p,uniq[i],p)
# Out:
# AMR_ASN_pval: 99 unique proteins with significant residues
# P15151	51	uniprot.org/uniprot/P15151
# P10912	38	uniprot.org/uniprot/P10912
# Q07108	31	uniprot.org/uniprot/Q07108
# O75643	27	uniprot.org/uniprot/O75643
# P47989	21	uniprot.org/uniprot/P47989
# P08069	17	uniprot.org/uniprot/P08069
# Q01974	17	uniprot.org/uniprot/Q01974
# P23946	16	uniprot.org/uniprot/P23946
# P21399	15	uniprot.org/uniprot/P21399
# Q13231	15	uniprot.org/uniprot/Q13231
# P30533	14	uniprot.org/uniprot/P30533
# P43246	14	uniprot.org/uniprot/P43246
# P52292	13	uniprot.org/uniprot/P52292
# Q16647	13	uniprot.org/uniprot/Q16647
# P15289	12	uniprot.org/uniprot/P15289
# P29016	12	uniprot.org/uniprot/P29016
# P09871	12	uniprot.org/uniprot/P09871
# Q96F46	11	uniprot.org/uniprot/Q96F46
# P06731	11	uniprot.org/uniprot/P06731
# P04629	10	uniprot.org/uniprot/P04629
# Q8N539	10	uniprot.org/uniprot/Q8N539
# O43157	10	uniprot.org/uniprot/O43157
# O14732	10	uniprot.org/uniprot/O14732
# Q13426	10	uniprot.org/uniprot/Q13426
# P08684	10	uniprot.org/uniprot/P08684
# P78560	9	uniprot.org/uniprot/P78560
# Q16853	8	uniprot.org/uniprot/Q16853
# P09917	8	uniprot.org/uniprot/P09917
# Q86XE5	7	uniprot.org/uniprot/Q86XE5
# Q9NRW3	7	uniprot.org/uniprot/Q9NRW3
# P07998	7	uniprot.org/uniprot/P07998
# Q6PIW4	6	uniprot.org/uniprot/Q6PIW4
# P11226	6	uniprot.org/uniprot/P11226
# Q8IV48	6	uniprot.org/uniprot/Q8IV48
# P29401	6	uniprot.org/uniprot/P29401
# P07858	6	uniprot.org/uniprot/P07858
# Q9Y2C4	5	uniprot.org/uniprot/Q9Y2C4
# P05062	5	uniprot.org/uniprot/P05062
# P27694	5	uniprot.org/uniprot/P27694
# P24855	5	uniprot.org/uniprot/P24855
# P01011	5	uniprot.org/uniprot/P01011
# Q9UBD6	5	uniprot.org/uniprot/Q9UBD6
# Q8WVQ1	5	uniprot.org/uniprot/Q8WVQ1
# Q8N149	5	uniprot.org/uniprot/Q8N149
# P08648	5	uniprot.org/uniprot/P08648
# P22033	4	uniprot.org/uniprot/P22033
# Q5S007	4	uniprot.org/uniprot/Q5S007
# P52895	4	uniprot.org/uniprot/P52895
# O00411	4	uniprot.org/uniprot/O00411
# Q9UNA4	4	uniprot.org/uniprot/Q9UNA4
# P49450	4	uniprot.org/uniprot/P49450
# P33261	3	uniprot.org/uniprot/P33261
# P20813	3	uniprot.org/uniprot/P20813
# P19652	3	uniprot.org/uniprot/P19652
# P06732	3	uniprot.org/uniprot/P06732
# P49862	3	uniprot.org/uniprot/P49862
# Q96AY2	3	uniprot.org/uniprot/Q96AY2
# P35613	3	uniprot.org/uniprot/P35613
# P43235	3	uniprot.org/uniprot/P43235
# P49327	3	uniprot.org/uniprot/P49327
# Q8N4E7	3	uniprot.org/uniprot/Q8N4E7
# P50542	3	uniprot.org/uniprot/P50542
# Q7L576	3	uniprot.org/uniprot/Q7L576
# Q495A1	3	uniprot.org/uniprot/Q495A1
# Q9BUT1	3	uniprot.org/uniprot/Q9BUT1
# Q05315	2	uniprot.org/uniprot/Q05315
# Q8NEU8	2	uniprot.org/uniprot/Q8NEU8
# Q96CA5	2	uniprot.org/uniprot/Q96CA5
# P34913	2	uniprot.org/uniprot/P34913
# P02768	2	uniprot.org/uniprot/P02768
# P15085	2	uniprot.org/uniprot/P15085
# Q9BZM4	2	uniprot.org/uniprot/Q9BZM4
# P00747	2	uniprot.org/uniprot/P00747
# P16444	2	uniprot.org/uniprot/P16444
# P81605	2	uniprot.org/uniprot/P81605
# P68431	2	uniprot.org/uniprot/P68431
# Q9NRG1	2	uniprot.org/uniprot/Q9NRG1
# P22748	2	uniprot.org/uniprot/P22748
# P50226	2	uniprot.org/uniprot/P50226
# P50135	2	uniprot.org/uniprot/P50135
# Q9UHD2	2	uniprot.org/uniprot/Q9UHD2
# P07101	1	uniprot.org/uniprot/P07101
# Q9H211	1	uniprot.org/uniprot/Q9H211
# Q96RS0	1	uniprot.org/uniprot/Q96RS0
# Q9NUI1	1	uniprot.org/uniprot/Q9NUI1
# P34931	1	uniprot.org/uniprot/P34931
# Q13232	1	uniprot.org/uniprot/Q13232
# Q92731	1	uniprot.org/uniprot/Q92731
# Q86YC2	1	uniprot.org/uniprot/Q86YC2
# Q6PI48	1	uniprot.org/uniprot/Q6PI48
# Q15399	1	uniprot.org/uniprot/Q15399
# P14778	1	uniprot.org/uniprot/P14778
# Q12913	1	uniprot.org/uniprot/Q12913
# Q13546	15	uniprot.org/uniprot/Q13546
# P09871	14	uniprot.org/uniprot/P09871
# P62805	14	uniprot.org/uniprot/P62805
# Q86SE8	14	uniprot.org/uniprot/Q86SE8
# Q9UBD6	13	uniprot.org/uniprot/Q9UBD6
# P40926	13	uniprot.org/uniprot/P40926
# Q13614	13	uniprot.org/uniprot/Q13614
# P20702	12	uniprot.org/uniprot/P20702
# O60462	12	uniprot.org/uniprot/O60462
# Q8N539	12	uniprot.org/uniprot/Q8N539
# P08684	12	uniprot.org/uniprot/P08684
# Q8N371	11	uniprot.org/uniprot/Q8N371
# Q59GY8	11	uniprot.org/uniprot/Q59GY8
# Q16853	10	uniprot.org/uniprot/Q16853
# P49917	10	uniprot.org/uniprot/P49917
# Q92731	10	uniprot.org/uniprot/Q92731
# Q6S383	10	uniprot.org/uniprot/Q6S383
# Q16695	9	uniprot.org/uniprot/Q16695
# P48551	9	uniprot.org/uniprot/P48551
# Q14393	9	uniprot.org/uniprot/Q14393
# Q14397	8	uniprot.org/uniprot/Q14397
# P11245	8	uniprot.org/uniprot/P11245
# P22234	7	uniprot.org/uniprot/P22234
# P06276	7	uniprot.org/uniprot/P06276
# Q9UN36	7	uniprot.org/uniprot/Q9UN36
# P53992	7	uniprot.org/uniprot/P53992
# P07998	7	uniprot.org/uniprot/P07998
# P68431	7	uniprot.org/uniprot/P68431
# Q9Y4F1	7	uniprot.org/uniprot/Q9Y4F1
# O43157	6	uniprot.org/uniprot/O43157
# O60760	6	uniprot.org/uniprot/O60760
# P07332	6	uniprot.org/uniprot/P07332
# P42126	6	uniprot.org/uniprot/P42126
# Q9UBR2	6	uniprot.org/uniprot/Q9UBR2
# Q9P0N9	6	uniprot.org/uniprot/Q9P0N9
# P51124	5	uniprot.org/uniprot/P51124
# Q9BV20	5	uniprot.org/uniprot/Q9BV20
# Q14849	5	uniprot.org/uniprot/Q14849
# P29972	5	uniprot.org/uniprot/P29972
# P40692	5	uniprot.org/uniprot/P40692
# P54132	4	uniprot.org/uniprot/P54132
# P05154	4	uniprot.org/uniprot/P05154
# O60494	4	uniprot.org/uniprot/O60494
# Q8NBP7	4	uniprot.org/uniprot/Q8NBP7
# Q13231	4	uniprot.org/uniprot/Q13231
# Q86SR1	4	uniprot.org/uniprot/Q86SR1
# P30038	4	uniprot.org/uniprot/P30038
# Q5S007	4	uniprot.org/uniprot/Q5S007
# O75636	4	uniprot.org/uniprot/O75636
# P27694	3	uniprot.org/uniprot/P27694
# Q9HC38	3	uniprot.org/uniprot/Q9HC38
# Q5VZV1	3	uniprot.org/uniprot/Q5VZV1
# P11172	3	uniprot.org/uniprot/P11172
# P09601	3	uniprot.org/uniprot/P09601
# P36955	3	uniprot.org/uniprot/P36955
# Q15485	3	uniprot.org/uniprot/Q15485
# P51161	3	uniprot.org/uniprot/P51161
# P06899	3	uniprot.org/uniprot/P06899
# Q10589	3	uniprot.org/uniprot/Q10589
# P06732	3	uniprot.org/uniprot/P06732
# P50226	3	uniprot.org/uniprot/P50226
# P17948	3	uniprot.org/uniprot/P17948
# P06731	1	uniprot.org/uniprot/P06731
# Q99638	1	uniprot.org/uniprot/Q99638
# P06132	1	uniprot.org/uniprot/P06132
# O00411	1	uniprot.org/uniprot/O00411
#
# EUR_AFR_pval: 116 unique proteins with significant residues
# Q8TBC4	60	uniprot.org/uniprot/Q8TBC4
# O00625	55	uniprot.org/uniprot/O00625
# P20813	38	uniprot.org/uniprot/P20813
# Q59FQ1	32	uniprot.org/uniprot/Q59FQ1
# P01130	32	uniprot.org/uniprot/P01130
# O00294	28	uniprot.org/uniprot/O00294
# Q13564	26	uniprot.org/uniprot/Q13564
# P23381	25	uniprot.org/uniprot/P23381
# P08581	24	uniprot.org/uniprot/P08581
# P15151	23	uniprot.org/uniprot/P15151
# P50542	23	uniprot.org/uniprot/P50542
# P00749	21	uniprot.org/uniprot/P00749
# P07093	20	uniprot.org/uniprot/P07093
# P13726	20	uniprot.org/uniprot/P13726
# Q9Y600	19	uniprot.org/uniprot/Q9Y600
# P21695	18	uniprot.org/uniprot/P21695
# O00204	17	uniprot.org/uniprot/O00204
# P04629	17	uniprot.org/uniprot/P04629
# Q16773	15	uniprot.org/uniprot/Q16773
# P19793	14	uniprot.org/uniprot/P19793
# Q5SWW9	14	uniprot.org/uniprot/Q5SWW9
# Q9HC38	14	uniprot.org/uniprot/Q9HC38
# Q53XS3	13	uniprot.org/uniprot/Q53XS3
# Q9BPX1	11	uniprot.org/uniprot/Q9BPX1
# Q86SZ2	11	uniprot.org/uniprot/Q86SZ2
# O00602	11	uniprot.org/uniprot/O00602
# Q16647	11	uniprot.org/uniprot/Q16647
# Q86SE8	10	uniprot.org/uniprot/Q86SE8
# P13671	10	uniprot.org/uniprot/P13671
# P19801	9	uniprot.org/uniprot/P19801
# P18858	8	uniprot.org/uniprot/P18858
# P14618	8	uniprot.org/uniprot/P14618
# P25054	8	uniprot.org/uniprot/P25054
# O95684	8	uniprot.org/uniprot/O95684
# P62805	7	uniprot.org/uniprot/P62805
# P08709	7	uniprot.org/uniprot/P08709
# Q09013	7	uniprot.org/uniprot/Q09013
# Q6UWP2	7	uniprot.org/uniprot/Q6UWP2
# P24855	7	uniprot.org/uniprot/P24855
# Q7L5Y1	7	uniprot.org/uniprot/Q7L5Y1
# Q5SRE7	6	uniprot.org/uniprot/Q5SRE7
# Q02790	6	uniprot.org/uniprot/Q02790
# P02652	6	uniprot.org/uniprot/P02652
# Q7Z623	6	uniprot.org/uniprot/Q7Z623
# P53602	6	uniprot.org/uniprot/P53602
# O75369	6	uniprot.org/uniprot/O75369
# Q96E14	6	uniprot.org/uniprot/Q96E14
# P38935	6	uniprot.org/uniprot/P38935
# Q9Y4F1	6	uniprot.org/uniprot/Q9Y4F1
# O43704	6	uniprot.org/uniprot/O43704
# P27708	5	uniprot.org/uniprot/P27708
# Q13835	5	uniprot.org/uniprot/Q13835
# P14410	5	uniprot.org/uniprot/P14410
# P03956	5	uniprot.org/uniprot/P03956
# Q9H9A7	5	uniprot.org/uniprot/Q9H9A7
# P55809	4	uniprot.org/uniprot/P55809
# %%
# Now, let's do the same, but sorted by structid instead of protein
# Sort unique proteins by the number of *unique* significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('structid').seqid.nunique()
    uniq.sort(ascending=False)
    print "\n%s: %d unique structures with significant residues"%(pop_pval,len(uniq))
    for i,p in enumerate(uniq.index):
        print "%s\t%d"%(p,uniq[i])
# Out:
# AMR_ASN_pval: 243 unique structures with significant residues
# 1NN8	51
# 3CCK	31
# 3HUP	31
# 1E8I	30
# 1E87	30
# 4F91	26
# 4F92	25
# 4F93	24
# 4KIT	23
# 1A22	21
# 2E1Q	20
# 2CKJ	18
# 1AXI	17
# 1IGR	17
# 1LG2	15
# 3ZZW	15
# 2B3X	15
# 2B3Y	15
# 4GT4	14
# 3THZ	14
# 3THX	14
# 2P03	13
# 2IAG	13
# 3B6H	13
# 3THW	13
# 4E4V	13
# 1HKK	12
# 1LQ0	12
# 4J1Y	12
# 1GZQ	12
# 1E2S	12
# 1E1Z	12
# 3THY	12
# 1N2L	12
# 1N2K	12
# 1E33	12
# 1AUK	11
# 4HSA	11
# 1UQS	11
# 1E3C	11
# 4M7H	10
# 3II6	10
# 3OL2	10
# 2QST	10
# 4M7F	10
# 2J0D	9
# 2DDK	9
# 1GZP	9
# 2CZH	9
# 2OF5	9
# 4AOJ	9
# 2CZI	9
# 2CZK	9
# 3T8X	9
# 3TJS	8
# 2FVZ	8
# 3ALA	8
# 3V92	8
# 2P01	8
# 2QSQ	8
# 2E0O	7
# 3S5O	7
# 3S5N	7
# 3V98	7
# 3V99	7
# 3D8B	6
# 3MOS	6
# 3VM8	6
# 3VOW	6
# 1ZBH	6
# 1HUP	6
# 2VER	6
# 4AG1	5
# 3HD6	5
# 1XDM	5
# 4K5Z	5
# 4K60	5
# 4KP0	5
# 2OTP	5
# 3CBK	5
# 3CBJ	5
# 4KXV	5
# 3AI8	5
# 2IPP	5
# 2HVX	5
# 2H2N	5
# 3O8Y	5
# 4KXX	5
# 3N7O	5
# 4AG2	5
# 1NN6	5
# 4A1N	5
# 1FGU	5
# 1PJP	5
# 3S0N	5
# 3VI3	5
# 1KLT	5
# 4AWN	5
# 1HUC	5
# 3VI4	5
# 4AFU	5
# 3OOY	5
# 4AFZ	5
# 4AFS	5
# 4AFQ	4
# 4BTY	4
# 3BIC	4
# 4KXW	4
# 2Y73	4
# 4EBC	4
# 4BTW	4
# 4BTX	4
# 4BOC	4
# 2Y74	4
# 2H2U	4
# 2HDJ	4
# 4EBD	4
# 4KXY	4
# 3R45	4
# 1CSB	4
# 1GMY	4
# 3G6X	4
# 1T31	4
# 4FS2	4
# 1PU4	4
# 3H4D	4
# 3H4B	4
# 1US1	4
# 3GV8	4
# 3GV7	4
# 3Q8P	4
# 3G6Y	4
# 3G6V	4
# 3Q8Q	4
# 3Q8R	4
# 3Q8S	4
# 2C10	4
# 2C11	4
# 3D6T	4
# 4KXU	4
# 1TU6	3
# 2ACH	3
# 2AG5	3
# 1I0E	3
# 1AS4	3
# 1R03	3
# 1FCH	3
# 4N78	3
# 3QU8	3
# 2ZIX	3
# 3CAA	3
# 3UCR	3
# 4GQS	3
# 3OSN	3
# 3NGD	3
# 4EYH	3
# 3P8C	3
# 3HHD	3
# 3H40	3
# 2AOV	2
# 2AOW	2
# 2AOU	2
# 2AOT	2
# 3F7G	2
# 3F7B	2
# 3FJU	2
# 3DLW	2
# 1ITQ	2
# 1ITU	2
# 4CAA	2
# 1KCG	2
# 4EBE	2
# 2AOX	2
# 1QMN	2
# 1JQD	2
# 3QR2	2
# 2XIJ	2
# 2V77	2
# 4IW0	2
# 4HGM	2
# 2QXG	2
# 2XIQ	2
# 4HGK	2
# 2YMK	2
# 4H8S	2
# 1KI0	2
# 1E07	2
# 2JBH	2
# 1LCL	2
# 3APU	2
# 3APW	2
# 4FS1	2
# 1Z29	2
# 1L2J	1
# 3W98	1
# 2WVR	1
# 3W99	1
# 3WA9	1
# 3WAA	1
# 3WKJ	1
# 4DEP	1
# 4EYI	1
# 1F6O	1
# 4FC7	1
# 4FXO	1
# 4GT5	1
# 4GTU	1
# 1BNK	1
# 4AH6	1
# 3GDQ	1
# 3TK0	1
# 3AZG	1
# 2QXI	1
# 2QXH	1
# 2XSN	1
# 2Z7X	1
# 3AFA	1
# 2NZ6	1
# 3ANS	1
# 3ANT	1
# 3APV	1
# 2HE3	1
# 3APX	1
# 3AYW	1
# 3AZE	1
# 3AZF	1
# 3AZH	1
# 3QQN	1
# 3AZK	1
# 3AZL	1
# 2CV5	1
# 3EGI	1
# 3EU7	1
# 3F7U	1
# 1ZS6	1
# 1ZNC	1
# 3FW3	1
# 2W18	1
# 1SZB	1
# 3PDC	1
# 3QI5	1
# 3QNW	1
# 3BSQ	1
#
# AMR_EUR_pval: 291 unique structures with significant residues
# 1LG2	13
# 1LQ0	12
# 1HKK	11
# 1S4B	9
# 3OBZ	8
# 2RE9	8
# 2OPW	8
# 2OU1	8
# 2O36	7
# 3HD6	7
# 2D68	6
# 2E1Q	6
# 4GT4	6
# 1HUP	4
# 3A6N	4
# 3R45	4
# 3S84	4
# 2CKJ	4
# 4EYI	3
# 4EBE	3
# 3GV5	3
# 4EYH	3
# 3GV7	3
# 3H40	3
# 3WAA	3
# 4FS2	3
# 4FS1	3
# 4EBC	3
# 4EBD	3
# 3GV8	3
# 3Q8S	3
# 2OTP	3
# 3Q8R	3
# 3Q8Q	3
# 3NGD	3
# 3OSN	3
# 2B3Y	3
# 2B3X	3
# 3Q8P	3
# 4LDR	3
# 4LDQ	3
# 3H4B	3
# 3G6V	3
# 3G6X	3
# 3G6Y	3
# 3H4D	3
# 1HJW	3
# 1SZB	2
# 1SG4	2
# 1Z7J	2
# 1Y1D	2
# 3LPP	2
# 1USD	2
# 1QO5	2
# 1NWT	2
# 1NWS	2
# 1NWR	2
# 1LCY	2
# 4H1J	2
# 1NWU	2
# 3CC6	2
# 2G3Z	1
# 3CFQ	1
# 3CBR	1
# 2NOY	1
# 3GS0	1
# 3GRG	1
# 3GRB	1
# 3GPS	1
# 3GLZ	1
# 3FCB	1
# 3FC8	1
# 4P0H	1
# 3ESO	1
# 3ESN	1
# 3DO4	1
# 3DK2	1
# 3DK0	1
# 3DJZ	1
# 3DJT	1
# 3DJS	1
# 3DJR	1
# 3DJI	1
# 3DJH	1
# 3DID	1
# 3DGD	1
# 3D7P	1
# 3IJJ	1
# 3IMR	1
# 3IMS	1
# 3L5T	1
# 3P3T	1
# 3P3S	1
# 3P3R	1
# 3OZK	1
# 3NG5	1
# 3NEX	1
# 3NES	1
# 3NEO	1
# 3NEE	1
# 3M1O	1
# 3LPO	1
# 3L5V	1
# 3L5U	1
# 3L5S	1
# 3IMT	1
# 3L5R	1
# 3L5P	1
# 3KGU	1
# 3KGT	1
# 3KGS	1
# 3JTU	1
# 3JSG	1
# 3JSF	1
# 3IPE	1
# 3IPB	1
# 3IMW	1
# 3IMV	1
# 3IMU	1
# 1BM7	1
#
# AMR_AFR_pval: 178 unique structures with significant residues
# 1WMK	33
# 2CKE	32
# 1Z9X	31
# 4BSS	30
# 4KNG	29
# 4BST	29
# 4BSR	28
# 4BSU	27
# 3NYN	22
# 3NYO	21
# 2IAG	12
# 1APZ	12
# 1APY	12
# 4KGH	12
# 3B6H	11
# 3HD6	11
# 2FV7	10
# 4FC7	7
# 3QU8	7
# 3S5N	7
# 4FC6	7
# 3S5O	7
# 3FVH	6
# 2JIS	6
# 4HAB	6
# 2OU1	6
# 2HI4	6
# 3P2W	6
# 4H6Y	5
# 3W98	5
# 3Q1I	4
# 3AZN	4
# 3FVS	4
# 3AZM	4
# 3P36	4
# 3FVU	4
# 3FVX	4
# 3W96	4
# 3AZK	4
# 3AZJ	4
# 3WAA	4
# 3LFV	4
# 3MF0	4
# 3HIH	4
# 4DFW	4
# 4H71	4
# 1UMW	4
# 1W7M	4
# 4K71	4
# 4HCO	4
# 4HY2	4
# 3HIK	4
# 3AZG	4
# 3AZL	3
# 2BXM	3
# 1FCH	3
# 1HUW	3
# 1N5U	3
# 3AZI	3
# 1W7L	3
# 2B3X	3
# 2B3Y	3
# 2BXN	3
# 2XSN	3
# 3AZE	3
# 2BXO	3
# 2BXP	3
# 3AZH	3
# 3A73	3
# 3B9M	3
# 4N0F	3
# 2OTP	3
# 2XVW	3
# 4N0U	3
# 1AO6	3
# 3TDL	3
# 4HGK	3
# 4G04	3
# 4EMX	3
# 4E9D	3
# 4E9C	3
# 4L8U	3
# 4BKE	3
# 3WKJ	3
# 4LA0	3
# 3UIV	3
# 3WA9	3
# 4H5X	3
# 4MLU	3
# 4LB9	3
# 3SQJ	3
# 3P37	3
# 3P35	3
# 3P34	3
# 4L1J	2
# 4LKM	2
# 4HGM	2
# 4IW0	2
# 2ESG	2
# 2BXK	2
# 1E7A	2
# 2BXI	2
# 1E7H	2
# 1P4R	2
# 4L7E	2
# 1PKX	2
# 1XDM	2
# 1W7N	2
# 4L9Q	2
# 2NLB	2
# 4LKL	2
# 1Q4K	2
# 4LB2	2
# 1PL0	2
# 4L7W	2
# 2BXQ	2
# 3AZF	2
# 3AFA	2
# 3CX9	2
# 3C5L	2
# 3BZI	2
# 3B9L	2
# 3W97	2
# 3W99	2
# 3AYW	2
# 4E67	2
# 4DMB	2
# 3T6A	1
# 1HA2	1
# 3SR2	1
# 1IJU	1
# 1HK4	1
# 1HGU	1
# 1H9Z	1
# 1GNI	1
# 1E7I	1
# 3GTU	1
# 1E7F	1
# 1E7E	1
# 1E7B	1
# 3GXM	1
# 1E78	1
# 1BM0	1
# 1BKE	1
# 1BJ5	1
# 3LU7	1
# 3LAR	1
# 1UOR	1
# 2NLC	1
# 4L9K	1
# 4KF6	1
# 2NLH	1
# 2I30	1
# 2I2Z	1
# 4G03	1
# 2VRE	1
# 2WFD	1
# 2CV5	1
# 4IW2	1
# 3KS9	1
# 4J6G	1
# 4K2C	1
# 4KBS	1
# 2BXL	1
# 2NLG	1
# 2XSI	1
# 2XVV	1
# 2BXH	1
# 2BXG	1
# 2BXF	1
# 2BXD	1
# 2BXC	1
# 2BXB	1
# 2BX8	1
# 3AV1	1
# 3AV2	1
# 1Y7V	1
# 3JRY	1
#
# ASN_EUR_pval: 514 unique structures with significant residues
# 3ZNI	51
# 1NN8	39
# 3EO3	36
# 2YI1	35
# 2J0D	35
# 2YHY	35
# 2YHW	34
# 3TJS	27
# 1ZBH	24
# 3DLX	23
# 4BN2	23
# 2I6T	22
# 1ROA	20
# 1RN7	20
# 3DL2	19
# 2PLA	18
# 4HSA	16
# 4F92	14
# 4F91	14
# 1S31	14
# 1XVP	14
# 1LG2	14
# 4FFX	13
# 4I4G	13
# 3K6S	13
# 1LQ0	13
# 2OPW	13
# 4F93	12
# 3OBZ	12
# 3MOP	12
# 3K72	12
# 3K71	12
# 4KIT	11
# 4FLC	11
# 2DR2	11
# 2QQO	11
# 2H7C	11
# 4I4H	11
# 2AKE	11
# 2ANW	10
# 1W6U	10
# 1A22	10
# 2V0M	10
# 4JOB	10
# 4JOC	10
# 4K9U	10
# 4JOD	10
# 2AZX	10
# 4J1Y	10
# 2ANY	9
# 1MX5	9
# 1ULH	9
# 4K9W	9
# 1MX1	9
# 3NXU	9
# 1HKK	9
# 2QUH	9
# 1AXI	9
# 2QUJ	9
# 3KVQ	9
# 3VZD	9
# 1MX9	8
# 2QUI	8
# 1R6U	8
# 2QQL	8
# 2PZF	8
# 2QUK	8
# 1O5T	8
# 3EH2	8
# 1T5A	8
# 4K9X	8
# 1W8D	8
# 3OL2	8
# 3ALA	8
# 2HRQ	8
# 3LRE	8
# 4K9T	8
# 2H31	7
# 4K81	7
# 2BP1	7
# 1XG5	7
# 3LLI	7
# 3LLK	7
# 1W73	7
# 1LMW	6
# 2J9Q	6
# 2BUB	6
# 4CFE	6
# 4AFZ	6
# 2QYF	6
# 1I0E	6
# 4L72	6
# 4LQY	6
# 4LR2	6
# 4NRE	5
# 2DQY	5
# 3G0C	5
# 3G0D	5
# 4G1F	5
# 3G0G	5
# 1T3N	5
# 4I3Q	5
# 2D68	5
# 3F8S	5
# 4AFU	5
# 1JMC	5
# 3II6	5
# 4CNC	5
# 2QJR	5
# 3HD6	5
# 4FS2	4
# 3OTQ	4
# 4KP0	4
# 3Q8S	4
# 3Q8R	4
# 3Q8Q	4
# 3Q8P	4
# 3PB6	4
# 3PB9	4
# 2DR0	4
# 1W0F	4
# 3PB8	4
# 3PB4	4
# 3PB7	4
# 1ZD2	4
# 1Y1D	4
# 4HAI	4
# 3KOO	4
# 1ZD5	4
# 1ZD4	4
# 1ZD3	4
# 3I28	4
# 3I1Y	4
# 1EBA	4
# 3H4D	4
# 3H4B	4
# 3GV8	4
# 2DPJ	4
# 3GV7	4
# 4K9V	4
# 3G6Y	4
# 3G6X	4
# 3G6V	4
# 1VSC	4
# 2DPI	4
# 1HYN	4
# 3QWL	4
# 4J03	4
# 3WKA	4
# 3WKD	4
# 3WK6	4
# 3WK7	4
# 3WK8	4
# 3WK9	4
# 1VJ5	4
# 3WKB	4
# 3WKC	4
# 3WKE	4
# 1S8O	4
# 4FC7	4
# 4FC6	4
# 4EBC	4
# 3A6N	4
# 4EBD	4
# 1IYH	4
# 1IYI	4
# 3WK5	4
# 3WK4	4
# 3D6T	4
# 1IDN	4
# 2ALZ	4
# 4CFF	4
# 3VI7	4
# 3VI5	4
# 2H2U	4
# 1BHQ	4
# 1TQN	4
# 3UA1	4
# 2HRR	4
# 1BHO	4
# 2FLL	4
# 1V40	4
# 4CNM	4
# 2XAC	3
# 3HHD	3
# 1AGN	3
# 4MWT	3
# 4MWS	3
# 4KXU	3
# 3H40	3
# 2Y73	3
# 2C10	3
# 2J6L	3
# 4KXY	3
# 2DQZ	3
# 2H2N	3
# 2FLN	3
# 4KXX	3
# 4KXW	3
# 4KXV	3
# 1W0E	3
# 1G1O	3
# 4AZ0	3
# 3OSN	3
# 3QR2	3
# 3NGD	3
# 3SC0	3
# 4EYH	3
# 1FQY	3
# 1US1	3
# 1W0G	3
# 1PU4	3
# 1Z7J	3
# 1FGU	3
# 1IH5	3
# 1IMV	3
# 4CIB	3
# 4CIA	3
# 4CI9	3
# 1KLT	3
# 3JVF	3
# 1IIK	2
# 1DVT	2
# 2J91	2
# 1IJN	2
# 2H4E	2
# 1SOQ	2
# 1DVU	2
# 2H11	2
# 1SOK	2
# 1DVX	2
# 1DVY	2
# 1THC	2
# 1III	2
# 1TT6	2
# 1E4H	2
# 1DVS	2
# 2QGB	2
# 1BM7	2
# 1LHN	2
# 1BMZ	2
# 1KDK	2
# 2QGE	2
# 2QGD	2
# 2QGC	2
# 1D1S	2
# 2NOY	2
# 1D1T	2
# 1QWH	2
# 2QEL	2
# 1D2S	2
# 2PAB	2
# 2G9K	2
# 1DVQ	2
# 2GAB	2
# 2G3X	2
# 1TTR	2
# 1YAH	2
# 2C11	2
# 1FHN	2
# 2BZG	2
# 1FH2	2
# 1DVZ	2
# 2B9A	2
# 1Z83	2
# 1F86	2
# 1ZCR	2
# 1F41	2
# 1ETB	2
# 2B16	2
# 2B15	2
# 1LHO	2
# 2B14	2
# 1E3F	2
# 1ZD6	2
# 1YAJ	2
# 1YA8	2
# 2G5U	2
# 1YA4	2
# 2G4G	2
# 2G4E	2
# 2G3Z	2
# 1E5A	2
# 2FLP	2
# 2FLM	2
# 1TZ8	2
# 1U21	2
# 2FBR	2
# 2F8I	2
# 2ROX	2
# 2F7I	2
# 2E1Q	2
# 1ICT	2
# 1X7S	2
# 1X7T	2
# 1HJV	2
# 1LHU	2
# 5TTR	2
# 2ROY	2
# 3NG5	2
# 3OZK	2
# 3P3R	2
# 3P3S	2
# 3P3T	2
# 3P3U	2
# 3S84	2
# 3SBY	2
# 3SSG	2
# 2VCQ	2
# 3TCT	2
# 3TFB	2
# 3U2I	2
# 3U2J	2
# 3W3B	2
# 4AB1	2
# 3O4O	2
# 3NEX	2
# 4BTX	2
# 3NES	2
# 3IMS	2
# 3IMT	2
# 3IMU	2
# 3IMV	2
# 3IMW	2
# 3IPB	2
# 3IPE	2
# 3K1R	2
# 3KGS	2
# 3KGT	2
# 3KGU	2
# 3KXO	2
# 3M1O	2
# 3NEE	2
# 3NEO	2
# 4BTW	2
# 4BTY	2
# 3I9P	2
# 4I89	2
# 4IK6	2
# 4IK7	2
# 4IKI	2
# 4IKJ	2
# 4IKK	2
# 4IKL	2
# 4KY2	2
# 4L1S	2
# 4L1T	2
# 4MAS	2
# 4MRB	2
# 4MRC	2
# 4N85	2
# 4N86	2
# 4N87	2
# 4IIZ	2
# 4HJU	2
# 4DER	2
# 4HJT	2
# 4DES	2
# 4DET	2
# 4DEU	2
# 4DEW	2
# 4EBE	2
# 4EC0	2
# 4EDY	2
# 4EDZ	2
# 4FI6	2
# 4FI7	2
# 4FI8	2
# 4FS1	2
# 4HIQ	2
# 4HIS	2
# 4HJS	2
# 3IMR	2
# 3T30	2
# 3I9I	2
# 3CC6	2
# 3DJR	2
# 3DID	2
# 3DGD	2
# 3D7P	2
# 3D2T	2
# 3CXF	2
# 3CN2	2
# 3CN1	2
# 3CN0	2
# 3CFT	2
# 3CFQ	2
# 3CFN	2
# 3CFM	2
# 3CBR	2
# 3DJT	2
# 3BT0	2
# 3B56	2
# 3A4F	2
# 3A4E	2
# 3A4D	2
# 2Z65	2
# 2Z62	2
# 2YMK	2
# 2Y7Q	2
# 2Y74	2
# 2W18	2
# 2VER	2
# 2VD0	2
# 3DJS	2
# 3CN3	2
# 3DJZ	2
# 3ESN	2
# 3HJ0	2
# 3GS7	2
# 3GS4	2
# 3GS0	2
# 3GRG	2
# 3GRB	2
# 3GPS	2
# 3GLZ	2
# 3FCB	2
# 3FC8	2
# 3EU7	2
# 3ESP	2
# 3CN4	2
# 3DK0	2
# 3DK2	2
# 3DO4	2
# 3VM8	1
# 4I87	1
# 3S0N	1
# 1EGC	1
# 1EGE	1
# 2Q7D	1
# 2POM	1
# 2PD6	1
# 4I85	1
# 3UL7	1
# 2Z7X	1
# 1HDX	1
# 1HDY	1
# 1HDZ	1
# 2CKJ	1
# 2CVD	1
# 1HSO	1
# 1HSZ	1
# 1HTB	1
# 1U3T	1
# 4K5Z	1
# 1E3C	1
# 1E33	1
# 4NEN	1
# 4NEH	1
# 2VCW	1
# 2VCX	1
# 2VCZ	1
# 2QST	1
# 1U3V	1
# 2VD1	1
# 4LL9	1
# 1DEH	1
# 4LAY	1
# 4LAX	1
# 4LAV	1
# 2VD6	1
# 2B77	1
# 1U3U	1
# 4K60	1
# 1E1Z	1
# 1E2S	1
# 2JJU	1
# 4H1J	1
# 3VOW	1
# 1R3R	1
# 1N2L	1
# 1NN6	1
# 4AG2	1
# 4AG1	1
# 1PJP	1
# 4AFS	1
# 1Q1C	1
# 4AFQ	1
# 1R3Q	1
# 1R3S	1
# 2D9C	1
# 1R3T	1
# 1R3V	1
# 1R3W	1
# 1R3Y	1
# 3EPG	1
# 4A27	1
# 3ZZW	1
# 3ZJB	1
# 3EE2	1
# 1N2K	1
# 3HUD	1
# 3EPI	1
# 3OOY	1
# 3UL8	1
# 2J4O	1
# 3N7O	1
# 4F52	1
# 4EYI	1
# 3T6P	1
# 2IDX	1
# 2IBN	1
# 1THA	1
# 2HVX	1
# 1L2J	1
# 4DGJ	1
# 3UL9	1
# 3V2B	1
# 3ESO	1
# 1LHV	1
# 1LHW	1
# 1T31	1
# 2E0O	1
# 4EE0	1
#
# ASN_AFR_pval: 423 unique structures with significant residues
# 2CKJ	48
# 2HGX	46
# 2E1Q	46
# 2HGW	46
# 1KTA	44
# 2HG8	43
# 2HDK	43
# 2HHF	43
# 1KT8	43
# 4BN2	39
# 2NLK	35
# 3HUP	31
# 3CCK	31
# 1E87	30
# 1E8I	30
# 2XWU	28
# 3ZJY	28
# 4GNK	27
# 2X19	25
# 3OHM	25
# 1NN8	24
# 1F45	23
# 2A1H	23
# 4KIT	23
# 2PLA	23
# 2NZJ	23
# 1AU1	22
# 1EKP	22
# 1EKF	22
# 1EKV	21
# 3KOO	20
# 3I28	20
# 3OTQ	20
# 3I1Y	20
# 3A6N	18
# 4E36	16
# 3DLW	16
# 3QU8	16
# 1E33	16
# 4JBS	16
# 1AS4	16
# 3CAA	16
# 4CAA	16
# 4HSA	16
# 1A22	15
# 4NEU	15
# 1N2L	15
# 3SE6	15
# 1HWH	14
# 1E1Z	14
# 1E2S	14
# 1E3C	14
# 2ACH	14
# 3T30	14
# 3AZJ	14
# 3AZH	14
# 1N2K	14
# 4J1Y	14
# 3AZM	13
# 3QOA	13
# 3HD6	13
# 2DFD	13
# 3W98	13
# 3IBD	13
# 1QMN	13
# 2C6F	13
# 1ZSQ	13
# 4I91	13
# 4BXK	12
# 4M7H	12
# 4M7F	12
# 2QQJ	12
# 2XYD	12
# 4BZS	12
# 3K6S	12
# 3W96	12
# 3NXQ	11
# 3UYJ	11
# 2C6N	11
# 3II6	10
# 3UA5	10
# 1L2J	10
# 2QQO	10
# 4CA6	10
# 2J0D	10
# 2ODV	10
# 1JPS	10
# 2ODU	9
# 1N6U	9
# 3K72	9
# 2C5D	9
# 3K71	9
# 2C10	9
# 4BTX	9
# 1AXI	9
# 1PU4	8
# 2Y74	8
# 1AUK	8
# 4BTY	8
# 3ALA	8
# 2C11	8
# 2Y73	8
# 4BTW	8
# 3TJS	8
# 1US1	8
# 2PFR	8
# 3EH2	7
# 2H31	7
# 4H6Y	7
# 1UJ3	7
# 1P0Q	7
# 4DYL	6
# 1P0P	6
# 1SG4	6
# 2XMQ	6
# 2XMR	6
# 3AZN	6
# 1EF7	6
# 1N6V	6
# 3OL2	6
# 3QWL	6
# 1IH5	5
# 4LDR	5
# 3AZK	5
# 3AZL	5
# 3AZI	5
# 3W99	5
# 3RBN	5
# 3AZG	5
# 3AZF	5
# 3AZE	5
# 3AYW	5
# 3ANT	5
# 1DEU	5
# 3ANS	5
# 3AFA	5
# 2ZKS	5
# 2ZGC	5
# 3W97	5
# 3WA9	5
# 1EM2	5
# 3D6T	4
# 2D7I	4
# 1HKK	4
# 1IYH	4
# 1IYI	4
# 1KF9	4
# 1LG2	4
# 1LQ0	4
# 2ZGJ	4
# 2J60	4
# 1V40	4
# 2E0O	4
# 2D7R	4
# 2ZGH	4
# 4OE5	4
# 4BBA	4
# 3KQ4	4
# 4CDG	4
# 4BB9	4
# 3VI5	4
# 3VI7	4
# 3PDC	4
# 3WAA	4
# 4LDQ	3
# 4LY9	3
# 2XAC	3
# 1QRP	3
# 3UTL	3
# 4MQU	3
# 4MRO	3
# 1PSN	3
# 3MW7	3
# 4MSU	3
# 1PSO	3
# 1NI6	3
# 1O1V	3
# 3MQ7	3
# 4MTL	3
# 1I0E	3
# 3V9I	3
# 1Z29	3
# 1ZD2	3
# 1ZD4	3
# 1VJ5	3
# 1TWR	3
# 1TWN	3
# 3ZI1	3
# 1FLH	3
# 1LQ8	3
# 4JNC	3
# 1FGU	3
# 1IMV	3
# 2J3G	3
# 2J3U	2
# 2J3O	2
# 2J3T	2
# 2J3F	2
# 2YMK	2
# 2MM3	2
# 4HAI	2
# 2J1G	2
# 4J03	2
# 3WKE	2
# 2PD6	2
# 3WKD	2
# 3WKC	2
# 3WKB	2
# 3WKA	2
# 4JQ1	2
# 2J2P	2
# 4BGM	2
# 2J0Y	2
# 4C5W	2
# 1ZD3	2
# 1ZD5	2
# 4GQS	2
# 1SO7	2
# 4EDZ	2
# 4H1S	2
# 4EDY	2
# 1S8O	2
# 1RH2	2
# 4EC0	2
# 4DVQ	2
# 4C8R	2
# 2F26	2
# 2J0H	2
# 3IPS	2
# 4H8S	2
# 2HDJ	2
# 4BHI	2
# 4BHG	2
# 4BHF	2
# 4JQ3	2
# 4BGK	2
# 2IAG	2
# 2IPJ	2
# 4BG1	2
# 2J0G	2
# 4JQ2	2
# 2VCQ	2
# 4L1X	2
# 3E73	2
# 3WK6	2
# 3WK4	2
# 2YBU	2
# 1FQY	2
# 2Z7X	2
# 3F8G	2
# 2ZN9	2
# 3F7G	2
# 3SQO	2
# 3WK8	2
# 3LY6	2
# 4L1W	2
# 4JQ4	2
# 3PC7	2
# 3O2G	2
# 3D4J	2
# 3MS5	2
# 3CU7	2
# 3WK7	2
# 3WK5	2
# 4JTQ	2
# 3JVF	2
# 1J96	2
# 3KXO	2
# 4JTR	2
# 3KFQ	2
# 1IHI	2
# 2VD0	2
# 3WK9	2
# 3IPU	2
# 3G3D	2
# 4JQA	2
# 1R3V	1
# 1VJ9	1
# 1D1S	1
# 1R3T	1
# 1R3W	1
# 1R3Y	1
# 1AGN	1
# 4NC5	1
# 1CZM	1
# 4NCS	1
# 1CRM	1
# 1BZM	1
# 4NEN	1
# 1VCU	1
# 4FGL	1
# 4NEH	1
# 1SNT	1
# 1R3R	1
# 4GTU	1
# 1AZM	1
# 1R3S	1
# 1W10	1
# 1R3Q	1
# 1HP7	1
# 1KCW	1
# 1KCG	1
# 4JOD	1
# 1JV0	1
# 4JNW	1
# 1J9W	1
# 1ITF	1
# 4J6G	1
# 4K8R	1
# 4IGD	1
# 4K9T	1
# 1HUH	1
# 1HUG	1
# 4KXU	1
# 4H1Y	1
# 1HCB	1
# 1FNH	1
# 1OVL	1
# 1F5L	1
# 4KXV	1
# 4KXW	1
# 4KXX	1
# 4KXY	1
# 1OY7	1
# 4MNV	1
# 4H2G	1
# 1D1T	1
# 4H2B	1
# 1VJA	1
# 3IPQ	1
# 1W12	1
# 2XIJ	1
# 3V9G	1
# 3V9H	1
# 2ZV6	1
# 2ZNH	1
# 3W6H	1
# 3W6I	1
# 2YBT	1
# 2XSN	1
# 2XIQ	1
# 2X7H	1
# 2VM8	1
# 2X1H	1
# 2X0B	1
# 2WXW	1
# 2WG4	1
# 2WFX	1
# 2WFD	1
# 2WEK	1
# 2W2P	1
# 2W2O	1
# 3TEM	1
# 3APU	1
# 3APW	1
# 3RME	1
# 3IG6	1
# 3GGR	1
# 3GCW	1
# 3FY1	1
# 3FXY	1
# 3FW1	1
# 3LXE	1
# 3EE2	1
# 3E6U	1
# 3MOS	1
# 3BIC	1
# 3BG3	1
# 3B6H	1
# 3OOY	1
# 3PB1	1
# 3R8Q	1
# 3RM4	1
# 3RM8	1
# 3RM9	1
# 2VRE	1
# 2VD1	1
# 4FGK	1
# 2CV5	1
# 2F24	1
# 2F13	1
# 2F12	1
# 2F11	1
# 2F10	1
# 2F0Z	1
# 2E0M	1
# 2E0L	1
# 2CVD	1
# 2CJW	1
# 2VCZ	1
# 2CAB	1
# 4EE0	1
# 4ENZ	1
# 4FDH	1
# 4FDI	1
# 2C0C	1
# 2AG5	1
# 4FDJ	1
# 4FGJ	1
# 2F25	1
# 2F27	1
# 2F28	1
# 2F29	1
# 2VCX	1
# 2VCW	1
# 2V0M	1
# 2RD7	1
# 2R2W	1
# 2QSQ	1
# 2PMW	1
# 2OL2	1
# 2OF5	1
# 3WKJ	1
# 2OBY	1
# 2NN7	1
# 2NN1	1
# 2NMX	1
# 2J8Z	1
# 2IT4	1
# 4BOC	1
# 2GSE	1
# 2FW4	1
# 2FOY	1
#
# EUR_AFR_pval: 524 unique structures with significant residues
# 4HLT	51
# 3ACL	51
# 4EWD	51
# 4GUL	50
# 4ERO	49
# 4EWE	48
# 4EWA	48
# 1J1L	47
# 3QU8	37
# 2NVU	35
# 1YOV	33
# 3P5C	32
# 3P5B	32
# 3M0C	32
# 3GZN	31
# 3DBR	31
# 3DBL	31
# 3DBH	31
# 3C5N	28
# 4K3J	23
# 1NN8	23
# 2J9Q	23
# 1SHY	23
# 2JIS	19
# 1X0X	18
# 2IFG	17
# 4DY0	16
# 4JNI	16
# 4JK5	15
# 1GJ9	15
# 1GJ7	15
# 1GJD	15
# 1GJ8	15
# 3FVS	15
# 4DY7	15
# 3FVX	15
# 1C5W	14
# 1GJA	14
# 1GJC	14
# 1O5B	14
# 1C5X	14
# 1GI7	14
# 1GI8	14
# 1GI9	14
# 1O5C	14
# 1C5Y	14
# 1O5A	14
# 3ZI1	14
# 1W12	14
# 1XVP	14
# 2AKE	14
# 2DR2	14
# 1C5Z	14
# 1O3P	13
# 4MNX	13
# 4MNW	13
# 4DVA	13
# 2NWN	13
# 3OY5	13
# 4MNY	13
# 3OY6	13
# 1SC8	13
# 3MHW	13
# 3KID	13
# 3KHV	13
# 3KGP	13
# 1VJA	13
# 3IG6	13
# 1W0Z	13
# 1W10	13
# 1W11	13
# 3FVU	13
# 3ELA	13
# 2VIN	13
# 3MWI	13
# 3M61	13
# 4H42	13
# 4GLY	13
# 4MNV	13
# 1F92	13
# 1EJN	13
# 4JNL	13
# 1F5L	13
# 4JK6	13
# 3OX7	12
# 2VIO	12
# 2PUQ	12
# 2VIQ	12
# 2VIP	12
# 1GJB	12
# 2R2W	12
# 1VJ9	12
# 3UA5	12
# 1W13	12
# 1W14	12
# 1LMW	12
# 2VIW	12
# 2VIV	12
# 4DAY	11
# 1YDE	11
# 1JPS	11
# 2QUJ	11
# 2QUH	11
# 3B6H	11
# 1ULH	11
# 2BJN	11
# 1W7M	11
# 1W7N	11
# 3QOA	10
# 3T30	10
# 3MXN	10
# 4I91	10
# 1W7L	10
# 2IAG	10
# 3IBD	10
# 2QUI	10
# 1Q1Z	9
# 3HIG	9
# 3HII	9
# 1O5T	9
# 2QUK	9
# 2D68	8
# 1W2K	8
# 3HI7	8
# 1T5A	8
# 1W0Y	8
# 1UJ3	8
# 2JHK	8
# 1Q1Q	8
# 1Q20	8
# 1Q22	8
# 1X9N	8
# 3K5T	8
# 3MPH	8
# 4E0S	8
# 2JHI	8
# 1QFK	7
# 3QHE	7
# 1FAK	7
# 2JHL	7
# 2WNP	7
# 3AFA	7
# 3AYW	7
# 2JHM	7
# 4AWN	7
# 2JHH	7
# 1XG5	7
# 4A35	7
# 1WT6	7
# 3OBZ	6
# 1Q1C	6
# 3D4J	6
# 3W96	6
# 1WTG	6
# 2ZWL	6
# 1WUN	6
# 1WV7	6
# 3AZN	6
# 4B3G	6
# 2ZZU	6
# 4LAX	6
# 3AZK	6
# 3AZJ	6
# 3AV1	6
# 3AV2	6
# 2Z5F	6
# 2AER	6
# 4H6Y	6
# 2B8O	6
# 2OU1	6
# 3T7U	6
# 2AEI	6
# 1WQV	6
# 1DAN	6
# 2OPW	6
# 3TH4	5
# 4C6F	5
# 3AZI	5
# 4C6D	5
# 1XM9	5
# 3W99	5
# 3AZH	5
# 3LPO	5
# 4C6Q	5
# 3AZM	5
# 4C6J	5
# 2EC9	5
# 4C6K	5
# 1WSS	5
# 4C6N	5
# 2C4F	5
# 2ZP0	5
# 4C6I	5
# 3DLX	4
# 2A2Q	4
# 4IBL	4
# 2A1X	4
# 4ERC	4
# 3LPP	4
# 4AUO	4
# 1ORE	4
# 3SC0	4
# 3TH2	4
# 4C6P	4
# 4C6O	4
# 3W98	4
# 4C6M	4
# 3PB9	4
# 4C6L	4
# 1KF9	4
# 4B7L	4
# 4C6B	4
# 4C6C	4
# 4C6E	4
# 2FIR	4
# 3PB4	4
# 3AU3	4
# 3PB7	4
# 3PB6	4
# 3PB8	4
# 4DW2	4
# 3WAA	3
# 1NDE	3
# 3JYH	3
# 4FC6	3
# 2WA6	3
# 3WA9	3
# 2GSX	3
# 4FC7	3
# 3N0T	3
# 3THP	3
# 2D39	3
# 4NRV	2
# 4O3N	2
# 1Z7J	2
# 1Z6J	2
# 2E1Q	2
# 4O3P	2
# 4O3S	2
# 2CKJ	2
# 2VRE	2
# 2WA5	2
# 2IMG	2
# 4O3R	2
# 2X0B	2
# 1Y1D	2
# 2CLT	2
# 4J9S	2
# 2WA7	2
# 2WXW	2
# 4O3Q	2
# 4O3O	2
# 4J9R	2
# 4EEY	2
# 1P5J	2
# 3MR3	2
# 3IFC	2
# 4DL5	2
# 4DL4	2
# 1TDH	2
# 4DL3	2
# 4DL2	2
# 3MR2	2
# 3MR5	2
# 4ECQ	2
# 3MR6	2
# 4BYF	2
# 1LCY	2
# 4J9Q	2
# 4AFX	2
# 4A5W	2
# 3SBY	2
# 4ED8	2
# 4H1S	2
# 4ED2	2
# 4ECZ	2
# 4ED0	2
# 4ECS	2
# 3FER	2
# 4ECY	2
# 4ECX	2
# 4ECW	2
# 4J9O	2
# 4J9L	2
# 4ED6	2
# 4J9P	2
# 4ECU	2
# 4ECT	2
# 4ED7	2
# 1LG2	1
# 1J9C	1
# 1IJN	1
# 1DVX	1
# 2I6T	1
# 1LQ0	1
# 1DVQ	1
# 2H11	1
# 1III	1
# 2FDY	1
# 1IIK	1
# 1ICT	1
# 2HI9	1
# 2FLB	1
# 2FLM	1
# 2G3X	1
# 2G3Z	1
# 2FBR	1
# 2G4G	1
# 2G5U	1
# 2G9K	1
# 2H4E	1
# 2GAB	1
# 1HKK	1
# 2G4E	1
# 1Y7V	1
# 1G1O	1
# 1TZ8	1
# 1ETB	1
# 1E5A	1
# 2B9A	1
# 1E4H	1
# 2B7D	1
# 2B77	1
# 2B16	1
# 2B15	1
# 2B14	1
# 1E3F	1
# 1BOY	1
# 1WCH	1
# 1DVZ	1
# 1DVY	1
# 1ZD6	1
# 1X7S	1
# 1ZCR	1
# 1X7T	1
# 1BMZ	1
# 1U21	1
# 2CV5	1
# 2F9B	1
# 1TTR	1
# 2F8I	1
# 2F7I	1
# 1FHN	1
# 1FH2	1
# 1QWH	1
# 2F26	1
# 1SO7	1
# 2E9X	1
# 1DVS	1
# 1DVU	1
# 1SOK	1
# 1F86	1
# 2D9C	1
# 1SOQ	1
# 1F41	1
# 1TFH	1
# 1THA	1
# 1THC	1
# 1TT6	1
# 1DVT	1
# 5TTR	1
# 2J6L	1
# 4DEU	1
# 3S3P	1
# 3SE6	1
# 3SSG	1
# 3TCT	1
# 3TFB	1
# 3U2I	1
# 3U2J	1
# 3W3B	1
# 3WKJ	1
# 3ZDQ	1
# 4AYT	1
# 4AYW	1
# 4AYX	1
# 4BXK	1
# 4CA6	1
# 4DER	1
# 4DES	1
# 3P3U	1
# 3P3T	1
# 3P3S	1
# 3L4Z	1
# 3IPE	1
# 3J0A	1
# 3KGS	1
# 3KGT	1
# 3KGU	1
# 3L4W	1
# 3L4Y	1
# 3M1O	1
# 3P3R	1
# 3NEE	1
# 3NEO	1
# 3NES	1
# 3NEX	1
# 3NG5	1
# 3NXQ	1
# 3OZK	1
# 4DET	1
# 4DEW	1
# 3IMW	1
# 4E36	1
# 4IK7	1
# 4IKI	1
# 4IKJ	1
# 4IKK	1
# 4IKL	1
# 4JBS	1
# 4JTU	1
# 4K8R	1
# 4KY2	1
# 4L1S	1
# 4L1T	1
# 4MAS	1
# 4MRB	1
# 4MRC	1
# 4N85	1
# 4N86	1
# 4N87	1
# 4IK6	1
# 4IIZ	1
# 4I89	1
# 4HE0	1
# 4FI6	1
# 4FI7	1
# 4FI8	1
# 4H1Y	1
# 4H27	1
# 4H2B	1
# 4H2G	1
# 4HE1	1
# 4I87	1
# 4HE2	1
# 4HIQ	1
# 4HIS	1
# 4HJS	1
# 4HJT	1
# 4HJU	1
# 4I85	1
# 3IPB	1
# 3IMV	1
# 2NMP	1
# 3CN3	1
# 3A4F	1
# 3A6N	1
# 3AZE	1
# 3AZF	1
# 3AZG	1
# 3AZL	1
# 3B56	1
# 3B7W	1
# 3BIC	1
# 3BT0	1
# 3CBR	1
# 3CFM	1
# 3CFN	1
# 3CFQ	1
# 3CFT	1
# 3CN0	1
# 3CN1	1
# 3A4E	1
# 3A4D	1
# 2XIQ	1
# 2QGC	1
# 2NOY	1
# 2OTP	1
# 2P0R	1
# 2PAB	1
# 2Q9Q	1
# 2QEL	1
# 2QGB	1
# 2QGD	1
# 2XIJ	1
# 2QGE	1
# 2QQJ	1
# 2QTW	1
# 2ROX	1
# 2ROY	1
# 2WMD	1
# 2X29	1
# 3CN2	1
# 3CN4	1
# 3IMU	1
# 3COG	1
# 3GLZ	1
# 3GPS	1
# 3GRB	1
# 3GRG	1
# 3GS0	1
# 3GS4	1
# 3GS7	1
# 3GXM	1
# 3GZC	1
# 3GZD	1
# 3H42	1
# 3HJ0	1
# 3I9I	1
# 3I9P	1
# 3IMR	1
# 3IMS	1
# 3IMT	1
# 3FCB	1
# 3FC8	1
# 3ESP	1
# 3DJT	1
# 3CXF	1
# 3D2T	1
# 3D7P	1
# 3DGD	1
# 3DID	1
# 3DJR	1
# 3DJS	1
# 3DJZ	1
# 3ESO	1
# 3DK0	1
# 3DK2	1
# 3DL2	1
# 3DO4	1
# 3E3R	1
# 3EE6	1
# 3ESN	1
# 1BM7	1

# %%
# Tomorrow morning, take the list of highly differentiated uniprot/pdb IDs in Evernote
# and see how many of them are in these two lists
# Then go the other direction, and see how many of these are in the differeniated list
with open('temp/highly_diff_prots.txt') as fin:
    hd_unp = [l for l in fin]
with open('temp/highly_diff_structs.txt') as fin:
    hd_pdb = [l for l in fin]

for pop_pval in pop_pvals:
    print pop_pval
    tdf = df[df[pop_pval]<0.05]
    uniqp = tdf.groupby('unp').seqid.nunique()
    # How many of the significant spheres were in proteins corresponding to high CMS genes?
    sbset = [unp for unp in uniqp if unp in hd_unp]
    print "%s (%2.2f%%) spheres corresponded to significant HD proteins."%(len(sbset),len(sbset)/len(uniqp))
    # How many high CMS genes correspond to proteins with significant spheres?
    sbset = [unp for unp in hd_unp if unp in uniqp]
    print "%s (%2.2f%%) HD proteins included significant spheres."%(len(sbset),len(sbset)/len(hd_unp))
    for p in sbset: print pop_pval,p
    
    uniqs = tdf.groupby('structid').seqid.nunique()
    # How many of the significant spheres were in structures corresponding to high CMS genes?
    sbset = [pdb for pdb in uniqs if pdb in hd_pdb]
    print "%s (%2.2f%%) spheres corresponded to significant HD structures."%(len(sbset),len(sbset)/len(uniqp))
    # How many high CMS genes correspond to structures with significant spheres?
    sbset = [pdb for pdb in hd_pdb if pdb in uniqs]
    print "%s (%2.2f%%) HD structures included significant spheres."%(len(sbset),len(sbset)/len(hd_pdb))
    for s in sbset: print pop_pval,s
    print ''
# Out:
# AMR_ASN_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
#
# AMR_EUR_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
#
# AMR_AFR_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
#
# ASN_EUR_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
#
# ASN_AFR_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
#
# EUR_AFR_pval
# 0 (0.00%) spheres corresponded to significant HD proteins.
# 0 (0.00%) HD proteins included significant spheres.
# 0 (0.00%) spheres corresponded to significant HD structures.
# 0 (0.00%) HD structures included significant spheres.
