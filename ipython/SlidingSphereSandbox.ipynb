# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import glob,gzip
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the results file into a pandas data frame
#FIXME: Extract the biounit from the file name and add to all rows
import pandas as pd
results_fnames = glob.glob('results/sliding_sphere_10/split/obs/bystruct/*.txt.gz')
dfs = [pd.read_table(gzip.open(fname,'rb'),delimiter='\t') for fname in results_fnames]
df = pd.concat(dfs)
print "Spheres read:",len(df)
del dfs
# Out:
# Structures read: 9888898

# %%
count_cols    = ['amr_count','asn_count','eur_count','afr_count']
cdaf_cols     = ['amr_cdaf','asn_cdaf', 'eur_cdaf', 'afr_cdaf']
sumddaf_cols  = ['amr_asn_sumddaf', 'amr_eur_sumddaf', 'amr_afr_sumddaf', 'asn_eur_sumddaf', 'asn_afr_sumddaf', 'eur_afr_sumddaf']
meanddaf_cols = ['amr_asn_meanddaf','amr_eur_meanddaf','amr_afr_meanddaf','asn_eur_meanddaf','asn_afr_meanddaf','eur_afr_meanddaf']
minddaf_cols  = ['amr_asn_minddaf', 'amr_eur_minddaf', 'amr_afr_minddaf', 'asn_eur_minddaf', 'asn_afr_minddaf', 'eur_afr_minddaf']
maxddaf_cols  = ['amr_asn_maxddaf', 'amr_eur_maxddaf', 'amr_afr_maxddaf', 'asn_eur_maxddaf', 'asn_afr_maxddaf', 'eur_afr_maxddaf']
nest_cols     = [count_cols,cdaf_cols,sumddaf_cols,meanddaf_cols,minddaf_cols,maxddaf_cols]
count_pval_cols    = ['amr_count_pval','asn_count_pval','eur_count_pval','afr_count_pval']
cdaf_pval_cols     = ['amr_cdaf_pval','asn_cdaf_pval', 'eur_cdaf_pval', 'afr_cdaf_pval']
sumddaf_pval_cols  = ['amr_asn_sumddaf_pval', 'amr_eur_sumddaf_pval', 'amr_afr_sumddaf_pval', 'asn_eur_sumddaf_pval', 'asn_afr_sumddaf_pval', 'eur_afr_sumddaf_pval']
meanddaf_pval_cols = ['amr_asn_meanddaf_pval','amr_eur_meanddaf_pval','amr_afr_meanddaf_pval','asn_eur_meanddaf_pval','asn_afr_meanddaf_pval','eur_afr_meanddaf_pval']
minddaf_pval_cols  = ['amr_asn_minddaf_pval', 'amr_eur_minddaf_pval', 'amr_afr_minddaf_pval', 'asn_eur_minddaf_pval', 'asn_afr_minddaf_pval', 'eur_afr_minddaf_pval']
maxddaf_pval_cols  = ['amr_asn_maxddaf_pval', 'amr_eur_maxddaf_pval', 'amr_afr_maxddaf_pval', 'asn_eur_maxddaf_pval', 'asn_afr_maxddaf_pval', 'eur_afr_maxddaf_pval']
nest_pval_cols     = [count_pval_cols,cdaf_pval_cols,sumddaf_pval_cols,meanddaf_pval_cols,minddaf_pval_cols,maxddaf_pval_cols]
nest_all = [nest_cols,nest_pval_cols]

# %%
# Boxplot for each count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(df.ix[:,colset])
    plt.tight_layout()
    plt.show()

# %%
# Boxplot for each pvalues for count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_pval_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(-np.log10(df.ix[:,colset]))
    plt.hlines(2,0,10,'red',linestyles='dotted')
    plt.hlines(1.3,0,10,'blue',linestyles='dotted')
    plt.tight_layout()
    plt.show()

# %%
# Boxplot for the number of significant spheres for count, cDAF, or ΔDAF statistic, stratified by population, grouped protein
for colset in nest_pval_cols:
    ndf = []
    plt.figure(figsize=(15,6))
    for col in colset:
        sns.set_style("whitegrid")
        sns.set_palette("hls")
        dfc = df[df[col]<0.05].groupby('structid').size()
        ndf.append(dfc)
    sns.boxplot(ndf,names=colset)
    plt.tight_layout()
    plt.show()

# %%
# Boxplot for significant sphere values for count, cDAF, or ΔDAF statistic, stratified by population, grouped protein
for i,colset in enumerate(nest_pval_cols):
    ndf = []
    plt.figure(figsize=(15,6))
    for j,col in enumerate(colset):
        sns.set_style("whitegrid")
        sns.set_palette("hls")
        dfc = df[df[col]<0.05][nest_cols[i][j]]
        ndf.append(dfc)
    sns.boxplot(ndf,names=nest_cols[i])
    plt.tight_layout()
    plt.show()

# %%
# Boxplot for mean value of significant spheres for count, cDAF, or ΔDAF statistic, stratified by population, grouped protein
for i,colset in enumerate(nest_pval_cols):
    ndf = []
    plt.figure(figsize=(15,6))
    for j,col in enumerate(colset):
        sns.set_style("whitegrid")
        sns.set_palette("hls")
        dfc = df[df[col]<0.05].groupby('structid')[nest_cols[i][j]].mean()
        ndf.append(dfc)
    sns.boxplot(ndf,names=nest_cols[i])
    plt.tight_layout()
    plt.show()

# %%
# List the proteins with the *greatest number of* significant spheres for count, cDAF, and ΔDAF, stratified by population
for colset in nest_pval_cols:
    ndf = []
    for col in colset:
        dfc = df[df[col]<0.05].groupby('structid').size()
        dfc.sort()
        print "%s  %s"%(col,' | '.join(["%s: %.2f"%(sid,cnt) for sid,cnt in dfc.tail(5).iteritems()][::-1]))
    print ''
# Out:
# amr_count_pval  1TZN: 602.00 | 1QO5: 528.00 | 3J6C: 528.00 | 1V5W: 480.00 | 3L4G: 437.00
# asn_count_pval  2QG4: 628.00 | 1H2I: 380.00 | 1SYQ: 359.00 | 3H44: 352.00 | 3QU8: 322.00
# eur_count_pval  4HYY: 620.00 | 1QO5: 391.00 | 3RIL: 363.00 | 3IKM: 321.00 | 1ZVM: 276.00
# afr_count_pval  3J6C: 528.00 | 1TZN: 504.00 | 3SRF: 432.00 | 2A3W: 325.00 | 4OE5: 318.00
# amr_cdaf_pval  3RIL: 742.00 | 3L4G: 732.00 | 1TZN: 602.00 | 1QO5: 528.00 | 1Y7V: 489.00
# eur_afr_minddaf_pval  2CLP: 651.00 | 3L4G: 592.00 | 3SRF: 527.00 | 3RIL: 522.00 | 1V5W: 480.00
# amr_asn_maxddaf_pval  3RIL: 834.00 | 3SRF: 619.00 | 3L4G: 522.00 | 1Y7V: 513.00 | 1V5W: 504.00
# amr_eur_maxddaf_pval  3RIL: 775.00 | 3L4G: 588.00 | 3SRF: 527.00 | 1TZN: 504.00 | 1V5W: 480.00
# amr_afr_maxddaf_pval  3SRF: 625.00 | 3RIL: 608.00 | 3L4G: 604.00 | 1V5W: 504.00 | 2QG4: 479.00
# asn_eur_maxddaf_pval  3SRF: 625.00 | 3RIL: 608.00 | 3L4G: 604.00 | 1V5W: 504.00 | 2QG4: 479.00
# asn_afr_maxddaf_pval  3SRF: 619.00 | 3RIL: 541.00 | 3L4G: 529.00 | 1V5W: 504.00 | 2XWB: 409.00
# eur_afr_maxddaf_pval  3RIL: 543.00 | 3SRF: 527.00 | 3L4G: 507.00 | 1V5W: 480.00 | 1I10: 373.00

# %%
# List the proteins with the *most extremely* significant spheres for count, cDAF, and ΔDAF, stratified by population
for i,colset in enumerate(nest_pval_cols):
    ndf = []
    for j,col in enumerate(colset):
        dfc = df[df[col]<0.05].groupby('structid').min().sort([col,nest_cols[i][j]],ascending=[True,False]).head(5)
        print "%s  %s"%(col,' | '.join(["%s: %2.2f, p≤%1.1e"%(sid,val,pval) for sid,_,pval,val in dfc.ix[:,["structid",col,nest_cols[i][j]]].itertuples()]))
    print ''
# Out:
# amr_count_pval  1Q94: 5.00, p≤1.0e-03 | 1BX2: 4.00, p≤1.0e-03 | 1DLH: 4.00, p≤1.0e-03 | 1FV1: 4.00, p≤1.0e-03 | 1HQR: 4.00, p≤1.0e-03
# asn_count_pval  1BX2: 4.00, p≤1.0e-03 | 1DLH: 4.00, p≤1.0e-03 | 1FV1: 4.00, p≤1.0e-03 | 1HQR: 4.00, p≤1.0e-03 | 1JWM: 4.00, p≤1.0e-03
# eur_count_pval  1BX2: 4.00, p≤1.0e-03 | 1DLH: 4.00, p≤1.0e-03 | 1FV1: 4.00, p≤1.0e-03 | 1HQR: 4.00, p≤1.0e-03 | 1JWM: 4.00, p≤1.0e-03
# afr_count_pval  1Q94: 5.00, p≤1.0e-03 | 1BX2: 4.00, p≤1.0e-03 | 1DLH: 4.00, p≤1.0e-03 | 1FV1: 4.00, p≤1.0e-03 | 1HQR: 4.00, p≤1.0e-03
# amr_cdaf_pval  10000000.0: 2.82, p≤1.0e-03 | 2NLC: 2.00, p≤1.0e-03 | 2NLG: 2.00, p≤1.0e-03 | 4KY9: 1.93, p≤1.0e-03 | 2VCT: 1.65, p≤1.0e-03
# asn_cdaf_pval  2NLG: 2.00, p≤1.0e-03 | 2VCT: 1.57, p≤1.0e-03 | 2HN7: 1.10, p≤1.0e-03 | 3CHN: 1.10, p≤1.0e-03 | 3RL1: 1.06, p≤1.0e-03
# eur_cdaf_pval  10000000.0: 3.00, p≤1.0e-03 | 2NLC: 2.00, p≤1.0e-03 | 2NLG: 2.00, p≤1.0e-03 | 4KY9: 1.98, p≤1.0e-03 | 2VCT: 1.51, p≤1.0e-03
# afr_cdaf_pval  10000000.0: 2.98, p≤1.0e-03 | 2QEJ: 2.00, p≤1.0e-03 | 2VCT: 1.27, p≤1.0e-03 | 4LLA: 1.02, p≤1.0e-03 | 4I5X: 1.01, p≤1.0e-03
# amr_asn_sumddaf_pval  2XY1: 0.22, p≤1.0e-03 | 2XYC: 0.22, p≤1.0e-03 | 3DLS: 0.20, p≤1.0e-03 | 1DIA: 0.17, p≤1.0e-03 | 1DIG: 0.17, p≤1.0e-03
# amr_eur_sumddaf_pval  1Z29: 0.11, p≤1.0e-03 | 1L9N: 0.09, p≤1.0e-03 | 1CZT: 0.06, p≤1.0e-03 | 1EKV: 0.06, p≤1.0e-03 | 2A1H: 0.06, p≤1.0e-03
# amr_afr_sumddaf_pval  1L9N: 0.17, p≤1.0e-03 | 1Z29: 0.12, p≤1.0e-03 | 1XAR: 0.07, p≤1.0e-03 | 1XPH: 0.07, p≤1.0e-03 | 1CZT: 0.06, p≤1.0e-03
# asn_eur_sumddaf_pval  1L9N: 0.17, p≤1.0e-03 | 1EKV: 0.12, p≤1.0e-03 | 2A1H: 0.12, p≤1.0e-03 | 1WLZ: 0.09, p≤1.0e-03 | 2R0K: 0.08, p≤1.0e-03
# asn_afr_sumddaf_pval  3DLS: 0.20, p≤1.0e-03 | 1L9N: 0.17, p≤1.0e-03 | 1XAR: 0.15, p≤1.0e-03 | 1XPH: 0.15, p≤1.0e-03 | 1EKV: 0.12, p≤1.0e-03
# eur_afr_sumddaf_pval  1HDZ: 0.66, p≤1.0e-03 | 3VCL: 0.52, p≤1.0e-03 | 2JJU: 0.44, p≤1.0e-03 | 1CSG: 0.38, p≤1.0e-03 | 2DBJ: 0.38, p≤1.0e-03
# amr_asn_meanddaf_pval  4BXF: 0.25, p≤1.0e-03 | 4CMM: 0.22, p≤1.0e-03 | 2AFM: 0.16, p≤1.0e-03 | 2AFO: 0.16, p≤1.0e-03 | 2AFS: 0.16, p≤1.0e-03
# amr_eur_meanddaf_pval  4BXF: 0.25, p≤1.0e-03 | 4CMM: 0.22, p≤1.0e-03 | 2AFM: 0.16, p≤1.0e-03 | 2AFO: 0.16, p≤1.0e-03 | 2AFS: 0.16, p≤1.0e-03
# amr_afr_meanddaf_pval  3GTU: 0.37, p≤1.0e-03 | 3IQ2: 0.27, p≤1.0e-03 | 4BXF: 0.25, p≤1.0e-03 | 4CMM: 0.22, p≤1.0e-03 | 1L9N: 0.17, p≤1.0e-03
# asn_eur_meanddaf_pval  1FV1: 0.27, p≤1.0e-03 | 3IQ2: 0.27, p≤1.0e-03 | 4BXF: 0.25, p≤1.0e-03 | 4CMM: 0.22, p≤1.0e-03 | 3HFV: 0.21, p≤1.0e-03
# asn_afr_meanddaf_pval  3CIP: 0.14, p≤1.0e-03 | 3PLS: 0.12, p≤1.0e-03 | 1DIA: 0.10, p≤1.0e-03 | 1DIB: 0.10, p≤1.0e-03 | 1DIG: 0.10, p≤1.0e-03
# eur_afr_meanddaf_pval  3I4R: 0.09, p≤1.0e-03 | 3P72: 0.06, p≤1.0e-03 | 1D5S: 0.04, p≤1.0e-03 | 1IZ2: 0.04, p≤1.0e-03 | 1OO8: 0.04, p≤1.0e-03
# amr_asn_minddaf_pval  4JJY: 0.22, p≤1.0e-03 | 1EKV: 0.09, p≤1.0e-03 | 1EZX: 0.09, p≤1.0e-03 | 1PSI: 0.09, p≤1.0e-03 | 2A1H: 0.09, p≤1.0e-03
# amr_eur_minddaf_pval  2OEX: 0.22, p≤1.0e-03 | 3RM9: 0.22, p≤1.0e-03 | 4JJY: 0.22, p≤1.0e-03 | 3DLS: 0.13, p≤1.0e-03 | 1HQR: 0.12, p≤1.0e-03
# amr_afr_minddaf_pval  3OG6: 0.52, p≤1.0e-03 | 2VCT: 0.38, p≤1.0e-03 | 1FV1: 0.30, p≤1.0e-03 | 4LLA: 0.29, p≤1.0e-03 | 1XPH: 0.28, p≤1.0e-03
# asn_eur_minddaf_pval  3OG6: 0.52, p≤1.0e-03 | 1FV1: 0.25, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03 | 2AFO: 0.19, p≤1.0e-03 | 2AFS: 0.19, p≤1.0e-03
# asn_afr_minddaf_pval  3OG6: 0.52, p≤1.0e-03 | 1FV1: 0.25, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03 | 2AFO: 0.19, p≤1.0e-03 | 2AFS: 0.19, p≤1.0e-03
# eur_afr_minddaf_pval  3OG6: 0.52, p≤1.0e-03 | 3GTU: 0.27, p≤1.0e-03 | 2IDX: 0.20, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03 | 2AFO: 0.19, p≤1.0e-03
# amr_asn_maxddaf_pval  3D34: 0.44, p≤1.0e-03 | 1XAR: 0.28, p≤1.0e-03 | 1XPH: 0.28, p≤1.0e-03 | 2IDX: 0.20, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03
# amr_eur_maxddaf_pval  2DNF: 0.62, p≤1.0e-03 | 2VCT: 0.40, p≤1.0e-03 | 2WJU: 0.40, p≤1.0e-03 | 2e+88: 0.37, p≤1.0e-03 | 1HJO: 0.37, p≤1.0e-03
# amr_afr_maxddaf_pval  3OG6: 0.52, p≤1.0e-03 | 1FV1: 0.25, p≤1.0e-03 | 2BKQ: 0.20, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03 | 2AFO: 0.19, p≤1.0e-03
# asn_eur_maxddaf_pval  3OG6: 0.52, p≤1.0e-03 | 1FV1: 0.25, p≤1.0e-03 | 2BKQ: 0.20, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03 | 2AFO: 0.19, p≤1.0e-03
# asn_afr_maxddaf_pval  3OG6: 0.52, p≤1.0e-03 | 3GTU: 0.27, p≤1.0e-03 | 2BKQ: 0.20, p≤1.0e-03 | 2IDX: 0.20, p≤1.0e-03 | 2AFM: 0.19, p≤1.0e-03
# eur_afr_maxddaf_pval  3D34: 0.44, p≤1.0e-03 | 4I2X: 0.32, p≤1.0e-03 | 1XAR: 0.28, p≤1.0e-03 | 1XPH: 0.28, p≤1.0e-03 | 2E8A: 0.27, p≤1.0e-03

# %%
metric = 'eur_afr_meanddaf'
pval   = 'eur_afr_meanddaf_pval'
# dfc = df[df[pval]<0.05].sort([metric,'afr_count','eur_count'],ascending=[True,False,False])
dfc = df[df[pval]<0.05].sort(['afr_count','eur_count'],ascending=[False,False])

top_10_structs,i,keys = dict(),0,[]
while len(top_10_structs) < 10:
    sid = dfc.iloc[i].structid
    if sid not in top_10_structs:
        top_10_structs[sid] = 1
        keys.append(sid)
    else:
        top_10_structs[sid] += 1
    i+= 1
# Structures ordered by the rank of their highest-ranking sphere
# Counts are for all spheres with a higher rank than the final sphere considered
for key in keys:
    print key,top_10_structs[key]

dfc = dfc.head(100)

print "%s  %s"%(metric,'\n'.join(["%s:%d.%s: %2.2f, p≤%1.1e afr=%d eur=%d"%(sid,seqid,chain,val,pval,afr,eur) for _,sid,seqid,chain,pval,val,afr,eur in dfc.ix[:,["structid",'seqid','chain',pval,metric,'afr_count','eur_count']].itertuples()]))
# Out:
# 3VCL 21
# 1FV1 3
# 1HQR 3
# 1Q94 24
# 1X7Q 3
# 2XPG 3
# 3IG6 16
# 1BX2 3
# 1PYW 1
# 1R5I 1
# eur_afr_meanddaf  3VCL:22.A: -0.06, p≤3.0e-02 afr=13 eur=13
# 3VCL:70.A: -0.07, p≤3.4e-02 afr=12 eur=12
# 3VCL:70.A: -0.07, p≤3.4e-02 afr=12 eur=12
# 3VCL:70.A: -0.07, p≤3.4e-02 afr=12 eur=12
# 3VCL:70.A: -0.07, p≤3.4e-02 afr=12 eur=12
# 3VCL:70.A: -0.07, p≤3.4e-02 afr=12 eur=12
# 1FV1:31.E: 0.06, p≤4.5e-02 afr=11 eur=11
# 1FV1:31.E: 0.06, p≤4.5e-02 afr=11 eur=11
# 1FV1:31.E: 0.06, p≤4.5e-02 afr=11 eur=11
# 1HQR:231.B: 0.06, p≤4.8e-02 afr=11 eur=11
# 1HQR:231.B: 0.06, p≤4.8e-02 afr=11 eur=11
# 1HQR:231.B: 0.06, p≤4.8e-02 afr=11 eur=11
# 3VCL:67.A: -0.06, p≤3.2e-02 afr=11 eur=11
# 3VCL:71.A: -0.08, p≤3.3e-02 afr=11 eur=11
# 3VCL:67.A: -0.06, p≤3.2e-02 afr=11 eur=11
# 3VCL:71.A: -0.08, p≤3.3e-02 afr=11 eur=11
# 3VCL:9.A: -0.07, p≤1.9e-02 afr=10 eur=10
# 3VCL:9.A: -0.07, p≤1.9e-02 afr=10 eur=10
