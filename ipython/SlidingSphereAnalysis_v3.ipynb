# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# Z:\projects\pdbmap

# %%
# Load libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the results file into a pandas data frame
import pandas as pd
results_fname = 'results/sliding_sphere_10/sliding_sphere_1KG_10A.txt'
df = pd.read_table(results_fname,delimiter='\t')
df.describe()
# Out:
#             structid          chain            unp          seqid  \
# count  128956.000000  128956.000000  128956.000000  128956.000000
# mean      305.653828      15.037239      14.529695      20.638315
# std       373.764879      41.172332      39.917331      41.062865
# min         1.000000    -145.535995    -164.703369    -148.708176
# 25%        97.000000      -7.087396      -9.495563      -3.006091
# 50%       210.000000      13.248099      11.126527      18.948650
# 75%       380.000000      36.344606      35.896456      42.549821
# max      3553.000000     246.622238     178.136505     207.025589
#
#                    x              y              z       rescount  \
# count  128956.000000  128956.000000  128956.000000  128956.000000
# mean      110.040076       0.621158       0.802561       0.756033
# std        40.603174       1.075946       1.203229       1.203705
# min         4.000000       0.000000       0.000000       0.000000
# 25%        80.000000       0.000000       0.000000       0.000000
# 50%       104.000000       0.000000       0.000000       0.000000
# 75%       137.000000       1.000000       1.000000       1.000000
# max       268.000000      21.000000      21.000000      21.000000
#
#            amr_count      asn_count      ...        amr_afr_minddaf_pval  \
# count  128956.000000  128956.000000      ...               128956.000000
# mean        0.802615       2.422640      ...                    0.340080
# std         1.225084       2.568467      ...                    0.328522
# min         0.000000       0.000000      ...                    0.000000
# 25%         0.000000       0.997200      ...                    0.000000
# 50%         0.000000       1.997200      ...                    0.287000
# 75%         1.000000       3.000000      ...                    0.626000
# max        21.000000      32.986000      ...                    1.000000
#
#        asn_eur_minddaf_pval  asn_afr_minddaf_pval  eur_afr_minddaf_pval  \
# count         128956.000000         128956.000000         128956.000000
# mean               0.358708              0.299109              0.164331
# std                0.338645              0.334450              0.310207
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.317000              0.167000              0.000000
# 75%                0.665000              0.597000              0.048000
# max                1.000000              1.000000              1.000000
#
#        amr_asn_maxddaf_pval  amr_eur_maxddaf_pval  amr_afr_maxddaf_pval  \
# count         128956.000000         128956.000000         128956.000000
# mean               0.290945              0.327926              0.344616
# std                0.294082              0.337920              0.348965
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.224000              0.237000              0.256000
# 75%                0.539000              0.630000              0.670000
# max                1.000000              1.000000              1.000000
#
#        asn_eur_maxddaf_pval  asn_afr_maxddaf_pval  eur_afr_maxddaf_pval
# count         128956.000000         128956.000000         128956.000000
# mean               0.284031              0.135834              0.281609
# std                0.341897              0.296921              0.303773
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.178000
# 75%                0.581000              0.000000              0.534000
# max                1.000000              1.000000              1.000000
#
# [8 rows x 81 columns]
