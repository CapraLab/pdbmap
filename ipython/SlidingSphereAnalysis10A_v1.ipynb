# %% [markdown]
# ## Duplicate of the first Sliding Sphere Analysis - Corrections Made - Evaluating 10A Spheres

# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# Z:\projects\pdbmap

# %%
# Load libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the results file into a pandas data frame
import pandas as pd
results_fname = 'results/sliding_sphere_10/sliding_sphere_1KG_10A.txt'
df = pd.read_table(results_fname,delimiter='\t')
df.describe()
# Out:
#             structid          chain            unp          seqid  \
# count  128956.000000  128956.000000  128956.000000  128956.000000
# mean      305.653828      15.037239      14.529695      20.638315
# std       373.764879      41.172332      39.917331      41.062865
# min         1.000000    -145.535995    -164.703369    -148.708176
# 25%        97.000000      -7.087396      -9.495563      -3.006091
# 50%       210.000000      13.248099      11.126527      18.948650
# 75%       380.000000      36.344606      35.896456      42.549821
# max      3553.000000     246.622238     178.136505     207.025589
#
#                    x              y              z       rescount  \
# count  128956.000000  128956.000000  128956.000000  128956.000000
# mean      110.040076       0.621158       0.802561       0.756033
# std        40.603174       1.075946       1.203229       1.203705
# min         4.000000       0.000000       0.000000       0.000000
# 25%        80.000000       0.000000       0.000000       0.000000
# 50%       104.000000       0.000000       0.000000       0.000000
# 75%       137.000000       1.000000       1.000000       1.000000
# max       268.000000      21.000000      21.000000      21.000000
#
#            amr_count      asn_count      ...        amr_afr_minddaf_pval  \
# count  128956.000000  128956.000000      ...               128956.000000
# mean        0.802615       2.422640      ...                    0.340080
# std         1.225084       2.568467      ...                    0.328522
# min         0.000000       0.000000      ...                    0.000000
# 25%         0.000000       0.997200      ...                    0.000000
# 50%         0.000000       1.997200      ...                    0.287000
# 75%         1.000000       3.000000      ...                    0.626000
# max        21.000000      32.986000      ...                    1.000000
#
#        asn_eur_minddaf_pval  asn_afr_minddaf_pval  eur_afr_minddaf_pval  \
# count         128956.000000         128956.000000         128956.000000
# mean               0.358708              0.299109              0.164331
# std                0.338645              0.334450              0.310207
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.317000              0.167000              0.000000
# 75%                0.665000              0.597000              0.048000
# max                1.000000              1.000000              1.000000
#
#        amr_asn_maxddaf_pval  amr_eur_maxddaf_pval  amr_afr_maxddaf_pval  \
# count         128956.000000         128956.000000         128956.000000
# mean               0.290945              0.327926              0.344616
# std                0.294082              0.337920              0.348965
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.224000              0.237000              0.256000
# 75%                0.539000              0.630000              0.670000
# max                1.000000              1.000000              1.000000
#
#        asn_eur_maxddaf_pval  asn_afr_maxddaf_pval  eur_afr_maxddaf_pval
# count         128956.000000         128956.000000         128956.000000
# mean               0.284031              0.135834              0.281609
# std                0.341897              0.296921              0.303773
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.178000
# 75%                0.581000              0.000000              0.534000
# max                1.000000              1.000000              1.000000
#
# [8 rows x 81 columns]

# %%
# View all column names
print df.dtypes
# Out:
# isvar          object
# issnp          object
# name           object
# amr_af         object
# asn_af         object
# eur_af         object
# afr_af         object
# aa             object
# ref_allele     object
# alt_allele     object
# structid        int64
# chain         float64
# unp           float64
# seqid         float64
# x               int64
# ...
# asn_eur_medianddaf_pval    float64
# asn_afr_medianddaf_pval    float64
# eur_afr_medianddaf_pval    float64
# amr_asn_minddaf_pval       float64
# amr_eur_minddaf_pval       float64
# amr_afr_minddaf_pval       float64
# asn_eur_minddaf_pval       float64
# asn_afr_minddaf_pval       float64
# eur_afr_minddaf_pval       float64
# amr_asn_maxddaf_pval       float64
# amr_eur_maxddaf_pval       float64
# amr_afr_maxddaf_pval       float64
# asn_eur_maxddaf_pval       float64
# asn_afr_maxddaf_pval       float64
# eur_afr_maxddaf_pval       float64
# Length: 91, dtype: object

# %%
# Define the population lists to avoid mess below
pop_pvals = ['AMR_ASN_pval','AMR_EUR_pval','AMR_AFR_pval','ASN_EUR_pval','ASN_AFR_pval','EUR_AFR_pval']
pop_ors   = ['AMR_ASN_obsor','AMR_EUR_obsor','AMR_AFR_obsor','ASN_EUR_obsor','ASN_AFR_obsor','EUR_AFR_obsor']

# %%
# Quality Control: There are a lot of residues with p-values equal to 1.0
# I need to find out what is driving these, but first, we'll remove them
# They probably reflect testing under an invalid condition
df[pop_pvals] = df[pop_pvals].replace(1,np.nan)
# There was a problem found earlier with 3RBN duplication, fixing:
df = df[df['structid']!='A']
df = df[df['structid']!='B']

# %%
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    df[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Not a good start, really. These p-values seem to be following three separate distributions in the first, second, and third tertiles (had to look that one up). I also don't see any infalation for p-values near 0.

# %%
# How many nominally significant (p<0.05) spheres do we have for each population comparison?
totcnt = len(df)
print "Total residues tested: %d"%totcnt
for pop_pval in pop_pvals:
    popcnt = len(df[~np.isnan(df[pop_pval])])
    sigcnt = len(df[df[pop_pval]<0.05])
    print "%s: %d\tof %d(%2.2f%%)"%(pop_pval,sigcnt,popcnt,(float(sigcnt)/popcnt)*100)
# Out:
# Total residues tested: 12542645
# AMR_ASN_pval: 997	of 113368(0.88%)
# AMR_EUR_pval: 83	of 82947(0.10%)
# AMR_AFR_pval: 185	of 111056(0.17%)
# ASN_EUR_pval: 1160	of 134528(0.86%)
# ASN_AFR_pval: 1158	of 163448(0.71%)
# EUR_AFR_pval: 2460	of 176138(1.40%)

# %% [markdown]
# Confusing p-value distributions aside, we're at least seeing nominally significant p-values in fewer than 5% of tested residues within each population, so there is some evidence that those residues are actually significant and not simply the product of chance. Then again, given the p-value distribution, the likelihood of a null residue having a p-value <0.05 isn't 5%, it's likely less.

# %%
# Let's see the p-value distributions from before, but only for our nominally significant residues
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    tdf = df[df[pop_pval]<0.05][pop_pval]
    tdf.hist(bins=20,range=(0,0.05))
    plt.xlabel("Nominally significant %s"%pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Oh, so here's a thought. Since I'm only looking at spheres that contained at least 2 variants in one of the populations, I'm further increasing the dependence of my tests. That might explain a lot of the mini-distributions I'm seeing, since any biases in PDB representation would cause inflation of all p-values derived from that protein/residue/gene/etc.
#
# I should be able to check for this effect by doing we talked about during our last meeting. I'll generate a non-redundant set of structures representing all of the proteins mapped in the PDB. I'll choose each structure as the one that contains the most protein sequence for the given protein. If this flattens out my p-value distribution, then I can attribute the effect to PDB bias.

# %%
# There are too many significant spheres to look at them at once.
# How many unique structures contained significant spheres, for each population comparison?
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').size()
    print "%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
# Out:
# AMR_ASN_pval: 27 unique proteins with significant residues
# AMR_EUR_pval: 2 unique proteins with significant residues
# AMR_AFR_pval: 11 unique proteins with significant residues
# ASN_EUR_pval: 33 unique proteins with significant residues
# ASN_AFR_pval: 39 unique proteins with significant residues
# EUR_AFR_pval: 29 unique proteins with significant residues

# %% [markdown]
# Okay, I'm going to reproduce the original p-value plots, but I'm only going to plot one p-value per unique protein. To find my significant sphers, I have to plot the smallest p-value for each protein. This will bias my p-value distribution towards lower p-values, but the important question will not be the absolute p-values observed, but whether they flatten into a more uniform distribution.

# %%
# First plot the p-values for each population comparison
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    tdf = df.loc[df.groupby('unp')[pop_pval].idxmin()]
    tdf[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Well, I did see the bias towards lower pvalues that I expected, but I didn't observe any flattening of the distribution. This time I'm going to group by both unp and seqid. This will uniquely identify each residue in each protein, and only plot it once, regardless of how many times it appeared in structures. Again, I'm going to use the lowest p-value for each residue, but it is more appropriate in this case, since I'm referring to a single amino acid in a protein, and asking what its most differentiated state was, across all structures.

# %%
# Plot the minimum p-value for each unique protein-residue combination, across all structures
for pop_pval in pop_pvals:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_pval].min().hist(bins=100,range=(0,1))
#     tdf[pop_pval].hist(bins=100,range=(0,1))
    plt.xlabel(pop_pval)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Well...huh. Maybe I'll learn something from the odds ratios (priors as determined by Fisher Exact)
# It is less clear whether I should be looking at the minimum or maximum for this, since these are
# unordered sets, so I'll just look at one and then the other.

# %%
# Plot the maximum OR for each sphere in each population comparison
for pop_or in pop_ors:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_or].max().hist(bins=100,range=(0,10))
    plt.xlabel(pop_or)
    plt.ylabel('count')
    plt.show()

# %%
# Plot the minimum OR for each sphere in each population comparison
for pop_or in pop_ors:
    fig = plt.figure(figsize=(10,5))
    df.groupby(['unp','seqid'])[pop_or].min().hist(bins=100,range=(0,10))
    plt.xlabel(pop_or)
    plt.ylabel('count')
    plt.show()

# %%
# How many duplicates am I even eliminating with this step?
"%d - %d => %d residues in %d proteins"%(len(df),len(df.groupby(['unp','seqid'])),len(df)-len(df.groupby(['unp','seqid'])),len(df.groupby('unp')))
# Out:
# '12542645 - 1125975 => 11416670 residues in 4400 proteins'

# %% [markdown]
# So I've evaluated 12,543,145  residues in solved structures,
# and I removed 1,126,458 as duplicates from homo-polymers, duplicate structures, etc,
# leaving me with 11,416,687 uniquely evaluated residues/spheres in 4,649 unique human proteins.
#
# It looks like I have a large bias for odds ratios of 0 and infinity, which corresponds to spheres containing no variation in one of the two populations. If the 0/N is in the same direction as the expected frequencies, then the OR is 0.0, if it is in the opposite, the OR is infinite.
#
# So far I'm not liking what I'm seeing, but let's move on to looking at a handful of our best-scoring spheres/proteins. I'll start by sorting the proteins by the number of significant spheres identified in that protein.

# %%
# Sort unique proteins by the number of significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').size()
    uniq.sort(ascending=False)
    print "%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
    print uniq.head(10)
# Out:
# AMR_ASN_pval: 27 unique proteins with significant residues
# unp
# P15151    720
# Q07108     87
# P47989     42
# Q495A1     30
# Q8N539     16
# O14732     10
# P07998     10
# P52292     10
# P35613     10
# P18283      8
# dtype: int64
# AMR_EUR_pval: 2 unique proteins with significant residues
# unp
# P68431    81
# P49450     2
# dtype: int64
# AMR_AFR_pval: 11 unique proteins with significant residues
# unp
# O75473    66
# Q9UIK4    34
# P43250    20
# Q7Z4H3    18
# P53350    13
# Q9UBD6    12
# P60022     9
# Q13426     5
# P01241     4
# Q9NUI1     2
# dtype: int64
# ASN_EUR_pval: 33 unique proteins with significant residues
# unp
# P15151    720
# Q9Y223     87
# Q13191     86
# Q6P2F0     33
# P23381     22
# Q8IV48     20
# P47989     20
# P35968     18
# O00206     17
# P30566     17
# dtype: int64
# ASN_AFR_pval: 39 unique proteins with significant residues
# unp
# P15151    300
# Q16853    114
# O15382    110
# P47989     87
# Q07108     87
# P34913     48
# Q86SE8     45
# P62805     45
# P15289     40
# O75628     37
# dtype: int64
# EUR_AFR_pval: 29 unique proteins with significant residues
# unp
# P15151    1560
# P00749     321
# O00625     143
# Q86SE8      79
# Q13564      50
# P20813      48
# Q8TBC4      32
# Q59FQ1      27
# P13726      26
# P19801      23
# dtype: int64

# %% [markdown]
# P15151 is a very interesting result. P15151 is the Poliovirus receptor (gene=PVR).
# Let's look closer

# %%
df[(df['unp'] == 'P15151') & np.any(df[pop_pvals]<0.05) & (df['chain']=='A')].sort('seqid')
# Out:
#          isvar  issnp         name  amr_af  asn_af  eur_af  afr_af structid  \
# 8022511      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022544      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022305      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022271      1      0  rs375970875     NaN     NaN     NaN     NaN     4FQP
# 8022372      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022408      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022444      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022480      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022265      1      1  rs200120420  0.0000    0.01       0  0.0041     4FQP
# 8022546      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022307      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022341      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022374      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022410      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022446      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022482      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022514      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022548      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022309      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022342      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022376      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022411      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022447      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022484      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022515      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022549      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022311      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022344      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022378      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022413      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# ...        ...    ...          ...     ...     ...     ...     ...      ...
# 8022286      1      0  rs141402342     NaN     NaN     NaN     NaN     4FQP
# 8022522      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8022297      1      0  rs145179509     NaN     NaN     NaN     NaN     4FQP
# 8022318      0    NaN          NaN     NaN     NaN     NaN     NaN     4FQP
# 8
# %%
# Sort unique proteins by the number of *unique* significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('unp').seqid.nunique()
    uniq.sort(ascending=False)
    print "\n%s: %d unique proteins with significant residues"%(pop_pval,len(uniq))
    uniq.hist()
    plt.show()
    for i,p in enumerate(uniq.index):
        print "%s\t%d\tuniprot.org/uniprot/%s"%(p,uniq[i],p)
# Out:
# AMR_ASN_pval: 27 unique proteins with significant residues
# Q07108	11	uniprot.org/uniprot/Q07108
# P15151	8	uniprot.org/uniprot/P15151
# P47989	6	uniprot.org/uniprot/P47989
# Q495A1	6	uniprot.org/uniprot/Q495A1
# P52292	3	uniprot.org/uniprot/P52292
# P07998	2	uniprot.org/uniprot/P07998
# Q9NRW3	2	uniprot.org/uniprot/Q9NRW3
# P35613	2	uniprot.org/uniprot/P35613
# P09871	2	uniprot.org/uniprot/P09871
# O14732	2	uniprot.org/uniprot/O14732
# P06731	2	uniprot.org/uniprot/P06731
# Q8NHL6	2	uniprot.org/uniprot/Q8NHL6
# O75643	1	uniprot.org/uniprot/O75643
# O43157	1	uniprot.org/uniprot/O43157
# P09917	1	uniprot.org/uniprot/P09917
# P10912	1	uniprot.org/uniprot/P10912
# P11226	1	uniprot.org/uniprot/P11226
# Q9NUI1	1	uniprot.org/uniprot/Q9NUI1
# P18283	1	uniprot.org/uniprot/P18283
# P19652	1	uniprot.org/uniprot/P19652
# P21399	1	uniprot.org/uniprot/P21399
# P49450	1	uniprot.org/uniprot/P49450
# P49862	1	uniprot.org/uniprot/P49862
# Q13426	1	uniprot.org/uniprot/Q13426
# Q8N149	1	uniprot.org/uniprot/Q8N149
# Q8N539	1	uniprot.org/uniprot/Q8N539
# P23946	1	uniprot.org/uniprot/P23946
#
# AMR_EUR_pval: 2 unique proteins with significant residues
# P68431	2	uniprot.org/uniprot/P68431
# P49450	2	uniprot.org/uniprot/P49450
#
# AMR_AFR_pval: 11 unique proteins with significant residues
# Q9UIK4	11	uniprot.org/uniprot/Q9UIK4
# O75473	6	uniprot.org/uniprot/O75473
# Q9UBD6	4	uniprot.org/uniprot/Q9UBD6
# Q7Z4H3	3	uniprot.org/uniprot/Q7Z4H3
# P43250	3	uniprot.org/uniprot/P43250
# Q9NP55	2	uniprot.org/uniprot/Q9NP55
# Q13426	2	uniprot.org/uniprot/Q13426
# Q9NUI1	1	uniprot.org/uniprot/Q9NUI1
# P60022	1	uniprot.org/uniprot/P60022
# P53350	1	uniprot.org/uniprot/P53350
# P01241	1	uniprot.org/uniprot/P01241
#
# ASN_EUR_pval: 33 unique proteins with significant residues
# Q13191	21	uniprot.org/uniprot/Q13191
# Q9Y223	10	uniprot.org/uniprot/Q9Y223
# Q8IV48	10	uniprot.org/uniprot/Q8IV48
# P35968	9	uniprot.org/uniprot/P35968
# P15151	8	uniprot.org/uniprot/P15151
# P13569	6	uniprot.org/uniprot/P13569
# Q6P2F0	6	uniprot.org/uniprot/Q6P2F0
# P50542	6	uniprot.org/uniprot/P50542
# P08684	5	uniprot.org/uniprot/P08684
# Q8N335	5	uniprot.org/uniprot/Q8N335
# Q8IX04	5	uniprot.org/uniprot/Q8IX04
# O00206	4	uniprot.org/uniprot/O00206
# P47989	3	uniprot.org/uniprot/P47989
# P19793	3	uniprot.org/uniprot/P19793
# P23381	2	uniprot.org/uniprot/P23381
# P00749	2	uniprot.org/uniprot/P00749
# Q8NHL6	2	uniprot.org/uniprot/Q8NHL6
# Q460N3	2	uniprot.org/uniprot/Q460N3
# P19320	2	uniprot.org/uniprot/P19320
# P55809	2	uniprot.org/uniprot/P55809
# P62837	2	uniprot.org/uniprot/P62837
# P30566	2	uniprot.org/uniprot/P30566
# P35613	2	uniprot.org/uniprot/P35613
# P28325	1	uniprot.org/uniprot/P28325
# Q16695	1	uniprot.org/uniprot/Q16695
# Q9P0N9	1	uniprot.org/uniprot/Q9P0N9
# Q15013	1	uniprot.org/uniprot/Q15013
# P10912	1	uniprot.org/uniprot/P10912
# Q9BUZ4	1	uniprot.org/uniprot/Q9BUZ4
# P50607	1	uniprot.org/uniprot/P50607
# O75643	1	uniprot.org/uniprot/O75643
# O43157	1	uniprot.org/uniprot/O43157
# P22234	1	uniprot.org/uniprot/P22234
#
# ASN_AFR_pval: 39 unique proteins with significant residues
# P47989	14	uniprot.org/uniprot/P47989
# P34913	11	uniprot.org/uniprot/P34913
# Q07108	11	uniprot.org/uniprot/Q07108
# O75628	10	uniprot.org/uniprot/O75628
# O15382	8	uniprot.org/uniprot/O15382
# P29460	7	uniprot.org/uniprot/P29460
# P40692	7	uniprot.org/uniprot/P40692
# P62805	6	uniprot.org/uniprot/P62805
# Q8N335	5	uniprot.org/uniprot/Q8N335
# Q59EE0	5	uniprot.org/uniprot/Q59EE0
# Q14849	5	uniprot.org/uniprot/Q14849
# O94829	5	uniprot.org/uniprot/O94829
# Q01970	5	uniprot.org/uniprot/Q01970
# Q86SE8	5	uniprot.org/uniprot/Q86SE8
# Q16853	4	uniprot.org/uniprot/Q16853
# P40926	4	uniprot.org/uniprot/P40926
# Q9NS87	3	uniprot.org/uniprot/Q9NS87
# P01574	3	uniprot.org/uniprot/P01574
# P15151	3	uniprot.org/uniprot/P15151
# Q9UBR2	3	uniprot.org/uniprot/Q9UBR2
# Q9UBD6	3	uniprot.org/uniprot/Q9UBD6
# P13726	2	uniprot.org/uniprot/P13726
# Q6P179	2	uniprot.org/uniprot/Q6P179
# P06731	2	uniprot.org/uniprot/P06731
# P07998	2	uniprot.org/uniprot/P07998
# P09871	2	uniprot.org/uniprot/P09871
# P10912	2	uniprot.org/uniprot/P10912
# P51161	2	uniprot.org/uniprot/P51161
# P15289	2	uniprot.org/uniprot/P15289
# P12821	1	uniprot.org/uniprot/P12821
# P22234	1	uniprot.org/uniprot/P22234
# P10147	1	uniprot.org/uniprot/P10147
# P16444	1	uniprot.org/uniprot/P16444
# P19652	1	uniprot.org/uniprot/P19652
# Q8N371	1	uniprot.org/uniprot/Q8N371
# Q13546	1	uniprot.org/uniprot/Q13546
# O75643	1	uniprot.org/uniprot/O75643
# Q8N539	1	uniprot.org/uniprot/Q8N539
# P20813	1	uniprot.org/uniprot/P20813
#
# EUR_AFR_pval: 29 unique proteins with significant residues
# P15151	18	uniprot.org/uniprot/P15151
# O00625	14	uniprot.org/uniprot/O00625
# P01130	12	uniprot.org/uniprot/P01130
# Q59FQ1	11	uniprot.org/uniprot/Q59FQ1
# P00749	10	uniprot.org/uniprot/P00749
# P20813	8	uniprot.org/uniprot/P20813
# P50542	7	uniprot.org/uniprot/P50542
# Q8TBC4	7	uniprot.org/uniprot/Q8TBC4
# Q86SE8	7	uniprot.org/uniprot/Q86SE8
# P08581	7	uniprot.org/uniprot/P08581
# Q5SWW9	6	uniprot.org/uniprot/Q5SWW9
# O00294	5	uniprot.org/uniprot/O00294
# Q53XS3	5	uniprot.org/uniprot/Q53XS3
# Q13564	5	uniprot.org/uniprot/Q13564
# P03956	4	uniprot.org/uniprot/P03956
# Q96BT7	3	uniprot.org/uniprot/Q96BT7
# P21695	3	uniprot.org/uniprot/P21695
# P19793	3	uniprot.org/uniprot/P19793
# P62805	2	uniprot.org/uniprot/P62805
# P23381	2	uniprot.org/uniprot/P23381
# P19801	2	uniprot.org/uniprot/P19801
# P55809	2	uniprot.org/uniprot/P55809
# P13726	2	uniprot.org/uniprot/P13726
# Q16773	1	uniprot.org/uniprot/Q16773
# O95684	1	uniprot.org/uniprot/O95684
# Q13231	1	uniprot.org/uniprot/Q13231
# Q16647	1	uniprot.org/uniprot/Q16647
# Q02790	1	uniprot.org/uniprot/Q02790
# Q9H9A7	1	uniprot.org/uniprot/Q9H9A7

# %%
df[(df['unp']=='P15151') & (df['EUR_AFR_pval']<0.05)].sort('seqid')[['structid','unp','chain','seqid']]

# %%
# Now, let's do the same, but sorted by structid instead of protein
# Sort unique proteins by the number of *unique* significant spheres
for pop_pval in pop_pvals:
    tdf = df[df[pop_pval]<0.05]
    uniq = tdf.groupby('structid').seqid.nunique()
    uniq.sort(ascending=False)
    print "\n%s: %d unique structures with significant residues"%(pop_pval,len(uniq))
    uniq.hist()
    plt.show()
    for i,p in enumerate(uniq.index):
        print "%s\t%d"%(p,uniq[i])

# %%
df[(df['structid']=='1NN8') & (df['ASN_EUR_pval']<0.05)]
# Out:
#          isvar  issnp name  amr_af  asn_af  eur_af  afr_af structid chain  \
# 4021200      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4021221      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021236      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021268      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021296      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4021300      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021351      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021359      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4021463      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021466      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4021471      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4021477      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4021497      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021514      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4021546      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021620      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4021751      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4021807      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4021911      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4021918      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022168      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022182      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022237      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4022293      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4022309      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022411      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     S
# 4022443      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022464      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022479      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4022481      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# ...        ...    ...  ...     ...     ...     ...     ...      ...   ...
# 4067453      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     T
# 4067467      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4067483      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4067621      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8     R
# 4067702      0    NaN  NaN     NaN     NaN     NaN     NaN     1NN8