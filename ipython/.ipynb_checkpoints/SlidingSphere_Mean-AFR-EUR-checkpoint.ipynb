# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import glob,gzip
import numpy as np
from numpy.random import randn
import random
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)

# %%
# Load the results file into a pandas data frame
fnames = glob.glob('results/sliding_sphere_10/split/obs/bystruct/*.txt.gz')
rlist  = [[r.split('-')[0][-4:],r.split('-')[1].split('.')[0]] for r in fnames]
rdf    = pd.DataFrame(rlist,columns=['structid','biounit'])
dfs,dfsigs = [],[]
# cols =  ['structid','chain','seqid','afr_count','eur_count','afr_cdaf']
# cols += ['eur_cdaf','afr_eur_meanddaf','afr_eur_meanddaf_pval']
cols = [10,11,12,13,14,15,16,20,21,24,25,77,145]
for fname in fnames:
    # Load only the relevant columns
    df    = pd.read_table(gzip.open(fname,'rb'),delimiter='\t',header=0,usecols=cols)
    df.drop_duplicates(subset=['x','y','z'],inplace=True) # remove duplicate residues
    # Create one dataframe containing only the significant spheres
    dfsig = df[df['eur_afr_meanddaf_pval']<0.05]
    # Sample a maximum of 1,500 (99th percentile) observed spheres from the structure
    if len(df) > 1500:
        df    = df.ix[random.sample(df.index,1500)]
    dfs.append(df)
    dfsigs.append(dfsig)
# Review final df for correctness
# Create the final observation dataframe
df    = pd.concat(dfs)
df    = pd.merge(df,rdf,on='structid')
# Create the final significant dataframe
dfsig = pd.concat(dfsigs)
dfsig = pd.merge(dfsig,rdf,on='structid')
# Cleanup the temporary lists
del dfs,dfsigs

# %%
# Well shit, I just deleted several cells on accident, and ipython notebook only lets you undo a single action.
# Not a huge loss at least, it was just the same code as above, but for permutations, and that code wasn't
# working well anyway. I'm not sure what I need to do, but this data is too large to be plotting effectively.
# Perhaps I can iteratively build the plot as I read and discard the structures?

# %%
# Plot KDE histograms stratified by permutation, observed, significant
# I'll probably need to sample from the permutation set
# I'll start with just the observed/significant values
# plt.figure(figsize=(20,6))
# sns.distplot(dfp['eur_afr_meanddaf'],  color='black',label='permutation')
# sns.distplot(df['eur_afr_meanddaf'],   color='blue', label='observed')
# sns.distplot(dfsig['eur_afr_meanddaf'],color='red',  label='significant')
# plt.xlim([-1,1])
# plt.ylim([0,20000]) # You stop getting meaningful distinction near 0

# %%
# We no longer need the non-significant spheres, so clean up the memory
# raise Exception('')
# del df,dfp

# %%
# # List the proteins with the *greatest number of* significant spheres for count, cDAF, and ΔDAF, stratified by population
# for colset in nest_pval_cols:
#     ndf = []
#     for col in colset:
#         dfc = df[df[col]<0.05].groupby('structid').size()
#         dfc.sort()
#         print "%s  %s"%(col,' | '.join(["%s: %.2f"%(sid,cnt) for sid,cnt in dfc.tail(5).iteritems()][::-1]))
#     print ''

# %%
# # List the proteins with the *most extremely* significant spheres for count, cDAF, and ΔDAF, stratified by population
# for i,colset in enumerate(nest_pval_cols):
#     ndf = []
#     for j,col in enumerate(colset):
#         dfc = df[df[col]<0.05].groupby('structid').min().sort([col,nest_cols[i][j]],ascending=[True,False]).head(5)
#         print "%s  %s"%(col,' | '.join(["%s: %2.2f, p≤%1.1e"%(sid,val,pval) for sid,_,pval,val in dfc.ix[:,["structid",col,nest_cols[i][j]]].itertuples()]))
#     print ''

# %%
# Convert the sort-columns to Z-scores
metric = 'eur_afr_meanddaf'
zmetric = (df[metric] - df[metric].mean())/df[metric].std(ddof=0)
# Maximum possible unique variants in sphere (sum of possibly overlapping counts)
varcnt = np.maximum(df['eur_count'],df['afr_count'])
print varcnt.shape
# Z-normalize and add to the dataframe
zvarcnt = (varcnt - varcnt.mean())/varcnt.std(ddof=0)
del varcnt
# Out:
# (20186685,)

# %%
plt.figure(figsize=(20,6))
x = zmetric * zvarcnt
x.sort()
plt.plot(x.unique(),color='blue')
x = zmetric + zvarcnt
x.sort()
# From this plot, I think that zmeteric*zvarcnt does a better job at distinguishably ranking the results
# It also more heavily weights spheres with large numbers of variants in the sphere
plt.plot(x.unique(),color='red')

# %%
# Top scoring - EUR selected Structures
metric = 'eur_afr_meanddaf'
pval   = 'eur_afr_meanddaf_pval'
zsorteur = zmetric * zvarcnt # larger positive values of zmetric indicate European selection
df['zsorteur'] = zsorteur

# dfc = df[df[pval]<0.05].sort([metric,'afr_count','eur_count'],ascending=[True,False,False])
dfc = df[df[pval]<0.05].sort('zsorteur',ascending=False)

top_20_structs,i,keys = dict(),0,[]
while len(top_20_structs) < 20:
    sid = dfc.iloc[i].structid
    if sid not in top_20_structs:
        top_20_structs[sid] = 1
        keys.append(sid)
    else:
        top_20_structs[sid] += 1
    i+= 1
# Structures ordered by the rank of their highest-ranking sphere
# Counts are for all spheres with a higher rank than the final sphere considered
for key in keys:
    print key,top_20_structs[key]

dfc = dfc.head(100)

print "%s\n%s"%(metric,'\n'.join(["%s:%d.%s (%s): %2.4f, p≤%1.1e afr=%d eur=%d"%(sid,seqid,chain,unp,val,pval,afr,eur) for _,sid,seqid,chain,unp,pval,val,afr,eur in dfc.ix[:,["structid",'seqid','chain','unp',pval,metric,'afr_count','eur_count']].itertuples()]))
# Out:
# 3D34 6
# 4LLA 18
# 1PL8 8
# 2VCT 12
# 2WJU 24
# 4ACS 8
# 2Q7Z 3
# 2YF0 4
# 4FXG 6
# 1J7E 3
# 1J78 12
# 1MA9 3
# 1KW2 3
# 1LOT 3
# 1KXP 4
# 2Z7X 5
# 3IUY 2
# 1UGN 1
# 2DNF 1
# 2XPG 1
# eur_afr_meanddaf
# 3D34:113.A (Q9BUD6): 0.2720, p≤2.0e-03 afr=5 eur=5
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 1J78:418.B (P02774): 0.3300, p≤1.9e-02 afr=2 eur=2

# %%
# Top Scoring - AFR selected Structures
metric = 'eur_afr_meanddaf'
pval   = 'eur_afr_meanddaf_pval'
zsortafr = -zmetric * zvarcnt # larger negative values of zmetric indicate African selection
df['zsortafr'] = zsortafr

dfc = df[df[pval]<0.05].sort('zsortafr',ascending=False)
# dfc = df[df[pval]<0.05].sort([metric,'afr_count','eur_count'],ascending=[False,False,False])

top_20_structs,i,keys = dict(),0,[]
while len(top_20_structs) < 20:
    sid = dfc.iloc[i].structid
    if sid not in top_20_structs:
        top_20_structs[sid] = 1
        keys.append(sid)
    else:
        top_20_structs[sid] += 1
    i+= 1
# Structures ordered by the rank of their highest-ranking sphere
# Counts are for all spheres with a higher rank than the final sphere considered
for key in keys:
    print key,top_20_structs[key]

dfc = dfc.head(100)

print "%s\n%s"%(metric,'\n'.join(["%s:%d.%s (%s): %2.4f, p≤%1.1e afr=%d eur=%d"%(sid,seqid,chain,unp,val,pval,afr,eur) for _,sid,seqid,chain,unp,pval,val,afr,eur in dfc.ix[:,["structid",'seqid','chain','unp',pval,metric,'afr_count','eur_count']].itertuples()]))
# Out:
# 3Q2C 16
# 1W14 4
# 4GLY 4
# 3M61 4
# 1LMW 8
# 1W13 4
# 3OY6 4
# 4JNL 4
# 1C5W 4
# 1GI7 4
# 1GI8 4
# 3KGP 4
# 2VIV 4
# 3MWI 4
# 2VIW 4
# 1G91 1
# 3CHN 3
# 2OCW 6
# 1VJA 2
# 3IG6 1
# eur_afr_meanddaf
# 3Q2C:3.A (Q8N6C8): -0.1802, p≤1.6e-02 afr=4 eur=2
# 3Q2C:4.A (Q8N6C8): -0.1802, p≤6.0e-03 afr=4 eur=2
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 3M61:60.U (P00749): -0.1800, p≤3.7e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1W13:60.U (P00749): -0.1800, p≤2.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 1GJ7:60.B (P00749): -0.1440, p≤4.1e-02 afr=4 eur=0
# 1GJ7:60.B (P00749): -0.1440, p≤4.1e-02 afr=4 eur=0
# 4H42:58.U (P00749): -0.1440, p≤4.4e-02 afr=4 eur=0
# 4MNY:60.A (P00749): -0.1440, p≤2.7e-02 afr=4 eur=0
# 4MNX:60.A (P00749): -0.1440, p≤4.0e-02 afr=4 eur=0

# %%
# Top scoring - EUR selected Proteins
metric = 'eur_afr_meanddaf'
pval   = 'eur_afr_meanddaf_pval'
zsorteur = zmetric * zvarcnt # larger positive values of zmetric indicate European selection
df['zsorteur'] = zsorteur

dfc = df[df[pval]<0.05].sort('zsorteur',ascending=False)

top_20_prots,i,keys = dict(),0,[]
while len(top_20_prots) < 20:
    unp = dfc.iloc[i].unp
    if unp not in top_20_prots:
        top_20_prots[unp] = set([dfc.iloc[i].seqid])
        keys.append(unp)
    else:
        top_20_prots[unp].add(dfc.iloc[i].seqid)
    i+= 1
# Structures ordered by the rank of their highest-ranking sphere
# Counts are for all spheres with a higher rank than the final sphere considered
for key in keys:
    print key,len(top_20_prots[key])

dfc = dfc.head(100)

print "%s\n%s"%(metric,'\n'.join(["%s:%d.%s (%s): %2.4f, p≤%1.1e afr=%d eur=%d"%(sid,seqid,chain,unp,val,pval,afr,eur) for _,sid,seqid,chain,unp,pval,val,afr,eur in dfc.ix[:,["structid",'seqid','chain','unp',pval,metric,'afr_count','eur_count']].itertuples()]))
# Out:
# Q9BUD6 3
# Q8N423 12
# Q00796 2
# P09210 12
# P17927 5
# Q9Y217 12
# O00187 9
# P02774 7
# Q15399 19
# Q86TM3 1
# Q8NHL6 1
# Q9UHG0 1
# P04439 1
# Q68J44 9
# P24855 1
# P52789 15
# P02788 1
# P08603 19
# P15848 4
# Q6ZMJ4 1
# eur_afr_meanddaf
# 3D34:113.A (Q9BUD6): 0.2720, p≤2.0e-03 afr=5 eur=5
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.C (Q8N423): 0.2597, p≤3.9e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.A (Q8N423): 0.2597, p≤4.6e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 4LLA:105.B (Q8N423): 0.2597, p≤4.2e-02 afr=4 eur=2
# 1PL8:221.D (Q00796): 0.4700, p≤3.5e-02 afr=2 eur=2
# 1PL8:220.A (Q00796): 0.4700, p≤3.5e-02 afr=2 eur=2
# 1PL8:220.A (Q00796): 0.4700, p≤3.5e-02 afr=2 eur=2
# 1PL8:220.D (Q00796): 0.4700, p≤3.8e-02 afr=2 eur=2
# 1PL8:221.A (Q00796): 0.4700, p≤3.5e-02 afr=2 eur=2
# 4LLA:104.B (Q8N423): 0.2696, p≤3.1e-02 afr=3 eur=2
# 4LLA:104.B (Q8N423): 0.2696, p≤3.1e-02 afr=3 eur=2
# 4LLA:104.B (Q8N423): 0.2696, p≤3.1e-02 afr=3 eur=2
# 4LLA:104.C (Q8N423): 0.2696, p≤3.0e-02 afr=3 eur=2
# 4LLA:104.A (Q8N423): 0.2696, p≤4.4e-02 afr=3 eur=2
# 4LLA:104.A (Q8N423): 0.2696, p≤4.4e-02 afr=3 eur=2
# 4LLA:104.A (Q8N423): 0.2696, p≤4.4e-02 afr=3 eur=2
# 3D34:113.B (Q9BUD6): 0.1840, p≤4.0e-03 afr=4 eur=4
# 3D34:16.B (Q9BUD6): 0.1750, p≤1.2e-02 afr=4 eur=4
# 3D34:16.A (Q9BUD6): 0.1750, p≤1.0e-03 afr=4 eur=4
# 2Q7Z:1565.A (P17927): 0.2227, p≤1.9e-02 afr=3 eur=3
# 2YF0:350.A (Q9Y217): 0.3440, p≤1.7e-02 afr=2 eur=1
# 2YF0:350.A (Q9Y217): 0.3440, p≤1.7e-02 afr=2 eur=1
# 2YF0:483.A (Q9Y217): 0.3440, p≤2.6e-02 afr=2 eur=1
# 2YF0:483.A (Q9Y217): 0.3440, p≤2.6e-02 afr=2 eur=1
# 4FXG:373.G (O00187): 0.3407, p≤1.9e-02 afr=1 eur=2
# 4FXG:373.G (O00187): 0.3407, p≤1.9e-02 afr=1 eur=2
# 4FXG:374.G (O00187): 0.3407, p≤2.7e-02 afr=1 eur=2
# 4FXG:374.G (O00187): 0.3407, p≤2.7e-02 afr=1 eur=2
# 4FXG:373.I (O00187): 0.3407, p≤1.9e-02 afr=1 eur=2
# 4FXG:373.I (O00187): 0.3407, p≤1.9e-02 afr=1 eur=2
# 1J7E:418.B (P02774): 0.3300, p≤3.2e-02 afr=2 eur=2
# 1J78:417.B (P02774): 0.3300, p≤2.0e-02 afr=2 eur=2
# 1J78:418.A (P02774): 0.3300, p≤1.9e-02 afr=2 eur=2
# 1J78:418.A (P02774): 0.3300, p≤1.9e-02 afr=2 eur=2
# 1MA9:417.A (P02774): 0.3300, p≤1.8e-02 afr=2 eur=2
# 1MA9:418.A (P02774): 0.3300, p≤2.3e-02 afr=2 eur=2
# 1J78:421.A (P02774): 0.3300, p≤2.1e-02 afr=2 eur=2
# 1J78:421.A (P02774): 0.3300, p≤2.1e-02 afr=2 eur=2
# 1J78:417.B (P02774): 0.3300, p≤2.0e-02 afr=2 eur=2
# 1J78:418.B (P02774): 0.3300, p≤1.9e-02 afr=2 eur=2
# 1MA9:421.A (P02774): 0.3300, p≤2.1e-02 afr=2 eur=2
# 1KW2:433.B (P02774): 0.3300, p≤1.7e-02 afr=2 eur=2
# 1J78:418.B (P02774): 0.3300, p≤1.9e-02 afr=2 eur=2

# %%
# Top scoring - EUR selected Proteins
metric = 'eur_afr_meanddaf'
pval   = 'eur_afr_meanddaf_pval'
zsorteur = -zmetric * zvarcnt # larger negative values of zmetric indicate African selection
df['zsorteur'] = zsorteur

dfc = df[df[pval]<0.05].sort('zsorteur',ascending=False)

top_20_prots,i,keys = dict(),0,[]
while len(top_20_prots) < 20:
    unp = dfc.iloc[i].unp
    if unp not in top_20_prots:
        top_20_prots[unp] = set([dfc.iloc[i].seqid])
        keys.append(unp)
    else:
        top_20_prots[unp].add(dfc.iloc[i].seqid)
    i+= 1
# Structures ordered by the rank of their highest-ranking sphere
# Counts are for all spheres with a higher rank than the final sphere considered
for key in keys:
    print key,len(top_20_prots[key])

dfc = dfc.head(100)

print "%s\n%s"%(metric,'\n'.join(["%s:%d.%s (%s): %2.4f, p≤%1.1e afr=%d eur=%d"%(sid,seqid,chain,unp,val,pval,afr,eur) for _,sid,seqid,chain,unp,pval,val,afr,eur in dfc.ix[:,["structid",'seqid','chain','unp',pval,metric,'afr_count','eur_count']].itertuples()]))
# Out:
# Q8N6C8 16
# P00749 3
# P55773 5
# P01833 8
# Q5SWW9 6
# Q5SWW8 4
# P04275 36
# P36952 26
# P17927 5
# Q00796 2
# Q9UHN1 11
# P08107 12
# Q5JQI4 9
# P11413 1
# Q96NA2 1
# Q8IVS2 11
# Q86SG5 4
# Q16548 4
# Q9P1W8 6
# P08922 1
# eur_afr_meanddaf
# 3Q2C:3.A (Q8N6C8): -0.1802, p≤1.6e-02 afr=4 eur=2
# 3Q2C:4.A (Q8N6C8): -0.1802, p≤6.0e-03 afr=4 eur=2
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 1W14:60.U (P00749): -0.1800, p≤3.0e-02 afr=4 eur=0
# 3M61:60.U (P00749): -0.1800, p≤3.7e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 4GLY:60.A (P00749): -0.1800, p≤4.7e-02 afr=4 eur=0
# 1W13:60.U (P00749): -0.1800, p≤2.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 3OY6:60.U (P00749): -0.1800, p≤3.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 1LMW:60.D (P00749): -0.1800, p≤4.5e-02 afr=4 eur=0
# 4JNL:60.U (P00749): -0.1800, p≤4.8e-02 afr=4 eur=0
# 4JNL:60.U (P00749): -0.1800, p≤4.8e-02 afr=4 eur=0
# 4JNL:60.U (P00749): -0.1800, p≤4.8e-02 afr=4 eur=0
# 3Q2C:83.A (Q8N6C8): -0.2396, p≤3.0e-02 afr=3 eur=2
# 3Q2C:82.A (Q8N6C8): -0.2396, p≤3.1e-02 afr=3 eur=2
# 3Q2C:2.A (Q8N6C8): -0.2396, p≤8.0e-03 afr=3 eur=2
# 3Q2C:84.A (Q8N6C8): -0.2396, p≤3.1e-02 afr=3 eur=2
# 3Q2C:78.A (Q8N6C8): -0.2373, p≤2.8e-02 afr=3 eur=1
# 3Q2C:77.A (Q8N6C8): -0.2373, p≤1.3e-02 afr=3 eur=1
# 3Q2C:76.A (Q8N6C8): -0.3550, p≤4.0e-03 afr=2 eur=1
# 3Q2C:79.A (Q8N6C8): -0.3550, p≤2.1e-02 afr=2 eur=1
# 3Q2C:87.A (Q8N6C8): -0.3550, p≤1.5e-02 afr=2 eur=1
# 1G91:27.A (P55773): -0.3421, p≤1.3e-02 afr=2 eur=1
# 3CHN:559.S (P01833): -0.7100, p≤4.0e-03 afr=1 eur=1
# 2OCW:563.A (P01833): -0.7100, p≤7.0e-03 afr=1 eur=1
# 2OCW:564.A (P01833): -0.7100, p≤7.0e-03 afr=1 eur=1
# 3CHN:553.S (P01833): -0.7100, p≤8.0e-03 afr=1 eur=1
# 3CHN:560.S (P01833): -0.7100, p≤7.0e-03 afr=1 eur=1
# 2OCW:562.A (P01833): -0.7100, p≤6.0e-03 afr=1 eur=1
# 2OCW:561.A (P01833): -0.7100, p≤1.0e-02 afr=1 eur=1
# 2OCW:560.A (P01833): -0.7100, p≤8.0e-03 afr=1 eur=1
# 2OCW:565.A (P01833): -0.7100, p≤7.0e-03 afr=1 eur=1
# 3Q2C:34.A (Q8N6C8): -0.7000, p≤8.0e-03 afr=1 eur=1
# 3Q2C:80.A (Q8N6C8): -0.7000, p≤2.0e-02 afr=1 eur=1
# 3Q2C:81.A (Q8N6C8): -0.7000, p≤2.6e-02 afr=1 eur=1
# 1VJA:60.U (P00749): -0.1440, p≤3.9e-02 afr=4 eur=0
# 1VJA:60.U (P00749): -0.1440, p≤3.9e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 3IG6:60.B (Q5SWW9): -0.1440, p≤2.2e-02 afr=4 eur=0
# 1GJ7:60.B (P00749): -0.1440, p≤4.1e-02 afr=4 eur=0
# 1GJ7:60.B (P00749): -0.1440, p≤4.1e-02 afr=4 eur=0
# 4H42:58.U (P00749): -0.1440, p≤4.4e-02 afr=4 eur=0
# 4MNY:60.A (P00749): -0.1440, p≤2.7e-02 afr=4 eur=0
# 4MNX:60.A (P00749): -0.1440, p≤4.0e-02 afr=4 eur=0
