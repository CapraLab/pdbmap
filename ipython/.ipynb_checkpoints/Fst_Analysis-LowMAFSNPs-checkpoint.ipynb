# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# [Errno 2] No such file or directory: '../../pdbmap'
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import glob,gzip,os,operator
import numpy as np
from numpy.random import randn
from itertools import combinations
import random
import pandas as pd
from scipy import stats
from scipy.spatial import KDTree
from sklearn.metrics import confusion_matrix
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patheffects as PathEffects
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Summary
# NOTE: The SNPs used for this analysis were required to have an individual MAF below 0.05
#
# This is a comparison of which genes are marked as significant by various binning methods. A bin will be called significant if it contains at least 3 nsSNPs and has an Fst greater than 0.05. A second comparison will require an Fst > 0.15.

# %%
def conf_matrix(ax,grp1,grp2,lab1,lab2):
    # Calculate the confusion matrix
    grp1,grp2 = grp1.align(grp2,join="outer",axis=0)
    grp1 = grp1.fillna(False)
    grp2 = grp2.fillna(False)
    if not (grp1 & grp2).sum():
        cm = np.zeros((2,2))
        cm[0][0] = len(grp1)
    else:
        cm = confusion_matrix(grp1,grp2)
    ax.text(0,0,'{0:,}'.format(cm[0][0]),fontsize=40,horizontalalignment='center',verticalalignment='center',color='white',path_effects=[PathEffects.withStroke(linewidth=3,foreground="black")])
    ax.text(0,1,'{0:,}'.format(cm[1][0]),fontsize=40,horizontalalignment='center',verticalalignment='center',color='white',path_effects=[PathEffects.withStroke(linewidth=3,foreground="black")])
    ax.text(1,0,'{0:,}'.format(cm[0][1]),fontsize=40,horizontalalignment='center',verticalalignment='center',color='white',path_effects=[PathEffects.withStroke(linewidth=3,foreground="black")])
    ax.text(1,1,'{0:,}'.format(cm[1][1]),fontsize=40,horizontalalignment='center',verticalalignment='center',color='white',path_effects=[PathEffects.withStroke(linewidth=3,foreground="black")])
    cm[0][0] = 0 # improve visualization of significant agreement/disagreement
    # Show confusion matrix in a separate window
    ax.imshow(cm,cmap=plt.cm.jet,interpolation='nearest')
#     ax.set_title("%s vs %s"%(lab1,lab2),fontsize=35)
    ax.set_ylabel(lab1,fontsize=30)
    ax.set_xlabel(lab2,fontsize=30)
    ax.set_xlim([-0.5,1.5])
    ax.set_ylim([-0.5,1.5])
    ax.set_xticks([0,1])
    ax.set_yticks([0,1])
    ax.set_xticklabels(["Not Significant","Significant"])
    ax.set_yticklabels(["Not Significant","Significant"],rotation='vertical')
    ax.grid(False,'both','both')

# %%
def unlist_col(col):
    return [str(c).split(',') for c in col]

# %%
resdir = "/Volumes/sivleyrm/pdbmap/results/fst_analysis_maf-lt-05_20150615"
shcols = ["fst","nsnp","snplist","maflist","fstlist","unpac","hgnc"]
def load_fst(metric,unq_cols):
    df = pd.read_csv("%s/fst_by_%s.txt"%(resdir,metric),sep=" ",header=None,names=unq_cols+shcols)
    df["snplist"] = unlist_col(df["snplist"])
    df["maflist"] = unlist_col(df["maflist"])
    df["fstlist"] = unlist_col(df["fstlist"])
    df.sort("unpac")
    print "%d %s bins"%(len(df),metric)
    return df

# %%
fst_by_gene   = load_fst("gene",["gene"])
# Out:
# 4712 gene bins

# %%
# fst_by_unp    = load_fst("uniprot",["unp"])

# %%
fst_by_pfam   = load_fst("pfam",["gene","pfam"])
# Out:
# 6012 pfam bins

# %%
fst_by_ipfam  = load_fst("ipfam",["gene","pfamblock"])
# Out:
# 4928 ipfam bins

# %%
fst_by_scop   = load_fst("scop",["gene","scop"])
# Out:
# 4912 scop bins

# %%
fst_by_iscop  = load_fst("iscop",["gene","scopblock"])
# Out:
# 4858 iscop bins

# %%
# fst_by_sec    = load_fst("secondary",["structid","biounit","ss"])

# %%
fst_by_isec   = load_fst("isecondary",["structid","biounit","ssblock"])
# Out:
# 36024 isecondary bins

# %%
fst_by_sphere = load_fst("sphere",["structid","biounit","model","chain","seqid"])
# Out:
# 69101 sphere bins

# %%
# fst_grp = [fst_by_gene,fst_by_unp,fst_by_pfam,fst_by_ipfam,fst_by_scop,fst_by_iscop,fst_by_isec,fst_by_sphere]
# fst_grp = [fst_by_gene,fst_by_pfam,fst_by_ipfam,fst_by_scop,fst_by_iscop,fst_by_isec,fst_by_sphere]
fst_grp = [fst_by_gene,fst_by_pfam,fst_by_scop,fst_by_isec,fst_by_sphere]

# %%
# fst_labs = ["by-gene","by-pfam","by-ipfam","by-scop","by-iscop","by-iss","by-sphere"]
fst_labs = ["by-gene","by-pfam","by-scop","by-iss","by-sphere"]

# %%
# Number of genes covered by each method
for i,fst in enumerate(fst_grp):
    print "%8s\t%2.2f"%(fst_labs[i],len(fst.groupby("unpac")))
# Out:
#  by-gene	3544.00
#  by-pfam	3117.00
#  by-scop	3143.00
#   by-iss	3427.00
# by-sphere	3550.00

# %%
# Average SNP count per metric
for i,fst in enumerate(fst_grp):
    print "%8s\t%2.2f"%(fst_labs[i],fst["nsnp"].mean())
# Out:
#  by-gene	9.66
#  by-pfam	6.23
#  by-scop	8.17
#   by-iss	1.50
# by-sphere	2.39

# %%
# Disregard bins with fewer than 2 SNPs
fst_grp = [fst[fst["nsnp"]>1] for fst in fst_grp]

# %%
# Average SNP count per metric
for i,fst in enumerate(fst_grp):
    print "%8s\t%2.2f"%(fst_labs[i],fst["nsnp"].mean())
# Out:
#  by-gene	10.71
#  by-pfam	7.23
#  by-scop	9.03
#   by-iss	2.79
# by-sphere	3.15

# %%
# Mean percent difference in maximum Fst and bin Fst
print "Mean Percent Difference Between Max Individual Fst and Binned Fst"
fst_diff = [np.mean((fst["fst"]-fst["fstlist"].apply(max).astype(np.float64))/fst["fst"]) for fst in fst_grp]
print "Method  \tPerDiff\tnSNPs"
for i,diff in enumerate(fst_diff):
    print "%8s\t% 0.2f\t%0.2f"%(fst_labs[i],diff,fst_grp[i]["nsnp"].mean())
# Out:
# Mean Percent Difference Between Max Individual Fst and Binned Fst
# Method  	PerDiff	nSNPs
#  by-gene	 0.24	10.71
#  by-pfam	 0.11	7.23
#  by-scop	 0.35	9.03
#   by-iss	-0.10	2.79
# by-sphere	-0.02	3.15

# %%
# For each gene, determine if it contains a significant bin
sig_grp = [fst.groupby("unpac").apply(lambda x: len(x[x["fst"]>0.05])>0) for fst in fst_grp]

# %%
# Generate an 8x8 confusion matrix
# Calculate the confusion matrix
fig,axes = plt.subplots(len(sig_grp),len(sig_grp),figsize=(50,50))
for i,grp1 in enumerate(sig_grp):
    for j,grp2 in enumerate(sig_grp):
        if j <= i:
            conf_matrix(axes[i][j],grp1,grp2,fst_labs[i],fst_labs[j])
        else:
            axes[i][j].set_frame_on(False)
            axes[i][j].axes.get_xaxis().set_visible(False)
            axes[i][j].axes.get_yaxis().set_visible(False)
plt.tight_layout()

# %%
# For each gene, determine if it contains a significant bin
sig_grp = [fst.groupby("unpac").apply(lambda x: len(x[x["fst"]>0.15])>0) for fst in fst_grp]

# %%
# Generate an 8x8 confusion matrix
# Calculate the confusion matrix
fig,axes = plt.subplots(len(sig_grp),len(sig_grp),figsize=(50,50))
for i,grp1 in enumerate(sig_grp):
    for j,grp2 in enumerate(sig_grp):
        if j <= i:
            conf_matrix(axes[i][j],grp1,grp2,fst_labs[i],fst_labs[j])
        else:
            axes[i][j].set_frame_on(False)
            axes[i][j].axes.get_xaxis().set_visible(False)
            axes[i][j].axes.get_yaxis().set_visible(False)
plt.tight_layout()

# %%
fst_by_sphere[(fst_by_sphere["nsnp"]>2) & (fst_by_sphere["fst"]>0.15)].sort(["structid","biounit"])
# Out:
#       structid  biounit  model chain  seqid       fst  nsnp  \
# 15531     1F3U        3      1     F     61  0.153685     3
# 8660      1V82        1      1     B    131  0.155143     3
# 8662      1V82        1      1     B    132  0.154525     3
# 20136     2C35        1      1     B    135  0.161748     3
# 36041     2RKB        1      1     B    289  0.158691     5
# 36042     2RKB        1      1     A    289  0.158691     5
# 36043     2RKB        1      1     B    291  0.161145     3
# 36044     2RKB        1      1     A    291  0.161145     3
# 36045     2RKB        1      1     B    293  0.161145     3
# 36046     2RKB        1      1     A    293  0.161145     3
# 15499     3FE4        2      1     B     57  0.153058     3
# 15500     3FE4        2      1     B     58  0.153058     3
# 17885     3NVQ        1      1     E    515  0.160700     3
# 17886     3NVQ        1      1     A    515  0.160700     3
# 17887     3NVQ        1      1     E    516  0.160700     3
# 17888     3NVQ        1      1     A    516  0.160700     3
# 17889     3NVQ        1      1     E    517  0.160700     3
# 17890     3NVQ        1      1     A    517  0.160700     3
# 25561     3NVQ        1      1     E    515  0.160700     3
# 25562     3NVQ        1      1     A    515  0.160700     3
# 25563     3NVQ        1      1     E    516  0.160700     3
# 25564     3NVQ        1      1     A    516  0.160700     3
# 25565     3NVQ        1      1     E    517  0.160700     3
# 25566     3NVQ        1      1     A    517  0.160700     3
# 20257     4DOH        1      1     R     43  0.160996     4
# 20260     4DOH        1      1     R    126  0.161748     3
# 64432     4DOH        1      1     R     43  0.161745     3
# 64435     4DOH        1      1     R    126  0.161748     3
# 29939     4LLA        1      1     A    131  0.351125     3
# 29940     4LLA        1      1     A    132  0.344290     4
#
#                                                  snplist  \
# 15531   [rs58800854, chr19:6389600-6389601, rs140431319]
# 8660   [chr4:1803470-1803471, rs35434644, chr11:13425...
# 8662   [rs150916178, rs35434644, chr11:134253800-1342...
# 20136            [rs151250126, rs199954231, rs191996643]
# 36041  [chr12:113865876-113865877, rs140833562, rs150...
# 36042  [chr12:113865876-113865877, rs140833562, rs150...
# 36043            [rs150420059, rs146573098, rs199858173]
# 36044            [rs150420059, rs199858173, rs146573098]
# 36045            [rs150420059, rs146573098, rs199858173]
# 36046            [rs150420059, rs199858173, rs146573098]
# 15499             [rs200886584, rs58800854, rs140431319]
# 15500   [rs200886584, rs58800854, chr19:6389600-6389601]
# 17885   [rs741761, chr15:74703927-74703928, rs200894892]
# 17886   [chr15:74703927-74703928, rs741761, rs200894892]
# 17887   [rs741761, chr15:74703927-74703928, rs200894892]
# 17888   [chr15:74703927-74703928, rs741761, rs200894892]
# 17889   [rs741761, chr15:74703927-74703928, rs200894892]
# 17890   [chr15:74703927-74703928, rs741761, rs200894892]
# 25561   [rs741761, chr15:74703927-74703928, rs200894892]
# 25562   [chr15:74703927-74703928, rs200894892, rs741761]
# 25563   [rs741761, chr15:74703927-74703928, rs200894892]
# 25564   [chr15:74703927-74703928, rs200894892, rs741761]
# 25565   [rs741761, chr15:74703927-74703928, rs200894892]
# 25566   [chr15:74703927-74703928, rs200894892, rs741761]
# 20257  [rs151250126, rs199954231, rs191996643, chr6:1...
# 20260            [rs151250126, rs199954231, rs191996643]
# 64432  [rs191996643, rs199954231, chr6:137338159-1373...
# 64435            [rs191996643, rs199954231, rs200209614]
# 29939              [rs7247025, rs149499521, rs142656214]
# 29940  [rs4993132, chr19:54782174-54782175, rs7247025...
#
#                                                  maflist  \
# 15531              [0.0491214, 0.000199681, 0.000199681]
# 8660               [0.000199681, 0.0499201, 0.000199681]
# 8662               [0.000399361, 0.0499201, 0.000199681]
# 20136              [0.000199681, 0.000199681, 0.0427316]
# 36041  [0.000199681, 0.000199681, 0.00179712, 0.02356...
# 36042  [0.000199681, 0.000199681, 0.00179712, 0.00019...
# 36043               [0.00179712, 0.0235623, 0.000199681]
# 36044               [0.00179712, 0.000199681, 0.0235623]
# 36045               [0.00179712, 0.0235623, 0.000199681]
# 36046               [0.00179712, 0.000199681, 0.0235623]
# 15499              [0.000399361, 0.0491214, 0.000199681]
# 15500              [0.000399361, 0.0491214, 0.000199681]
# 17885             [0.00119808, 0.000199681, 0.000199681]
# 17886             [0.000199681, 0.00119808, 0.000199681]
# 17887             [0.00119808, 0.000199681, 0.000199681]
# 17888             [0.000199681, 0.00119808, 0.000199681]
# 17889             [0.00119808, 0.000199681, 0.000199681]
# 17890             [0.000199681, 0.00119808, 0.000199681]
# 25561             [0.00119808, 0.000199681, 0.000199681]
# 25562             [0.000199681, 0.000199681, 0.00119808]
# 25563             [0.00119808, 0.000199681, 0.000199681]
# 25564             [0.000199681, 0.000199681, 0.00119808]
# 25565             [0.00119808, 0.000199681, 0.000199681]
# 25566             [0.000199681, 0.000199681, 0.00119808]
# 20257  [0.000199681, 0.000199681, 0.0427316, 0.000199...
# 20260              [0.000199681, 0.000199681, 0.0427316]
# 64432              [0.0427316, 0.000199681, 0.000199681]
# 64435              [0.0427316, 0.000199681, 0.000199681]
# 29939                [0.0335463, 0.00159744, 0.00179712]
# 29940   [0.00439297, 0.000798722, 0.0335463, 0.00159744]
#
#                                                  fstlist   unpac    hgnc
# 15531                [0.15495, -5.5217e-06, -8.0156e-06]  P35269  GTF2F1
# 8660                    [0.00055949, 0.1564, 3.0464e-05]  Q9P2W7  B3GAT1
# 8662                     [0.0010713, 0.1564, 3.0464e-05]  Q9P2W7  B3GAT1
# 20136                 [0.00055949, -5.5217e-06, 0.16327]  P62487  POLR2G
# 36041  [-0.00030599, -0.00030599, 0.0015008, 0.1745, ...  Q96GA7    SDSL
# 36042  [-0.00030599, -0.00030599, 0.0015008, -0.00030...  Q96GA7    SDSL
# 36043                   [0.0015008, 0.1745, -0.00030599]  Q96GA7    SDSL
# 36044                   [0.0015008, -0.00030599, 0.1745]  Q96GA7    SDSL
# 36045                   [0.0015008, 0.1745, -0.00030599]  Q96GA7    SDSL
# 36046                   [0.0015008, -0.00030599, 0.1745]  Q96GA7    SDSL
# 15499                 [2.3687e-05, 0.15495, -8.0156e-06]  P23280     CA6
# 15500                 [2.3687e-05, 0.15495, -5.5217e-06]  P23280     CA6
# 17885                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 17886                  [3.0464e-05, 0.16095, 0.00055949]  O75326  SEMA7A
# 17887                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 17888                  [3.0464e-05, 0.16095, 0.00055949]  O75326  SEMA7A
# 17889                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 17890                  [3.0464e-05, 0.16095, 0.00055949]  O75326  SEMA7A
# 25561                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 25562                  [3.0464e-05, 0.00055949, 0.16095]  O75326  SEMA7A
# 25563                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 25564                  [3.0464e-05, 0.00055949, 0.16095]  O75326  SEMA7A
# 25565                  [0.16095, 3.0464e-05, 0.00055949]  O75326  SEMA7A
# 25566                  [3.0464e-05, 0.00055949, 0.16095]  O75326  SEMA7A
# 20257    [0.00055949, -5.5217e-06, 0.16327, -8.0156e-06]  Q9UHF4  IL20RA
# 20260                 [0.00055949, -5.5217e-06, 0.16327]  Q9UHF4  IL20RA
# 64432                [0.16327, -5.5217e-06, -8.0156e-06]  Q9UHF4  IL20RA
# 64435                 [0.16327, -5.5217e-06, 0.00055949]  Q9UHF4  IL20RA
# 29939                     [0.35826, 0.0046268, 0.003728]  Q8N423  LILRB2
# 29940         [0.0041371, 0.0018076, 0.35826, 0.0046268]  Q8N423  LILRB2

# %%
# For each gene, determine if it contains a significant bin
sig_grp = [fst.groupby("unpac").apply(lambda x: len(x[x["fst"]>0.35])>0) for fst in fst_grp]

# %%
# Generate an 8x8 confusion matrix
# Calculate the confusion matrix
fig,axes = plt.subplots(len(sig_grp),len(sig_grp),figsize=(50,50))
for i,grp1 in enumerate(sig_grp):
    for j,grp2 in enumerate(sig_grp):
        if j <= i:
            conf_matrix(axes[i][j],grp1,grp2,fst_labs[i],fst_labs[j])
        else:
            axes[i][j].set_frame_on(False)
            axes[i][j].axes.get_xaxis().set_visible(False)
            axes[i][j].axes.get_yaxis().set_visible(False)
plt.tight_layout()

# %%
fst_by_sphere[(fst_by_sphere["nsnp"]>2) & (fst_by_sphere["fst"]>0.35)]
# Out:
#       structid  biounit  model chain  seqid       fst  nsnp  \
# 29939     4LLA        1      1     A    131  0.351125     3
#
#                                      snplist  \
# 29939  [rs7247025, rs149499521, rs142656214]
#
#                                    maflist                         fstlist  \
# 29939  [0.0335463, 0.00159744, 0.00179712]  [0.35826, 0.0046268, 0.003728]
#
#         unpac    hgnc
# 29939  Q8N423  LILRB2

# %%
# For each gene, determine if it contains a significant bin
sig_grp = [fst.groupby("unpac").apply(lambda x: len(x[x["fst"]>0.5])>0) for fst in fst_grp]

# %%
# Generate an 8x8 confusion matrix
# Calculate the confusion matrix
fig,axes = plt.subplots(len(sig_grp),len(sig_grp),figsize=(50,50))
for i,grp1 in enumerate(sig_grp):
    for j,grp2 in enumerate(sig_grp):
        if j <= i:
            conf_matrix(axes[i][j],grp1,grp2,fst_labs[i],fst_labs[j])
        else:
            axes[i][j].set_frame_on(False)
            axes[i][j].axes.get_xaxis().set_visible(False)
            axes[i][j].axes.get_yaxis().set_visible(False)
plt.tight_layout()
