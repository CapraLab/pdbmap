# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import gzip
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
# Biological unit specification
structid = "ENSP00000296589_1"
biounit  = 0

# %%
# Load the results file into a pandas data frame
results_fname = 'results/sliding_sphere_10/split/obs/bystruct/sliding_sphere_%s-%d.txt.gz'%(structid,biounit)
with gzip.open(results_fname,'rb') as obs_fin:
    header = obs_fin.readline().split('\t')
with gzip.open(results_fname,'rb') as obs_fin:
    df = pd.read_table(obs_fin,delimiter='\t')

# %%
# for i,col in enumerate(df.columns):
#     print i,col

# %%
# Convenient sets of column names
count_cols    = ['amr_count','asn_count','eur_count','afr_count']
cdaf_cols     = ['amr_cdaf','asn_cdaf', 'eur_cdaf', 'afr_cdaf']
sumddaf_cols  = ['amr_asn_sumddaf', 'amr_eur_sumddaf', 'amr_afr_sumddaf', 'asn_eur_sumddaf', 'asn_afr_sumddaf', 'eur_afr_sumddaf']
meanddaf_cols = ['amr_asn_meanddaf','amr_eur_meanddaf','amr_afr_meanddaf','asn_eur_meanddaf','asn_afr_meanddaf','eur_afr_meanddaf']
minddaf_cols  = ['amr_asn_minddaf', 'amr_eur_minddaf', 'amr_afr_minddaf', 'asn_eur_minddaf', 'asn_afr_minddaf', 'eur_afr_minddaf']
maxddaf_cols  = ['amr_asn_maxddaf', 'amr_eur_maxddaf', 'amr_afr_maxddaf', 'asn_eur_maxddaf', 'asn_afr_maxddaf', 'eur_afr_maxddaf']
nest_cols     = [count_cols,cdaf_cols,sumddaf_cols,meanddaf_cols,minddaf_cols,maxddaf_cols]
count_pval_cols    = ['amr_count_pval','asn_count_pval','eur_count_pval','afr_count_pval']
cdaf_pval_cols     = ['amr_cdaf_pval','asn_cdaf_pval', 'eur_cdaf_pval', 'afr_cdaf_pval']
sumddaf_pval_cols  = ['amr_asn_sumddaf_pval', 'amr_eur_sumddaf_pval', 'amr_afr_sumddaf_pval', 'asn_eur_sumddaf_pval', 'asn_afr_sumddaf_pval', 'eur_afr_sumddaf_pval']
meanddaf_pval_cols = ['amr_asn_meanddaf_pval','amr_eur_meanddaf_pval','amr_afr_meanddaf_pval','asn_eur_meanddaf_pval','asn_afr_meanddaf_pval','eur_afr_meanddaf_pval']
minddaf_pval_cols  = ['amr_asn_minddaf_pval', 'amr_eur_minddaf_pval', 'amr_afr_minddaf_pval', 'asn_eur_minddaf_pval', 'asn_afr_minddaf_pval', 'eur_afr_minddaf_pval']
maxddaf_pval_cols  = ['amr_asn_maxddaf_pval', 'amr_eur_maxddaf_pval', 'amr_afr_maxddaf_pval', 'asn_eur_maxddaf_pval', 'asn_afr_maxddaf_pval', 'eur_afr_maxddaf_pval']
nest_pval_cols     = [count_pval_cols,cdaf_pval_cols,sumddaf_pval_cols,meanddaf_pval_cols,minddaf_pval_cols,maxddaf_pval_cols]
nest_all = [nest_cols,nest_pval_cols]

# %%
# Summary boxplots of observed values for count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(df.ix[:,colset])
    plt.tight_layout()
    plt.show()

# %%
# Summary boxplots of pvalues for count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_pval_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(-np.log10(df.ix[:,colset]))
    plt.hlines(2,0,10,'red',linestyles='dotted')
    plt.hlines(1.3,0,10,'blue',linestyles='dotted')
    plt.tight_layout()
    plt.show()

# %%
# Load the permutation file into a pandas data frame
perm_fname = 'results/sliding_sphere_10/split/perm/bystruct/sliding_sphere_perm_%s-%d.txt.gz'%(structid,biounit)
print perm_fname
with gzip.open(perm_fname,'rb') as perm_fin:
    dfp = pd.read_table(perm_fin,delimiter='\t',header=0)
# Out:
# results/sliding_sphere_10/split/perm/bystruct/sliding_sphere_perm_ENSP00000296589_1-0.txt.gz
#                isvar          issnp         amr_af         asn_af  \
# count  233500.000000  233500.000000  233500.000000  233500.000000
# mean        0.132762       0.024039       0.000705       0.000814
# std         0.339318       0.153169       0.015567       0.017295
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       0.550000       0.390000
#
#               eur_af         afr_af          seqid              x  \
# count  233500.000000  233500.000000  233500.000000  233500.000000
# mean        0.000465       0.000121     297.259101      58.756975
# std         0.020764       0.002461     131.057762      13.833941
# min         0.000000       0.000000      68.000000      27.995750
# 25%         0.000000       0.000000     184.000000      45.565838
# 50%         0.000000       0.000000     299.000000      59.993362
# 75%         0.000000       0.000000     410.000000      70.960640
# max         0.970000       0.050000     524.000000      88.326416
#
#                    y              z       rescount      amr_count  \
# count  233500.000000  233500.000000  233500.000000  233500.000000
# mean       95.357931      35.688221      18.263383       0.043349
# std        13.809805      11.736360       5.950307       0.208813
# min        63.478359       9.472222       6.000000       0.000000
# 25%        84.580376      27.065111      14.000000       0.000000
# 50%        95.824333      35.730141      18.000000       0.000000
# 75%       106.319374      45.359428      22.000000       0.000000
# max       123.556496      62.448887      34.000000       3.000000
#
#            asn_count      eur_count      afr_count       amr_cdaf  \
# count  233500.000000  233500.000000  233500.000000  233500.000000
# mean        0.379161       0.058587       0.043349       0.012688
# std         0.634226       0.241095       0.208813       0.066388
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       0.000000
# max         6.000000       3.000000       3.000000       1.100000
#
#             asn_cdaf       eur_cdaf       afr_cdaf  amr_asn_sumddaf  \
# count  233500.000000  233500.000000  233500.000000    233500.000000
# mean        0.014439       0.008606       0.002167        -0.001751
# std         0.073256       0.089204       0.010441         0.058157
# min         0.000000       0.000000       0.000000        -0.480000
# 25%         0.000000       0.000000       0.000000        -0.001700
# 50%         0.000000       0.000000       0.000000         0.000000
# 75%         0.001700       0.000000       0.000000         0.000000
# max         1.170000       1.940000       0.150000         1.080000
#
#        amr_asn_meanddaf  amr_asn_medianddaf  amr_asn_minddaf  amr_asn_maxddaf  \
# count     233500.000000       233500.000000    233500.000000    233500.000000
# mean          -0.001383           -0.001403        -0.002910         0.000146
# std            0.050479            0.050333         0.050753         0.055588
# min           -0.160000           -0.160000        -0.160000        -0.160000
# 25%           -0.001700           -0.001700        -0.001700        -0.001700
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.540000            0.540000         0.540000         0.540000
#
#        amr_asn_abssumddaf  amr_asn_absmeanddaf  amr_asn_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.010923             0.009041               0.009041
# std              0.057944             0.049889               0.049889
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.001700             0.001700               0.001700
# max              1.080000             0.540000               0.540000
#
#        amr_asn_absminddaf  amr_asn_absmaxddaf  amr_eur_sumddaf  \
# count       233500.000000       233500.000000    233500.000000
# mean             0.007635            0.010614         0.004082
# std              0.047710            0.056800         0.056666
# min              0.000000            0.000000        -0.840000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.001700            0.001700         0.000000
# max              0.540000            0.540000         0.660000
#
#        amr_eur_meanddaf  amr_eur_medianddaf  amr_eur_minddaf  amr_eur_maxddaf  \
# count     233500.000000       233500.000000    233500.000000    233500.000000
# mean           0.003343            0.003320         0.001724         0.005013
# std            0.048936            0.048834         0.051565         0.051556
# min           -0.420000           -0.420000        -0.420000        -0.420000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.220000            0.220000         0.220000         0.220000
#
#        amr_eur_abssumddaf  amr_eur_absmeanddaf  amr_eur_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.011255             0.009332               0.009332
# std              0.056451             0.048358               0.048358
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.840000             0.420000               0.420000
#
#        amr_eur_absminddaf  amr_eur_absmaxddaf  amr_afr_sumddaf  \
# count       233500.000000       233500.000000    233500.000000
# mean             0.007826            0.011019         0.010520
# std              0.046369            0.054869         0.056965
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.420000            0.420000         1.000000
#
#        amr_afr_meanddaf  amr_afr_medianddaf  amr_afr_minddaf  amr_afr_maxddaf  \
# count     233500.000000       233500.000000    233500.000000    233500.000000
# mean           0.008731            0.008592         0.007308         0.010325
# std            0.049007            0.048897         0.046913         0.055750
# min            0.000000            0.000000         0.000000         0.000000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.500000            0.500000         0.500000         0.500000
#
#        amr_afr_abssumddaf  amr_afr_absmeanddaf  amr_afr_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.010520             0.008731               0.008731
# std              0.056965             0.049007               0.049007
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              1.000000             0.500000               0.500000
#
#        amr_afr_absminddaf  amr_afr_absmaxddaf  asn_eur_sumddaf  \
# count       233500.000000       233500.000000    233500.000000
# mean             0.007308            0.010325         0.005833
# std              0.046913            0.055750         0.113737
# min              0.000000            0.000000        -1.920000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.001700
# max              0.500000            0.500000         1.140000
#
#        asn_eur_meanddaf  asn_eur_medianddaf  asn_eur_minddaf  asn_eur_maxddaf  \
# count     233500.000000       233500.000000    233500.000000    233500.000000
# mean           0.004726            0.004722         0.001578         0.007923
# std            0.098489            0.098242         0.106259         0.101308
# min           -0.960000           -0.960000        -0.960000        -0.960000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.001700            0.001700         0.001700         0.001700
# max            0.380000            0.380000         0.380000         0.380000
#
#        asn_eur_abssumddaf  asn_eur_absmeanddaf  asn_eur_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.022178             0.018374               0.018374
# std              0.113299             0.097296               0.097296
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.001700             0.001700               0.001700
# max              1.920000             0.960000               0.960000
#
#        asn_eur_absminddaf  asn_eur_absmaxddaf  asn_afr_sumddaf  \
# count       233500.000000       233500.000000    233500.000000
# mean             0.015465            0.021629         0.012272
# std              0.093162            0.110582         0.063985
# min              0.000000            0.000000        -0.080000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.001700            0.001700         0.001700
# max              0.960000            0.960000         1.020000
#
#        asn_afr_meanddaf  asn_afr_medianddaf  asn_afr_minddaf  asn_afr_maxddaf  \
# count     233500.000000       233500.000000    233500.000000    233500.000000
# mean           0.010114            0.009989         0.008431         0.011973
# std            0.054424            0.054394         0.052256         0.061677
# min           -0.040000           -0.040000        -0.040000        -0.040000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.001700            0.001700         0.001700         0.001700
# max            0.340000            0.340000         0.340000         0.340000
#
#        asn_afr_abssumddaf  asn_afr_absmeanddaf  asn_afr_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.012951             0.010681               0.010681
# std              0.063956             0.054344               0.054344
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.001700             0.001700               0.001700
# max              1.020000             0.340000               0.340000
#
#        asn_afr_absminddaf  asn_afr_absmaxddaf  eur_afr_sumddaf  \
# count       233500.000000       233500.000000    233500.000000
# mean             0.009017            0.012533         0.006439
# std              0.052121            0.061596         0.084955
# min              0.000000            0.000000        -0.120000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.001700            0.001700         0.000000
# max              0.340000            0.340000         1.840000
#
#        eur_afr_meanddaf  eur_afr_medianddaf  eur_afr_minddaf  eur_afr_maxddaf  \
# count     233500.000000       233500.000000     233500.00000    233500.000000
# mean           0.005388            0.005267          0.00405         0.006853
# std            0.073968            0.073701          0.07074         0.084648
# min           -0.040000           -0.040000         -0.04000        -0.040000
# 25%            0.000000            0.000000          0.00000         0.000000
# 50%            0.000000            0.000000          0.00000         0.000000
# 75%            0.000000            0.000000          0.00000         0.000000
# max            0.920000            0.920000          0.92000         0.920000
#
#        eur_afr_abssumddaf  eur_afr_absmeanddaf  eur_afr_absmedianddaf  \
# count       233500.000000        233500.000000          233500.000000
# mean             0.009227             0.007693               0.007693
# std              0.084899             0.073817               0.073817
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              1.840000             0.920000               0.920000
#
#        eur_afr_absminddaf  eur_afr_absmaxddaf
# count       233500.000000       233500.000000
# mean             0.006385            0.009169
# std              0.070457            0.084520
# min              0.000000            0.000000
# 25%              0.000000            0.000000
# 50%              0.000000            0.000000
# 75%              0.000000            0.000000
# max              0.920000            0.920000

# %%
usechain = df.chain.unique()
minseqid = df.seqid.min()
maxseqid = df.seqid.max()
print usechain,minseqid,maxseqid
# Out:
# ['A'] 68 524

# %%
MINSEQ = minseqid
MAXSEQ = maxseqid
CHAIN  = usechain[0]
fig, axes = plt.subplots(4,figsize=(MAXSEQ/4,20))
for i,col in enumerate(nest_cols[2:]):
    eurafr  = col[-1]
    eurafrp = nest_pval_cols[2+i][-1]
    # For each residue in the sequence, show the permutation boxplot and observed value
    dft   = df[(df.chain==CHAIN) & (df.seqid>=MINSEQ) & (df.seqid<=MAXSEQ)]
    dfpt  = dfp[(dfp.chain==CHAIN) & (df.seqid>=MINSEQ) & (dfp.seqid<=MAXSEQ)]
    cdict = {0:'blue',1:'red'} # Significance coloring
    sns.boxplot(dfpt[eurafr],groupby=dfpt.seqid,ax=axes[i])
    axes[i].scatter(dft.seqid-MINSEQ,dft[eurafr],color=[cdict[x<0.05] for x in dft[eurafrp]],marker='o',s=75)
    stat  = eurafr.split('_')[-1][:-4]
    statp = stat+'p'
    axes[i].set_title("Observed Sphere Values in Permutation Context\n %s-%d deltaDAF (%s) EUR vs AFR"%(structid,biounit,stat),fontsize=15)
    # Generate Chimera attribute files
    with open("temp/%s-%d_%s.attr"%(structid,biounit,stat),'wb') as fout:
        fout.write("attribute: %s\nmatch mode: 1-to-1\nrecipient: residues\n\n"%stat)
        for _,row in df[['chain','seqid',eurafr]].iterrows():
            fout.write("\t:%d.%s\t%.6f\n"%(row[1],row[0],row[2]))
    with open("temp/%s-%d_%s.attr"%(structid,biounit,statp),'wb') as fout:
        fout.write("attribute: %s\nmatch mode: 1-to-1\nrecipient: residues\n\n"%statp)
        for _,row in df[['chain','seqid',eurafrp]].iterrows():
            fout.write("\t:%d.%s\t%.6f\n"%(row[1],row[0],row[2]))
plt.tight_layout()
savefig('temp/deltaDAF_Distribution_%s-%d.pdf'%(structid,biounit))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e2a9579c2ad4> in <module>()
#       8     # For each residue in the sequence, show the permutation boxplot and observed value
#       9     dft   = df[(df.chain==CHAIN) & (df.seqid>=MINSEQ) & (df.seqid<=MAXSEQ)]
# ---> 10     dfpt  = dfp[(dfp.chain==CHAIN) & (df.seqid>=MINSEQ) & (dfp.seqid<=MAXSEQ)]
#      11     cdict = {0:'blue',1:'red'} # Significance coloring
#      12     sns.boxplot(dfpt[eurafr],groupby=dfpt.seqid,ax=axes[i])
#
# /Users/mikesivley/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'chain'
