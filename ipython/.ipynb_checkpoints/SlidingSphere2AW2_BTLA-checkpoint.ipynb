# %%
# Ensure that we are in the main pdbmap directory and not a subdirectory or elsewhere
# %cd ../../pdbmap
# Out:
# /Users/mikesivley/pdbmap

# %%
# Load libraries
# %matplotlib inline
import gzip
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
pd.set_option('display.max_columns', 200)

# %%
# Biological unit specification
structid = "2AW2"
biounit  = 1

# %%
# Load the results file into a pandas data frame
results_fname = 'results/sliding_sphere_10/split/obs/bystruct/sliding_sphere_%s-%d.txt.gz'%(structid,biounit)
# import os
# os.system('gzcat %s | scripts/fix_headers.py | gzip > %s.fixed.gz'%(results_fname,results_fname))
results_fname += '.fixed.gz'
# results_fname = 'scripts/1q94.corrected.txt.gz'
with gzip.open(results_fname,'rb') as obs_fin:
    header = obs_fin.readline().split('\t')
with gzip.open(results_fname,'rb') as obs_fin:
    df = pd.read_table(obs_fin,delimiter='\t')

# %%
df[(df.chain=='B') & (df.seqid==58)]
# Out:
#     isvar issnp  name amr_af asn_af eur_af afr_af    aa ref_allele alt_allele  \
# 89      0  None  None   None   None   None   None  None       None       None
#
#    structid chain     unp  seqid          x          y          z  rescount  \
# 89     2AW2     B  Q92956     58 -12.354167 -33.993336  17.419832        18
#
#     amr_count  asn_count  eur_count  afr_count  amr_cdaf  asn_cdaf  eur_cdaf  \
# 89          1          1          1          1      0.01      0.04     0.004
#
#     afr_cdaf  amr_asn_sumddaf  amr_asn_meanddaf  amr_asn_medianddaf  \
# 89      0.04            -0.03             -0.03               -0.03
#
#     amr_asn_minddaf  amr_asn_maxddaf  amr_asn_abssumddaf  amr_asn_absmeanddaf  \
# 89            -0.03            -0.03                0.03                 0.03
#
#     amr_asn_absmedianddaf  amr_asn_absminddaf  amr_asn_absmaxddaf  \
# 89                   0.03                0.03                0.03
#
#     amr_eur_sumddaf  amr_eur_meanddaf  amr_eur_medianddaf  amr_eur_minddaf  \
# 89            0.006             0.006               0.006            0.006
#
#     amr_eur_maxddaf  amr_eur_abssumddaf  amr_eur_absmeanddaf  \
# 89            0.006               0.006                0.006
#
#     amr_eur_absmedianddaf  amr_eur_absminddaf  amr_eur_absmaxddaf  \
# 89                  0.006               0.006               0.006
#
#     amr_afr_sumddaf  amr_afr_meanddaf  amr_afr_medianddaf  amr_afr_minddaf  \
# 89            -0.03             -0.03               -0.03            -0.03
#
#     amr_afr_maxddaf  amr_afr_abssumddaf  amr_afr_absmeanddaf  \
# 89            -0.03                0.03                 0.03
#
#     amr_afr_absmedianddaf  amr_afr_absminddaf  amr_afr_absmaxddaf  \
# 89                   0.03                0.03                0.03
#
#     asn_eur_sumddaf  asn_eur_meanddaf  asn_eur_medianddaf  asn_eur_minddaf  \
# 89            0.036             0.036               0.036            0.036
#
#     asn_eur_maxddaf  asn_eur_abssumddaf  asn_eur_absmeanddaf  \
# 89            0.036               0.036                0.036
#
#     asn_eur_absmedianddaf  asn_eur_absminddaf  asn_eur_absmaxddaf  \
# 89                  0.036               0.036               0.036
#
#     asn_afr_sumddaf  asn_afr_meanddaf  asn_afr_medianddaf  asn_afr_minddaf  \
# 89                0                 0                   0                0
#
#     asn_afr_maxddaf  asn_afr_abssumddaf  asn_afr_absmeanddaf  \
# 89                0                   0                    0
#
#     asn_afr_absmedianddaf  asn_afr_absminddaf  asn_afr_absmaxddaf  \
# 89                      0                   0                   0
#
#     eur_afr_sumddaf  eur_afr_meanddaf  eur_afr_medianddaf  eur_afr_minddaf  \
# 89           -0.036            -0.036              -0.036           -0.036
#
#     eur_afr_maxddaf  eur_afr_abssumddaf  eur_afr_absmeanddaf  \
# 89           -0.036               0.036                0.036
#
#     eur_afr_absmedianddaf  eur_afr_absminddaf  eur_afr_absmaxddaf  \
# 89                  0.036               0.036               0.036
#
#     amr_count_pval  asn_count_pval  eur_count_pval  afr_count_pval  \
# 89           0.134           0.134           0.134            0.16
#
#     amr_cdaf_pval  asn_cdaf_pval  eur_cdaf_pval  afr_cdaf_pval  \
# 89          0.134          0.134          0.134          0.134
#
#     amr_asn_sumddaf_pval  amr_asn_meanddaf_pval  amr_asn_medianddaf_pval  \
# 89                 0.134                  0.131                    0.131
#
#     amr_asn_minddaf_pval  amr_asn_maxddaf_pval  amr_asn_abssumddaf_pval  \
# 89                 0.134                 0.131                    0.134
#
#     amr_asn_absmeanddaf_pval  amr_asn_absmedianddaf_pval  \
# 89                     0.131                       0.131
#
#     amr_asn_absminddaf_pval  amr_asn_absmaxddaf_pval  amr_eur_sumddaf_pval  \
# 89                    0.131                    0.134                 0.134
#
#     amr_eur_meanddaf_pval  amr_eur_medianddaf_pval  amr_eur_minddaf_pval  \
# 89                  0.131                    0.131                 0.131
#
#     amr_eur_maxddaf_pval  amr_abseur_sumddaf_abspval  \
# 89                 0.134                       0.134
#
#     amr_abseur_meanddaf_abspval  amr_abseur_medianddaf_abspval  \
# 89                        0.131                          0.131
#
#     amr_abseur_minddaf_abspval  amr_abseur_maxddaf_abspval  \
# 89                       0.131                       0.134
#
#     amr_afr_sumddaf_pval  amr_afr_meanddaf_pval  amr_afr_medianddaf_pval  \
# 89                  0.16                   0.16                     0.16
#
#     amr_afr_minddaf_pval  amr_afr_maxddaf_pval  amr_afr_abssumddaf_pval  \
# 89                  0.16                  0.16                     0.16
#
#     amr_afr_absmeanddaf_pval  amr_afr_absmedianddaf_pval  \
# 89                      0.16                        0.16
#
#     amr_afr_absminddaf_pval  amr_afr_absmaxddaf_pval  asn_eur_sumddaf_pval  \
# 89                     0.16                     0.16                 0.134
#
#     asn_eur_meanddaf_pval  asn_eur_medianddaf_pval  asn_eur_minddaf_pval  \
# 89                  0.131                    0.131                 0.131
#
#     asn_eur_maxddaf_pval  asn_abseur_sumddaf_abspval  \
# 89                 0.134                       0.134
#
#     asn_abseur_meanddaf_abspval  asn_abseur_medianddaf_abspval  \
# 89                        0.131                          0.131
#
#     asn_abseur_minddaf_abspval  asn_abseur_maxddaf_abspval  \
# 89                       0.131                       0.134
#
#     asn_afr_sumddaf_pval  asn_afr_meanddaf_pval  asn_afr_medianddaf_pval  \
# 89                 1.001                  1.001                    1.001
#
#     asn_afr_minddaf_pval  asn_afr_maxddaf_pval  asn_afr_abssumddaf_pval  \
# 89                 1.001                 1.001                    1.001
#
#     asn_afr_absmeanddaf_pval  asn_afr_absmedianddaf_pval  \
# 89                     1.001                       1.001
#
#     asn_afr_absminddaf_pval  asn_afr_absmaxddaf_pval  eur_afr_sumddaf_pval  \
# 89                    1.001                    1.001                 0.134
#
#     eur_afr_meanddaf_pval  eur_afr_medianddaf_pval  eur_afr_minddaf_pval  \
# 89                  0.131                    0.131                 0.134
#
#     eur_afr_maxddaf_pval  eur_absafr_sumddaf_abspval  \
# 89                 0.131                       0.134
#
#     eur_absafr_meanddaf_abspval  eur_absafr_medianddaf_abspval  \
# 89                        0.131                          0.131
#
#     eur_absafr_minddaf_abspval  eur_absafr_maxddaf_abspval
# 89                       0.131                       0.134

# %%
# for i,col in enumerate(header):
#     print i,col
# pd.set_option('display.max_columns', 200)
# df.describe()

# %%
# Convenient sets of column names
count_cols    = ['amr_count','asn_count','eur_count','afr_count']
cdaf_cols     = ['amr_cdaf','asn_cdaf', 'eur_cdaf', 'afr_cdaf']
sumddaf_cols  = ['amr_asn_sumddaf', 'amr_eur_sumddaf', 'amr_afr_sumddaf', 'asn_eur_sumddaf', 'asn_afr_sumddaf', 'eur_afr_sumddaf']
meanddaf_cols = ['amr_asn_meanddaf','amr_eur_meanddaf','amr_afr_meanddaf','asn_eur_meanddaf','asn_afr_meanddaf','eur_afr_meanddaf']
minddaf_cols  = ['amr_asn_minddaf', 'amr_eur_minddaf', 'amr_afr_minddaf', 'asn_eur_minddaf', 'asn_afr_minddaf', 'eur_afr_minddaf']
maxddaf_cols  = ['amr_asn_maxddaf', 'amr_eur_maxddaf', 'amr_afr_maxddaf', 'asn_eur_maxddaf', 'asn_afr_maxddaf', 'eur_afr_maxddaf']
nest_cols     = [count_cols,cdaf_cols,sumddaf_cols,meanddaf_cols,minddaf_cols,maxddaf_cols]
count_pval_cols    = ['amr_count_pval','asn_count_pval','eur_count_pval','afr_count_pval']
cdaf_pval_cols     = ['amr_cdaf_pval','asn_cdaf_pval', 'eur_cdaf_pval', 'afr_cdaf_pval']
sumddaf_pval_cols  = ['amr_asn_sumddaf_pval', 'amr_eur_sumddaf_pval', 'amr_afr_sumddaf_pval', 'asn_eur_sumddaf_pval', 'asn_afr_sumddaf_pval', 'eur_afr_sumddaf_pval']
meanddaf_pval_cols = ['amr_asn_meanddaf_pval','amr_eur_meanddaf_pval','amr_afr_meanddaf_pval','asn_eur_meanddaf_pval','asn_afr_meanddaf_pval','eur_afr_meanddaf_pval']
minddaf_pval_cols  = ['amr_asn_minddaf_pval', 'amr_eur_minddaf_pval', 'amr_afr_minddaf_pval', 'asn_eur_minddaf_pval', 'asn_afr_minddaf_pval', 'eur_afr_minddaf_pval']
maxddaf_pval_cols  = ['amr_asn_maxddaf_pval', 'amr_eur_maxddaf_pval', 'amr_afr_maxddaf_pval', 'asn_eur_maxddaf_pval', 'asn_afr_maxddaf_pval', 'eur_afr_maxddaf_pval']
nest_pval_cols     = [count_pval_cols,cdaf_pval_cols,sumddaf_pval_cols,meanddaf_pval_cols,minddaf_pval_cols,maxddaf_pval_cols]
nest_all = [nest_cols,nest_pval_cols]

# %%
# Summary boxplots of observed values for count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(df.ix[:,colset])
    plt.tight_layout()
    plt.show()

# %%
# Summary boxplots of pvalues for count, cDAF, or ΔDAF statistic, stratified by population
for colset in nest_pval_cols:
    plt.figure(figsize=(15,6))
    sns.set_style("whitegrid")
    sns.set_palette("hls")
    sns.boxplot(-np.log10(df.ix[:,colset]))
    plt.hlines(2,0,10,'red',linestyles='dotted')
    plt.hlines(1.3,0,10,'blue',linestyles='dotted')
    plt.tight_layout()
    plt.show()

# %%
# Load the permutation file into a pandas data frame
perm_fname = 'results/sliding_sphere_10/split/perm/bystruct/sliding_sphere_perm_%s-%d.txt.gz'%(structid,biounit)
# import os
# os.system('gzcat %s | scripts/fix_headers.py | gzip > %s.fixed.gz'%(perm_fname,perm_fname))
# perm_fname += '.fixed.gz'
with gzip.open(perm_fname,'rb') as perm_fin:
    dfp = pd.read_table(perm_fin,delimiter='\t')
pd.set_option('display.max_columns', 250)
print dfp.describe()
# Out:
#              # isvar          issnp         amr_af         asn_af  \
# count  103500.000000  103500.000000  103500.000000  103500.000000
# mean        0.053140       0.009739       0.000074       0.000298
# std         0.224314       0.098206       0.000860       0.003440
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       0.010000       0.040000
#
#               eur_af         afr_af          seqid              x  \
# count  103500.000000  103500.000000  103500.000000  103500.000000
# mean        0.000030       0.000367      69.236715     -13.403467
# std         0.000344       0.003721      34.061164       8.035614
# min         0.000000       0.000000       2.000000     -34.494198
# 25%         0.000000       0.000000      43.000000     -19.000891
# 50%         0.000000       0.000000      69.000000     -12.138636
# 75%         0.000000       0.000000      95.000000      -7.735374
# max         0.004000       0.040000     137.000000       2.785500
#
#                    y              z       rescount      amr_count  \
# count  103500.000000  103500.000000  103500.000000  103500.000000
# mean      -14.558491      23.366320      17.695652       0.132821
# std        17.934426       8.471777       5.566414       0.358165
# min       -56.643402       7.105500       5.000000       0.000000
# 25%       -25.683363      16.415443      14.000000       0.000000
# 50%        -9.037834      23.082548      17.000000       0.000000
# 75%        -0.565545      28.956001      21.000000       0.000000
# max        10.927750      47.310001      33.000000       3.000000
#
#            asn_count      eur_count      afr_count       amr_cdaf  \
# count  103500.000000  103500.000000  103500.000000  103500.000000
# mean        0.132821       0.132821       0.172126       0.001328
# std         0.358165       0.358165       0.404142       0.003582
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         3.000000       3.000000       3.000000       0.030000
#
#             asn_cdaf       eur_cdaf       afr_cdaf  amr_asn_sumddaf  \
# count  103500.000000  103500.000000  103500.000000    103500.000000
# mean        0.005313       0.000531       0.006492        -0.003985
# std         0.014327       0.001433       0.015362         0.010745
# min         0.000000       0.000000       0.000000        -0.090000
# 25%         0.000000       0.000000       0.000000         0.000000
# 50%         0.000000       0.000000       0.000000         0.000000
# 75%         0.000000       0.000000       0.000000         0.000000
# max         0.120000       0.012000       0.120000         0.000000
#
#        amr_asn_meanddaf  amr_asn_medianddaf  amr_asn_minddaf  amr_asn_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean          -0.003732           -0.003732        -0.003790        -0.003674
# std            0.009857            0.009857         0.009966         0.009834
# min           -0.030000           -0.030000        -0.030000        -0.030000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.000000            0.000000         0.000000         0.000000
#
#        amr_asn_abssumddaf  amr_asn_absmeanddaf  amr_asn_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.003985             0.003732               0.003732
# std              0.010745             0.009857               0.009857
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.090000             0.030000               0.030000
#
#        amr_asn_absminddaf  amr_asn_absmaxddaf  amr_eur_sumddaf  \
# count       103500.000000       103500.000000    103500.000000
# mean             0.003674            0.003790         0.000797
# std              0.009834            0.009966         0.002149
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.030000            0.030000         0.018000
#
#        amr_eur_meanddaf  amr_eur_medianddaf  amr_eur_minddaf  amr_eur_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean           0.000746            0.000746         0.000735         0.000758
# std            0.001971            0.001971         0.001967         0.001993
# min            0.000000            0.000000         0.000000         0.000000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.006000            0.006000         0.006000         0.006000
#
#        amr_eur_abssumddaf  amr_eur_absmeanddaf  amr_eur_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.000797             0.000746               0.000746
# std              0.002149             0.001971               0.001971
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.018000             0.006000               0.006000
#
#        amr_eur_absminddaf  amr_eur_absmaxddaf  amr_afr_sumddaf  \
# count       103500.000000       103500.000000    103500.000000
# mean             0.000735            0.000758        -0.005164
# std              0.001967            0.001993         0.012124
# min              0.000000            0.000000        -0.090000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.006000            0.006000         0.000000
#
#        amr_afr_meanddaf  amr_afr_medianddaf  amr_afr_minddaf  amr_afr_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean          -0.004853           -0.004853        -0.004853        -0.004853
# std            0.011047            0.011047         0.011047         0.011047
# min           -0.030000           -0.030000        -0.030000        -0.030000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.000000            0.000000         0.000000         0.000000
#
#        amr_afr_abssumddaf  amr_afr_absmeanddaf  amr_afr_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.005164             0.004853               0.004853
# std              0.012124             0.011047               0.011047
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.090000             0.030000               0.030000
#
#        amr_afr_absminddaf  amr_afr_absmaxddaf  asn_eur_sumddaf  \
# count       103500.000000       103500.000000    103500.000000
# mean             0.004853            0.004853         0.004782
# std              0.011047            0.011047         0.012894
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.030000            0.030000         0.108000
#
#        asn_eur_meanddaf  asn_eur_medianddaf  asn_eur_minddaf  asn_eur_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean           0.004478            0.004478         0.004408         0.004547
# std            0.011828            0.011828         0.011801         0.011960
# min            0.000000            0.000000         0.000000         0.000000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.036000            0.036000         0.036000         0.036000
#
#        asn_eur_abssumddaf  asn_eur_absmeanddaf  asn_eur_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.004782             0.004478               0.004478
# std              0.012894             0.011828               0.011828
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.108000             0.036000               0.036000
#
#        asn_eur_absminddaf  asn_eur_absmaxddaf  asn_afr_sumddaf  \
# count       103500.000000       103500.000000    103500.000000
# mean             0.004408            0.004547        -0.001179
# std              0.011801            0.011960         0.005830
# min              0.000000            0.000000        -0.030000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.036000            0.036000         0.000000
#
#        asn_afr_meanddaf  asn_afr_medianddaf  asn_afr_minddaf  asn_afr_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean          -0.001121           -0.001121        -0.001179        -0.001063
# std            0.005613            0.005613         0.005830         0.005547
# min           -0.030000           -0.030000        -0.030000        -0.030000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.000000            0.000000         0.000000         0.000000
#
#        asn_afr_abssumddaf  asn_afr_absmeanddaf  asn_afr_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.001179             0.001121               0.001121
# std              0.005830             0.005613               0.005613
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.030000             0.030000               0.030000
#
#        asn_afr_absminddaf  asn_afr_absmaxddaf  eur_afr_sumddaf  \
# count       103500.000000       103500.000000    103500.000000
# mean             0.001063            0.001179        -0.005961
# std              0.005547            0.005830         0.014047
# min              0.000000            0.000000        -0.108000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              0.030000            0.030000         0.000000
#
#        eur_afr_meanddaf  eur_afr_medianddaf  eur_afr_minddaf  eur_afr_maxddaf  \
# count     103500.000000       103500.000000    103500.000000    103500.000000
# mean          -0.005599           -0.005599        -0.005611        -0.005587
# std            0.012785            0.012785         0.012811         0.012762
# min           -0.036000           -0.036000        -0.036000        -0.036000
# 25%            0.000000            0.000000         0.000000         0.000000
# 50%            0.000000            0.000000         0.000000         0.000000
# 75%            0.000000            0.000000         0.000000         0.000000
# max            0.000000            0.000000         0.000000         0.000000
#
#        eur_afr_abssumddaf  eur_afr_absmeanddaf  eur_afr_absmedianddaf  \
# count       103500.000000        103500.000000          103500.000000
# mean             0.005961             0.005599               0.005599
# std              0.014047             0.012785               0.012785
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.000000             0.000000               0.000000
# max              0.108000             0.036000               0.036000
#
#        eur_afr_absminddaf  eur_afr_absmaxddaf
# count       103500.000000       103500.000000
# mean             0.005587            0.005611
# std              0.012762            0.012811
# min              0.000000            0.000000
# 25%              0.000000            0.000000
# 50%              0.000000            0.000000
# 75%              0.000000            0.000000
# max              0.036000            0.036000

# %%
usechain = df.chain.unique()
minseqid = df.seqid.min()
maxseqid = df.seqid.max()
print usechain,minseqid,maxseqid
# Out:
# ['B' 'A'] 2 137

# %%
MINSEQ = minseqid# minseqid
MAXSEQ = maxseqid
CHAIN  = usechain[0]
fig, axes = plt.subplots(4,figsize=(MAXSEQ/4,20))
for i,col in enumerate(nest_cols[2:]):
    eurafr  = col[-1]
    eurafrp = nest_pval_cols[2+i][-1]
    # For each residue in the sequence, show the permutation boxplot and observed value
    dft   = df[(df.chain==CHAIN) & (df.seqid<MAXSEQ)]
    dfpt  = dfp[(dfp.chain==CHAIN) & (dfp.seqid<MAXSEQ)]
    cdict = {0:'blue',1:'red'} # Significance coloring
    sns.boxplot(dfpt[eurafr],groupby=dfpt.seqid,ax=axes[i])
    axes[i].scatter(dft.seqid-MINSEQ,dft[eurafr],color=[cdict[x<0.05] for x in dft[eurafrp]],marker='o',s=75)
    stat  = eurafr.split('_')[-1][:-4]
    statp = stat+'p'
    axes[i].set_title("Observed Sphere Values in Permutation Context\n %s-%d deltaDAF (%s) EUR vs AFR"%(structid,biounit,stat),fontsize=15)
    # Generate Chimera attribute files
    with open("temp/%s-%d_%s.attr"%(structid,biounit,stat),'wb') as fout:
        fout.write("attribute: %s\nmatch mode: 1-to-1\nrecipient: residues\n\n"%stat)
        for _,row in df[['chain','seqid',eurafr]].iterrows():
            fout.write("\t:%d.%s\t%.6f\n"%(row[1],row[0],row[2]))
    with open("temp/%s-%d_%s.attr"%(structid,biounit,statp),'wb') as fout:
        fout.write("attribute: %s\nmatch mode: 1-to-1\nrecipient: residues\n\n"%statp)
        for _,row in df[['chain','seqid',eurafrp]].iterrows():
            fout.write("\t:%d.%s\t%.6f\n"%(row[1],row[0],row[2]))
plt.tight_layout()
plt.savefig('temp/deltaDAF_Distribution_%s-%d.pdf'%(structid,biounit))
#plt.show()
